# %%
import pandas as pd 
import numpy as np

# %%
def set_term(column1,column2):
    if not pd.isnull(column1):
        return column1
    if not pd.isnull(column2):
        return column2
    else:
        return np.nan

# %%
def separate_id(column,idx):
    for i in column:
        if idx in i:
            column.remove(i)
            if idx == 'UniProtKB' or idx == 'NCBIGene':
                return i.split(':')[-1]
            return i
    return np.nan

# %% [markdown]
# # Ontology of Genes and Genomes

# %%
important_columns_ogg = ['Preferred Label','Synonyms','Obsolete','database_cross_reference','full name from nomenclature authority','type of gene','NCBI GeneID','organism NCBITaxon ID']

# %%
ogg_df = pd.read_csv('data/Genetic/OGG.csv', usecols=important_columns_ogg, dtype=str)
ogg_df
# Out:
#       Preferred Label                              Synonyms Obsolete  \
# 0            NDUFB3P5                                   NaN    false
# 1            RPL34P13                           RPL34_3_616    false
# 2               EFNB3                      EPLG8|EFL6|LERK8    false
# 3              MIR532                   MIRN532|hsa-mir-532    false
# 4               GTSF1                               FAM112B    false
# ...               ...                                   ...      ...
# 69683            mdlB                    mdl|JW5061|ECK0443    false
# 69684       RVBD_0838                                   NaN    false
# 69685        SNORD62A                        U62A|RNU62|U62    false
# 69686    LOC101928500                                   NaN    false
# 69687            SNW1  Prp45|Bx42|SKIIP|PRPF45|NCOA-62|SKIP    false
#
#                                 database_cross_reference  \
# 0                                                    NaN
# 1                                             HGNC:36398
# 2      HGNC:3228|Ensembl:ENSG00000108947|Vega:OTTHUMG...
# 3                           HGNC:32795|miRBase:MI0003205
# 4      HPRD:08150|Ensembl:ENSG00000170627|Vega:OTTHUM...
# ...                                                  ...
# 69683                                    EcoGene:EG14374
# 69684                                                NaN
# 69685                                         HGNC:10219
# 69686                                                NaN
# 69687  HPRD:04340|MIM:603055|Ensembl:ENSG00000100603|...
#
#                    full name from nomenclature authority NCBI GeneID  \
# 0      NADH dehydrogenase (ubiquinone) 1 beta subcomp...       93997
# 1                    ribosomal protein L34 pseudogene 13   100270997
# 2                                              ephrin-B3        1949
# 3                                           microRNA 532      693124
# 4                           gametocyte specific factor 1      121355
# ...                                                  ...         ...
# 69683                                                NaN      945088
# 69684                                                NaN    13318740
# 69685                   small nucleolar RNA, C/D box 62A       26786
# 69686                                                NaN   101928500
# 69687                            SNW domain containing 1       22938
#
#       organism NCBITaxon ID    type of gene
# 0                      9606          pseudo
# 1                      9606          pseudo
# 2                      9606  protein-coding
# 3                      9606           ncRNA
# 4                      9606  protein-coding
# ...                     ...             ...
# 69683                511145  protein-coding
# 69684                 83332  protein-coding
# 69685                  9606          snoRNA
# 69686                  9606           ncRNA
# 69687                  9606  protein-coding
#
# [69688 rows x 8 columns]

# %%
ogg_df = ogg_df[ogg_df['Obsolete']=='false']
ogg_df.drop('Obsolete',inplace=True,axis=1)
print(ogg_df.shape)
# Out:
# (69688, 7)

# %%
ogg_df
# Out:
#       Preferred Label                              Synonyms  \
# 0            NDUFB3P5                                   NaN
# 1            RPL34P13                           RPL34_3_616
# 2               EFNB3                      EPLG8|EFL6|LERK8
# 3              MIR532                   MIRN532|hsa-mir-532
# 4               GTSF1                               FAM112B
# ...               ...                                   ...
# 69683            mdlB                    mdl|JW5061|ECK0443
# 69684       RVBD_0838                                   NaN
# 69685        SNORD62A                        U62A|RNU62|U62
# 69686    LOC101928500                                   NaN
# 69687            SNW1  Prp45|Bx42|SKIIP|PRPF45|NCOA-62|SKIP
#
#                                 database_cross_reference  \
# 0                                                    NaN
# 1                                             HGNC:36398
# 2      HGNC:3228|Ensembl:ENSG00000108947|Vega:OTTHUMG...
# 3                           HGNC:32795|miRBase:MI0003205
# 4      HPRD:08150|Ensembl:ENSG00000170627|Vega:OTTHUM...
# ...                                                  ...
# 69683                                    EcoGene:EG14374
# 69684                                                NaN
# 69685                                         HGNC:10219
# 69686                                                NaN
# 69687  HPRD:04340|MIM:603055|Ensembl:ENSG00000100603|...
#
#                    full name from nomenclature authority NCBI GeneID  \
# 0      NADH dehydrogenase (ubiquinone) 1 beta subcomp...       93997
# 1                    ribosomal protein L34 pseudogene 13   100270997
# 2                                              ephrin-B3        1949
# 3                                           microRNA 532      693124
# 4                           gametocyte specific factor 1      121355
# ...                                                  ...         ...
# 69683                                                NaN      945088
# 69684                                                NaN    13318740
# 69685                   small nucleolar RNA, C/D box 62A       26786
# 69686                                                NaN   101928500
# 69687                            SNW domain containing 1       22938
#
#       organism NCBITaxon ID    type of gene
# 0                      9606          pseudo
# 1                      9606          pseudo
# 2                      9606  protein-coding
# 3                      9606           ncRNA
# 4                      9606  protein-coding
# ...                     ...             ...
# 69683                511145  protein-coding
# 69684                 83332  protein-coding
# 69685                  9606          snoRNA
# 69686                  9606           ncRNA
# 69687                  9606  protein-coding
#
# [69688 rows x 7 columns]

# %% [markdown]
# # Protein Ontology

# %%
important_columns_pr = ['Preferred Label','Synonyms','Obsolete','database_cross_reference','http://www.geneontology.org/formats/oboInOwl#id','only_in_taxon','http://www.w3.org/2000/01/rdf-schema#comment']

# %%
pr_df = pd.read_csv('data/Genetic/PR.csv', usecols=important_columns_pr, dtype=str)
pr_df
# Out:
#                                           Preferred Label  \
# 0       solute carrier organic anion transporter famil...
# 1                            trbG (Escherichia coli K-12)
# 2       interleukin enhancer-binding factor 2 isoform ...
# 3       gag-pol polyprotein (Human immunodeficiency vi...
# 4       serine/threonine-protein kinase MRCK alpha iso...
# ...                                                   ...
# 331975              diamine acetyltransferase 1 (chicken)
# 331976    synaptophysin-like protein 1 isoform m2 (mouse)
# 331977                      zinc finger protein 3 homolog
# 331978                        RKD2 (Arabidopsis thaliana)
# 331979                    zinc finger RNA-binding protein
#
#                                                  Synonyms Obsolete  \
# 0                                         hSLCO3A1/iso:h3    false
# 1                                                     NaN    false
# 2                                             mILF2/iso:1    false
# 3       Pr160Gag-Pol (HIV-1 M:D_Z2/CDC-Z34)|gag-pol (H...    false
# 4                                        hCDC42BPA/iso:h6    false
# ...                                                   ...      ...
# 331975  SSAT-1 (chicken)|putrescine acetyltransferase ...    false
# 331976                                      mSYPL1/iso:m2    false
# 331977                                  ZFP3|zfp-3|ZNF752    false
# 331978                                                NaN    false
# 331979                 M-phase phosphoprotein homolog|ZFR    false
#
#        database_cross_reference  \
# 0            UniProtKB:Q9UIG8-3
# 1                           NaN
# 2            UniProtKB:Q9CXY6-1
# 3              UniProtKB:P12499
# 4            UniProtKB:Q5VT25-6
# ...                         ...
# 331975         UniProtKB:Q8AXL1
# 331976       UniProtKB:O09117-2
# 331977                      NaN
# 331978                      NaN
# 331979                      NaN
#
#        http://www.geneontology.org/formats/oboInOwl#id  \
# 0                                          PR:Q9UIG8-3
# 1                                     NCBIGene:1263580
# 2                                          PR:Q9CXY6-1
# 3                                            PR:P12499
# 4                                          PR:Q5VT25-6
# ...                                                ...
# 331975                                       PR:Q8AXL1
# 331976                                     PR:O09117-2
# 331977                                    PR:000017637
# 331978                               Araport:AT1G74480
# 331979                                    PR:000017654
#
#        http://www.w3.org/2000/01/rdf-schema#comment  \
# 0                       Category=organism-sequence.
# 1                                Category=external.
# 2                       Category=organism-sequence.
# 3                           Category=organism-gene.
# 4                       Category=organism-sequence.
# ...                                             ...
# 331975                      Category=organism-gene.
# 331976                  Category=organism-sequence.
# 331977                               Category=gene.
# 331978                           Category=external.
# 331979                               Category=gene.
#
#                                          only_in_taxon
# 0        http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1       http://purl.obolibrary.org/obo/NCBITaxon_83333
# 2       http://purl.obolibrary.org/obo/NCBITaxon_10090
# 3       http://purl.obolibrary.org/obo/NCBITaxon_11683
# 4        http://purl.obolibrary.org/obo/NCBITaxon_9606
# ...                                                ...
# 331975   http://purl.obolibrary.org/obo/NCBITaxon_9031
# 331976  http://purl.obolibrary.org/obo/NCBITaxon_10090
# 331977                                             NaN
# 331978   http://purl.obolibrary.org/obo/NCBITaxon_3702
# 331979                                             NaN
#
# [331980 rows x 7 columns]

# %%
pr_df = pr_df[pr_df['Obsolete']=='false']
pr_df.drop('Obsolete',inplace=True,axis=1)
print(pr_df.shape)
# Out:
# (326674, 6)
# /home/alvaro/anaconda3/envs/biobert/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
renamed_pr = {'Preferred Label':'Term','database_cross_reference':'cross_reference','http://www.geneontology.org/formats/oboInOwl#id':'id','only_in_taxon':'taxon_id','http://www.w3.org/2000/01/rdf-schema#comment':'type_of_ent'}
pr_df = pr_df.rename(columns=renamed_pr)

# %%
pr_df['taxon_id'] = pr_df['taxon_id'].apply(lambda x: x.split('/')[-1].split('_')[-1] if isinstance(x,str) else np.nan)

# %%
pr_df['type_of_ent'] = pr_df['type_of_ent'].apply(lambda x: x[x.find('Category=') + len('Category='):] if isinstance(x,str) else np.nan)

# %%
pr_df['type_of_ent'] = pr_df['type_of_ent'].apply(lambda x: x.split('.')[0] if isinstance(x,str) else np.nan)

# %%
pr_df['type_of_ent'] = pr_df['type_of_ent'].apply(lambda x: x.replace('-',' ') if isinstance(x,str) else np.nan)

# %%
pr_df['cross_reference'] = pr_df['cross_reference'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else np.nan)

# %%
pr_df['UniprotID'] = pr_df.apply(lambda x: separate_id(x.cross_reference,'UniProtKB') if isinstance(x.cross_reference,list) else np.nan,axis=1)

# %%
pr_df['NCBI_id'] = pr_df['id'].apply(lambda x: x.split(':')[-1] if x.startswith('NCBIGene') else np.nan)

# %%
pr_df.count()
# Out:
# Term               326674
# Synonyms           224830
# cross_reference    178542
# id                 326674
# type_of_ent        324708
# taxon_id           287437
# UniprotID          170646
# NCBI_id              5380
# dtype: int64

# %%
pr_df.sample(10)
# Out:
#                                                      Term  \
# 297515                            glucocorticoid receptor
# 322654  DNA-directed RNA polymerase I subunit RPA49 is...
# 284164                      NAD kinase isoform h3 (human)
# 288487        fucosyltransferase 6 (Arabidopsis thaliana)
# 250220  EP300-interacting inhibitor of differentiation...
# 276687  NADP-dependent malic enzyme isoform 1 (Escheri...
# 228288                                       plk-2 (worm)
# 237150                                  YOL097W-A (yeast)
# 305514  50S ribosomal protein L28 (Shewanella oneidens...
# 118010                   his4 (Schizosaccharomyces pombe)
#
#                                                  Synonyms  cross_reference  \
# 297515  nuclear receptor subfamily 3 group C member 1|...  [IUPHARobj:625]
# 322654                                     mPOLR1E/iso:m3               []
# 284164                                       hNADK/iso:h3               []
# 288487   AtFUT6|At-FUT6|F16A14.28|At1g14080|F7A19.16|FUT6               []
# 250220                                       mEID1/iso:m2               []
# 276687                                      Ec-maeB/iso:1               []
# 228288                                                NaN              NaN
# 237150                                                NaN              NaN
# 305514                          rpmB (SHEON)|rpmB|SO_4247               []
# 118010                                                NaN              NaN
#
#                              id        type_of_ent taxon_id UniprotID NCBI_id
# 297515             PR:000011406               gene      NaN       NaN     NaN
# 322654              PR:Q8K202-3  organism sequence    10090  Q8K202-3     NaN
# 284164              PR:O95544-3  organism sequence     9606  O95544-3     NaN
# 288487                PR:Q9XI80      organism gene     3702    Q9XI80     NaN
# 250220              PR:Q9DCR4-2  organism sequence    10090  Q9DCR4-2     NaN
# 276687              PR:P76558-1  organism sequence    83333  P76558-1     NaN
# 228288  WormBase:WBGene00004043           external     6239       NaN     NaN
# 237150           SGD:S000028854           external   559292       NaN     NaN
# 305514                PR:Q8E9M3      organism gene   211586    Q8E9M3     NaN
# 118010      PomBase:SPBC418.01c           external     4896       NaN     NaN

# %%
pr_df.rename(columns={'NCBI_id':'NCBI GeneID'},inplace=True)

# %%
pr_df
# Out:
#                                                      Term  \
# 0       solute carrier organic anion transporter famil...
# 1                            trbG (Escherichia coli K-12)
# 2       interleukin enhancer-binding factor 2 isoform ...
# 3       gag-pol polyprotein (Human immunodeficiency vi...
# 4       serine/threonine-protein kinase MRCK alpha iso...
# ...                                                   ...
# 331975              diamine acetyltransferase 1 (chicken)
# 331976    synaptophysin-like protein 1 isoform m2 (mouse)
# 331977                      zinc finger protein 3 homolog
# 331978                        RKD2 (Arabidopsis thaliana)
# 331979                    zinc finger RNA-binding protein
#
#                                                  Synonyms cross_reference  \
# 0                                         hSLCO3A1/iso:h3              []
# 1                                                     NaN             NaN
# 2                                             mILF2/iso:1              []
# 3       Pr160Gag-Pol (HIV-1 M:D_Z2/CDC-Z34)|gag-pol (H...              []
# 4                                        hCDC42BPA/iso:h6              []
# ...                                                   ...             ...
# 331975  SSAT-1 (chicken)|putrescine acetyltransferase ...              []
# 331976                                      mSYPL1/iso:m2              []
# 331977                                  ZFP3|zfp-3|ZNF752             NaN
# 331978                                                NaN             NaN
# 331979                 M-phase phosphoprotein homolog|ZFR             NaN
#
#                        id        type_of_ent taxon_id UniprotID NCBI GeneID
# 0             PR:Q9UIG8-3  organism sequence     9606  Q9UIG8-3         NaN
# 1        NCBIGene:1263580           external    83333       NaN     1263580
# 2             PR:Q9CXY6-1  organism sequence    10090  Q9CXY6-1         NaN
# 3               PR:P12499      organism gene    11683    P12499         NaN
# 4             PR:Q5VT25-6  organism sequence     9606  Q5VT25-6         NaN
# ...                   ...                ...      ...       ...         ...
# 331975          PR:Q8AXL1      organism gene     9031    Q8AXL1         NaN
# 331976        PR:O09117-2  organism sequence    10090  O09117-2         NaN
# 331977       PR:000017637               gene      NaN       NaN         NaN
# 331978  Araport:AT1G74480           external     3702       NaN         NaN
# 331979       PR:000017654               gene      NaN       NaN         NaN
#
# [326674 rows x 8 columns]

# %% [markdown]
# # Merge Both Ontologies

# %% [raw]
# df1 = pd.merge(pr_df[pr_df['NCBI GeneID'].notna()],ogg_df, on='NCBI GeneID', how = 'outer')
# df1

# %%
df1 = pd.concat([pr_df,ogg_df])
df1
# Out:
#                                                     Term  \
# 0      solute carrier organic anion transporter famil...
# 1                           trbG (Escherichia coli K-12)
# 2      interleukin enhancer-binding factor 2 isoform ...
# 3      gag-pol polyprotein (Human immunodeficiency vi...
# 4      serine/threonine-protein kinase MRCK alpha iso...
# ...                                                  ...
# 69683                                                NaN
# 69684                                                NaN
# 69685                                                NaN
# 69686                                                NaN
# 69687                                                NaN
#
#                                                 Synonyms cross_reference  \
# 0                                        hSLCO3A1/iso:h3              []
# 1                                                    NaN             NaN
# 2                                            mILF2/iso:1              []
# 3      Pr160Gag-Pol (HIV-1 M:D_Z2/CDC-Z34)|gag-pol (H...              []
# 4                                       hCDC42BPA/iso:h6              []
# ...                                                  ...             ...
# 69683                                 mdl|JW5061|ECK0443             NaN
# 69684                                                NaN             NaN
# 69685                                     U62A|RNU62|U62             NaN
# 69686                                                NaN             NaN
# 69687               Prp45|Bx42|SKIIP|PRPF45|NCOA-62|SKIP             NaN
#
#                      id        type_of_ent taxon_id UniprotID NCBI GeneID  \
# 0           PR:Q9UIG8-3  organism sequence     9606  Q9UIG8-3         NaN
# 1      NCBIGene:1263580           external    83333       NaN     1263580
# 2           PR:Q9CXY6-1  organism sequence    10090  Q9CXY6-1         NaN
# 3             PR:P12499      organism gene    11683    P12499         NaN
# 4           PR:Q5VT25-6  organism sequence     9606  Q5VT25-6         NaN
# ...                 ...                ...      ...       ...         ...
# 69683               NaN                NaN      NaN       NaN      945088
# 69684               NaN                NaN      NaN       NaN    13318740
# 69685               NaN                NaN      NaN       NaN       26786
# 69686               NaN                NaN      NaN       NaN   101928500
# 69687               NaN                NaN      NaN       NaN       22938
#
#       Preferred Label                           database_cross_reference  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# ...               ...                                                ...
# 69683            mdlB                                    EcoGene:EG14374
# 69684       RVBD_0838                                                NaN
# 69685        SNORD62A                                         HGNC:10219
# 69686    LOC101928500                                                NaN
# 69687            SNW1  HPRD:04340|MIM:603055|Ensembl:ENSG00000100603|...
#
#       full name from nomenclature authority organism NCBITaxon ID  \
# 0                                       NaN                   NaN
# 1                                       NaN                   NaN
# 2                                       NaN                   NaN
# 3                                       NaN                   NaN
# 4                                       NaN                   NaN
# ...                                     ...                   ...
# 69683                                   NaN                511145
# 69684                                   NaN                 83332
# 69685      small nucleolar RNA, C/D box 62A                  9606
# 69686                                   NaN                  9606
# 69687               SNW domain containing 1                  9606
#
#          type of gene
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 69683  protein-coding
# 69684  protein-coding
# 69685          snoRNA
# 69686           ncRNA
# 69687  protein-coding
#
# [396362 rows x 13 columns]

# %%
df1 = df1[(~df1.duplicated(subset='NCBI GeneID',keep='last')) | (df1['NCBI GeneID'].isnull())]

# %%
df1
# Out:
#                                                     Term  \
# 0      solute carrier organic anion transporter famil...
# 1                           trbG (Escherichia coli K-12)
# 2      interleukin enhancer-binding factor 2 isoform ...
# 3      gag-pol polyprotein (Human immunodeficiency vi...
# 4      serine/threonine-protein kinase MRCK alpha iso...
# ...                                                  ...
# 69683                                                NaN
# 69684                                                NaN
# 69685                                                NaN
# 69686                                                NaN
# 69687                                                NaN
#
#                                                 Synonyms cross_reference  \
# 0                                        hSLCO3A1/iso:h3              []
# 1                                                    NaN             NaN
# 2                                            mILF2/iso:1              []
# 3      Pr160Gag-Pol (HIV-1 M:D_Z2/CDC-Z34)|gag-pol (H...              []
# 4                                       hCDC42BPA/iso:h6              []
# ...                                                  ...             ...
# 69683                                 mdl|JW5061|ECK0443             NaN
# 69684                                                NaN             NaN
# 69685                                     U62A|RNU62|U62             NaN
# 69686                                                NaN             NaN
# 69687               Prp45|Bx42|SKIIP|PRPF45|NCOA-62|SKIP             NaN
#
#                      id        type_of_ent taxon_id UniprotID NCBI GeneID  \
# 0           PR:Q9UIG8-3  organism sequence     9606  Q9UIG8-3         NaN
# 1      NCBIGene:1263580           external    83333       NaN     1263580
# 2           PR:Q9CXY6-1  organism sequence    10090  Q9CXY6-1         NaN
# 3             PR:P12499      organism gene    11683    P12499         NaN
# 4           PR:Q5VT25-6  organism sequence     9606  Q5VT25-6         NaN
# ...                 ...                ...      ...       ...         ...
# 69683               NaN                NaN      NaN       NaN      945088
# 69684               NaN                NaN      NaN       NaN    13318740
# 69685               NaN                NaN      NaN       NaN       26786
# 69686               NaN                NaN      NaN       NaN   101928500
# 69687               NaN                NaN      NaN       NaN       22938
#
#       Preferred Label                           database_cross_reference  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# ...               ...                                                ...
# 69683            mdlB                                    EcoGene:EG14374
# 69684       RVBD_0838                                                NaN
# 69685        SNORD62A                                         HGNC:10219
# 69686    LOC101928500                                                NaN
# 69687            SNW1  HPRD:04340|MIM:603055|Ensembl:ENSG00000100603|...
#
#       full name from nomenclature authority organism NCBITaxon ID  \
# 0                                       NaN                   NaN
# 1                                       NaN                   NaN
# 2                                       NaN                   NaN
# 3                                       NaN                   NaN
# 4                                       NaN                   NaN
# ...                                     ...                   ...
# 69683                                   NaN                511145
# 69684                                   NaN                 83332
# 69685      small nucleolar RNA, C/D box 62A                  9606
# 69686                                   NaN                  9606
# 69687               SNW domain containing 1                  9606
#
#          type of gene
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 69683  protein-coding
# 69684  protein-coding
# 69685          snoRNA
# 69686           ncRNA
# 69687  protein-coding
#
# [396028 rows x 13 columns]

# %%
df1['Term'] = df1.apply(lambda x: set_term(x['Preferred Label'],x.Term),axis=1)
df1.drop('Preferred Label',axis=1,inplace=True)
# Out:
# <ipython-input-71-0d57d1641ab9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Term'] = df1.apply(lambda x: set_term(x['Preferred Label'],x.Term),axis=1)
# /home/alvaro/anaconda3/envs/biobert/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df1['Synonyms'] = df1.apply(lambda x: set_term(x.Synonyms,x['full name from nomenclature authority']),axis=1)
df1.drop('full name from nomenclature authority',axis=1,inplace=True)
# Out:
# <ipython-input-72-c20e30fdb410>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Synonyms'] = df1.apply(lambda x: set_term(x.Synonyms,x['full name from nomenclature authority']),axis=1)

# %%
df1['cross_reference'] = df1['cross_reference'].apply(lambda x: np.nan if x == [] else x)
# Out:
# <ipython-input-73-d168416dbc32>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['cross_reference'] = df1['cross_reference'].apply(lambda x: np.nan if x == [] else x)

# %%
df1['NCBItaxon_id'] = df1.apply(lambda x: set_term(x['taxon_id'],x['organism NCBITaxon ID']),axis=1)
df1.drop(['organism NCBITaxon ID','taxon_id'],axis=1,inplace=True)
# Out:
# <ipython-input-74-2a7e85be379b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['NCBItaxon_id'] = df1.apply(lambda x: set_term(x['taxon_id'],x['organism NCBITaxon ID']),axis=1)

# %%
df1['cross_reference'] = df1['cross_reference'].apply(lambda d: d if isinstance(d, list) else [])
# Out:
# <ipython-input-89-f20a191fa77c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['cross_reference'] = df1['cross_reference'].apply(lambda d: d if isinstance(d, list) else [])

# %%
df1['database_cross_reference'] = df1['database_cross_reference'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else np.nan )
# Out:
# <ipython-input-77-75c11e4e6a6b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['database_cross_reference'] = df1['database_cross_reference'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else np.nan )

# %%
df1['database_cross_reference'] = df1['database_cross_reference'].apply(lambda d: d if isinstance(d, list) else [])
# Out:
# <ipython-input-87-4d0de8a69d62>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['database_cross_reference'] = df1['database_cross_reference'].apply(lambda d: d if isinstance(d, list) else [])

# %%
df1['id'] = df1['id'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else np.nan )
# Out:
# <ipython-input-82-01f0159a6dc0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['id'] = df1['id'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else np.nan )

# %%
df1['id'] = df1['id'].apply(lambda d: d if isinstance(d, list) else [])
# Out:
# <ipython-input-90-a7176a96af58>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['id'] = df1['id'].apply(lambda d: d if isinstance(d, list) else [])

# %%
df1['cross_reference'] = df1['cross_reference'] + df1['database_cross_reference'] + df1['id']
# Out:
# <ipython-input-97-b16ed176b193>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['cross_reference'] = df1['cross_reference'] + df1['database_cross_reference'] + df1['id']

# %%
df1.drop(['database_cross_reference','id'],axis=1,inplace=True)
# Out:
# /home/alvaro/anaconda3/envs/biobert/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df1.sample(10)
# Out:
#                                                      Term  \
# 207229  peptidyl-prolyl cis-trans isomerase FKBP62 (Ar...
# 319962                        APC4 (Arabidopsis thaliana)
# 20787                                              CFL1P1
# 215580                protocadherin-15 isoform h5 (human)
# 290925  proline and serine-rich protein 3 isoform h3 (...
# 26110                                                rpiB
# 6249    heterochromatin protein 1-binding protein 3 is...
# 303055          brain-derived neurotrophic factor (human)
# 49902                                            SIGLEC10
# 93990   multiple epidermal growth factor-like domains ...
#
#                                                  Synonyms  \
# 207229  rotamase (Arabidopsis thaliana)|PPIase FKBP62 ...
# 319962                                                NaN
# 20787                                               CFLP1
# 215580  hPCDH15/iso:h5|protocadherin-15 isoform CD3-1 ...
# 290925                                    hPROSER3/iso:h3
# 26110                       JW4051|yjcA|alsI|ECK4083|alsB
# 6249                                       mHP1BP3/iso:m3
# 303055                      abrineurin (human)|hBDNF|BDNF
# 49902                               SIGLEC-10|PRO940|SLG2
# 93990   hMEGF8/NGlyco:1|UniProtKB:Q7Z7M0-1, Asn-421, M...
#
#                                           cross_reference  \
# 207229                                        [PR:Q38931]
# 319962                                [Araport:AT4G21530]
# 20787               [Ensembl:ENSG00000223820, HGNC:28560]
# 215580                                      [PR:Q96QU1-6]
# 290925                                      [PR:Q2NL68-3]
# 26110                                   [EcoGene:EG11827]
# 6249                                        [PR:Q3TEA8-3]
# 303055                                        [PR:P23560]
# 49902   [Vega:OTTHUMG00000165521, HPRD:07307, MIM:6060...
# 93990                                      [PR:000057544]
#
#                   type_of_ent UniprotID NCBI GeneID    type of gene  \
# 207229          organism gene    Q38931         NaN             NaN
# 319962               external       NaN         NaN             NaN
# 20787                     NaN       NaN      142913          pseudo
# 215580      organism sequence  Q96QU1-6         NaN             NaN
# 290925      organism sequence  Q2NL68-3         NaN             NaN
# 26110                     NaN       NaN      948602  protein-coding
# 6249        organism sequence  Q3TEA8-3         NaN             NaN
# 303055          organism gene    P23560         NaN             NaN
# 49902                     NaN       NaN       89790  protein-coding
# 93990   organism modification       NaN         NaN             NaN
#
#        NCBItaxon_id
# 207229         3702
# 319962         3702
# 20787          9606
# 215580         9606
# 290925         9606
# 26110        511145
# 6249          10090
# 303055         9606
# 49902          9606
# 93990          9606

# %%
df1['type of gene'] = df1['type of gene'].apply(lambda d: d + ' gene' if isinstance(d, str) else np.nan)
# Out:
# <ipython-input-109-448e6e48f2ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['type of gene'] = df1['type of gene'].apply(lambda d: d + ' gene' if isinstance(d, str) else np.nan)

# %%
df1['type'] = df1.apply(lambda x: set_term(x.type_of_ent,x['type of gene']),axis=1)
df1.drop(['type of gene','type_of_ent'],axis=1,inplace=True)
# Out:
# <ipython-input-111-674723b3db95>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['type'] = df1.apply(lambda x: set_term(x.type_of_ent,x['type of gene']),axis=1)
# /home/alvaro/anaconda3/envs/biobert/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df1['Synonyms'] = df1['Synonyms'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else np.nan )
# Out:
# <ipython-input-171-4361be24323f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Synonyms'] = df1['Synonyms'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else np.nan )

# %%
df1
# Out:
#                                                     Term  \
# 0      solute carrier organic anion transporter famil...
# 1                           trbG (Escherichia coli K-12)
# 2      interleukin enhancer-binding factor 2 isoform ...
# 3      gag-pol polyprotein (Human immunodeficiency vi...
# 4      serine/threonine-protein kinase MRCK alpha iso...
# ...                                                  ...
# 69683                                               mdlB
# 69684                                          RVBD_0838
# 69685                                           SNORD62A
# 69686                                       LOC101928500
# 69687                                               SNW1
#
#                                                 Synonyms  \
# 0                                      [hSLCO3A1/iso:h3]
# 1                                                    NaN
# 2                                          [mILF2/iso:1]
# 3      [Pr160Gag-Pol (HIV-1 M:D_Z2/CDC-Z34), gag-pol ...
# 4                                     [hCDC42BPA/iso:h6]
# ...                                                  ...
# 69683                             [mdl, JW5061, ECK0443]
# 69684                                                NaN
# 69685                                 [U62A, RNU62, U62]
# 69686                                                NaN
# 69687        [Prp45, Bx42, SKIIP, PRPF45, NCOA-62, SKIP]
#
#                                          cross_reference UniprotID  \
# 0                                          [PR:Q9UIG8-3]  Q9UIG8-3
# 1                                     [NCBIGene:1263580]       NaN
# 2                                          [PR:Q9CXY6-1]  Q9CXY6-1
# 3                                            [PR:P12499]    P12499
# 4                                          [PR:Q5VT25-6]  Q5VT25-6
# ...                                                  ...       ...
# 69683                                  [EcoGene:EG14374]       NaN
# 69684                                                 []       NaN
# 69685                                       [HGNC:10219]       NaN
# 69686                                                 []       NaN
# 69687  [HPRD:04340, MIM:603055, Ensembl:ENSG000001006...       NaN
#
#       NCBI GeneID NCBItaxon_id                 type
# 0             NaN         9606    organism sequence
# 1         1263580        83333             external
# 2             NaN        10090    organism sequence
# 3             NaN        11683        organism gene
# 4             NaN         9606    organism sequence
# ...           ...          ...                  ...
# 69683      945088       511145  protein-coding gene
# 69684    13318740        83332  protein-coding gene
# 69685       26786         9606          snoRNA gene
# 69686   101928500         9606           ncRNA gene
# 69687       22938         9606  protein-coding gene
#
# [396028 rows x 7 columns]

# %%
df1.count()
# Out:
# Term               396027
# Synonyms           265007
# cross_reference    396028
# UniprotID          170646
# NCBI GeneID         74587
# NCBItaxon_id       356713
# type               393915
# dtype: int64

# %% [markdown]
# # CTD Genes

# %%
ctd_df = pd.read_csv('data/Genetic/CTD_genes.csv', dtype=str)
ctd_df
# Out:
#                GeneSymbol                                           GeneName  \
# 0                  03B03F            DNA segment, 03B03F (Research Genetics)
# 1                  03B03R            DNA segment, 03B03R (Research Genetics)
# 2       03.MMHAP34FRA.SEQ                     DNA segment, 03.MMHAP34FRA.seq
# 3                   064YA                                                NaN
# 4                 102G4T7                               DNA segment, 102g4T7
# ...                   ...                                                ...
# 544904            ZZEF1.S  zinc finger, ZZ-type with EF-hand domain 1 S h...
# 544905              ZZZ-1     G_PROTEIN_RECEP_F1_2 domain-containing protein
# 544906               ZZZ3                   zinc finger ZZ-type containing 3
# 544907             ZZZ3.L       zinc finger, ZZ-type containing 3 L homeolog
# 544908             ZZZ3.S       zinc finger, ZZ-type containing 3 S homeolog
#
#            GeneID                                         AltGeneIDs  \
# 0           27777                                                NaN
# 1           27778                                                NaN
# 2           53288                                                NaN
# 3         5658107                                                NaN
# 4           56573                                                NaN
# ...           ...                                                ...
# 544904  108709661                                                NaN
# 544905     185208                                                NaN
# 544906      26009  100053222|100074855|100227013|100343576|100379...
# 544907  108714197                                                NaN
# 544908  108715504                                                NaN
#
#                                                  Synonyms     BioGRIDIDs  \
# 0                                                     NaN            NaN
# 1                                                     NaN            NaN
# 2                                                     NaN            NaN
# 3                                                     NaN            NaN
# 4                                                     NaN            NaN
# ...                                                   ...            ...
# 544904  XELAEV_18015398mg|zinc finger ZZ-type and EF-h...            NaN
# 544905                                      CELE_F32D8.10            NaN
# 544906  A306_07098|Anapl_04670|AS27_00889|ATAC1|ATAC c...  117482|224485
# 544907  XELAEV_18022920mg|ZZ-type zinc finger-containi...            NaN
# 544908  XELAEV_18025071mg|ZZ-type zinc finger-containi...            NaN
#
#         PharmGKBIDs                                         UniProtIDs
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4               NaN                                                NaN
# ...             ...                                                ...
# 544904          NaN                                         A0A1L8H8K3
# 544905          NaN                                             Q19959
# 544906  PA134873184  A0A096MN54|A0A0D9S6Y1|A0A1A7ZGG4|A0A1D5QUG5|A0...
# 544907          NaN                                         A0A1L8GLP2
# 544908          NaN                                         A0A1L8GF94
#
# [544909 rows x 8 columns]

# %%
ctd_df.drop('AltGeneIDs',axis=1,inplace=True)

# %%
ctd_df['Synonyms'] = ctd_df['Synonyms'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else [])

# %%
ctd_df['GeneName'] = ctd_df['GeneName'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else [])

# %%
ctd_df['Synonyms'] = ctd_df['Synonyms'] + ctd_df['GeneName']

# %%
ctd_df.drop('GeneName',axis=1,inplace=True)

# %%
ctd_df['BioGRIDIDs'] = ctd_df['BioGRIDIDs'].apply(lambda x: ['BioGRIDIDs:' + i for i in x.split('|')] if isinstance(x,str) else [])

# %%
ctd_df['PharmGKBIDs'] = ctd_df['PharmGKBIDs'].apply(lambda x: ['PharmGKBIDs:' + i for i in x.split('|')] if isinstance(x,str) else [])

# %%
ctd_df['cross_reference'] = ctd_df['BioGRIDIDs'] + ctd_df['PharmGKBIDs']
ctd_df.drop(['PharmGKBIDs','BioGRIDIDs'],axis=1,inplace=True)

# %%
ctd_df.rename(columns={'GeneID':'NCBI GeneID','UniProtIDs':'UniprotID'},inplace=True)

# %%
ctd_df.sample(10)
# Out:
#              GeneSymbol NCBI GeneID  \
# 518511        TSP_07545    10902000
# 353073      MS3_0012952    24589875
# 454155          SOAT1_0   105213989
# 9279          21UR-4280    13193496
# 526903        TSP_15719    10907385
# 291620      LG8H17ORF62   111967839
# 43489        AYB79_GT08    26834547
# 457447  SRAE_1000090500    36375000
# 477676       T265_03397    20317584
# 98050          CBG05216     8587539
#
#                                                  Synonyms   UniprotID  \
# 518511                     [protein-tyrosine phosphatase]         NaN
# 353073                      [MS3_02176, Microsomal GST-3]  A0A095AIX4
# 454155  [Soat1_1, sterol O-acyltransferase 1-like, ste...         NaN
# 9279                              [CELE_C02B10.24, ncRNA]         NaN
# 526903  [general transcription factor II-I repeat doma...         NaN
# 291620  [uncharacterized protein C17orf62 homolog, lin...         NaN
# 43489                                              [tRNA]         NaN
# 457447  [Zinc finger, RING-type domain and Zinc finger...         NaN
# 477676                             [hypothetical protein]  A0A074ZRV0
# 98050                     [Hypothetical protein CBG05216]         NaN
#
#        cross_reference
# 518511              []
# 353073              []
# 454155              []
# 9279                []
# 526903              []
# 291620              []
# 43489               []
# 457447              []
# 477676              []
# 98050               []

# %% [markdown]
# # Merge all DataFrames

# %%
df_final = pd.concat([ctd_df,df1])
df_final
# Out:
#               GeneSymbol NCBI GeneID  \
# 0                 03B03F       27777
# 1                 03B03R       27778
# 2      03.MMHAP34FRA.SEQ       53288
# 3                  064YA     5658107
# 4                102G4T7       56573
# ...                  ...         ...
# 69683                NaN      945088
# 69684                NaN    13318740
# 69685                NaN       26786
# 69686                NaN   101928500
# 69687                NaN       22938
#
#                                           Synonyms UniprotID  \
# 0        [DNA segment, 03B03F (Research Genetics)]       NaN
# 1        [DNA segment, 03B03R (Research Genetics)]       NaN
# 2                 [DNA segment, 03.MMHAP34FRA.seq]       NaN
# 3                                               []       NaN
# 4                           [DNA segment, 102g4T7]       NaN
# ...                                            ...       ...
# 69683                       [mdl, JW5061, ECK0443]       NaN
# 69684                                          NaN       NaN
# 69685                           [U62A, RNU62, U62]       NaN
# 69686                                          NaN       NaN
# 69687  [Prp45, Bx42, SKIIP, PRPF45, NCOA-62, SKIP]       NaN
#
#                                          cross_reference          Term  \
# 0                                                     []           NaN
# 1                                                     []           NaN
# 2                                                     []           NaN
# 3                                                     []           NaN
# 4                                                     []           NaN
# ...                                                  ...           ...
# 69683                                  [EcoGene:EG14374]          mdlB
# 69684                                                 []     RVBD_0838
# 69685                                       [HGNC:10219]      SNORD62A
# 69686                                                 []  LOC101928500
# 69687  [HPRD:04340, MIM:603055, Ensembl:ENSG000001006...          SNW1
#
#       NCBItaxon_id                 type
# 0              NaN                  NaN
# 1              NaN                  NaN
# 2              NaN                  NaN
# 3              NaN                  NaN
# 4              NaN                  NaN
# ...            ...                  ...
# 69683       511145  protein-coding gene
# 69684        83332  protein-coding gene
# 69685         9606          snoRNA gene
# 69686         9606           ncRNA gene
# 69687         9606  protein-coding gene
#
# [940937 rows x 8 columns]

# %%
df_final = df_final[(~df_final.duplicated(subset='NCBI GeneID',keep='last')) | (df_final['NCBI GeneID'].isnull())]

# %%
df_final['Term'] = df_final.apply(lambda x: set_term(x.Term,x['GeneSymbol']),axis=1)
df_final.drop('GeneSymbol',axis=1,inplace=True)
# Out:
# <ipython-input-190-174a0bd00cbd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Term'] = df_final.apply(lambda x: set_term(x.Term,x['GeneSymbol']),axis=1)
# /home/alvaro/anaconda3/envs/biobert/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_final.count()
# Out:
# NCBI GeneID        581156
# Synonyms           771576
# UniprotID          411456
# cross_reference    902597
# Term               902595
# NCBItaxon_id       356713
# type               393915
# dtype: int64

# %%
df_final.sample(10)
# Out:
#        NCBI GeneID                                           Synonyms  \
# 8942        947055                      [JW2560, rbaB, ECK2574, rhlA]
# 304073     9946610                             [hypothetical protein]
# 281425    63366353                                             [tRNA]
# 37701     26129897                                             [tRNA]
# 378788    25354627                             [hypothetical protein]
# 35888       730174  [nucleosome assembly protein 1-like 4 pseudoge...
# 227417         NaN                                                NaN
# 118327         NaN                                                NaN
# 35033       882835                                                NaN
# 312736    20230090                             [hypothetical protein]
#
#          UniprotID    cross_reference               Term NCBItaxon_id  \
# 8942           NaN  [EcoGene:EG10975]               srmB       511145
# 304073  A0A1S0TSE5                 []         LOAG_09176          NaN
# 281425         NaN                 []        J2C24_MGT06          NaN
# 37701          NaN                 []         ASQ72_GT21          NaN
# 378788      W2SPU7                 []       NECAME_14600          NaN
# 35888          NaN                 []           NAP1L4P3         9606
# 227417         NaN      [MGI:1916351]       Ydjc (mouse)        10090
# 118327         NaN       [HGNC:27845]     SOHLH1 (human)         9606
# 35033          NaN                 []             PA2946       208964
# 312736      V3ZXF2                 []  LOTGIDRAFT_106321          NaN
#
#                        type
# 8942    protein-coding gene
# 304073                  NaN
# 281425                  NaN
# 37701                   NaN
# 378788                  NaN
# 35888           pseudo gene
# 227417             external
# 118327             external
# 35033   protein-coding gene
# 312736                  NaN

# %% [markdown]
# # To JSON Genetic document

# %%
df_final.fillna('',inplace=True)
# Out:
# /home/alvaro/anaconda3/envs/biobert/lib/python3.8/site-packages/pandas/core/frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df_final.sample(5)
# Out:
#        NCBI GeneID                                   Synonyms UniprotID  \
# 137378                                         [SLC2A4/iso:1]
# 281168    63361438                                     [tRNA]
# 497954     6750663                     [hypothetical protein]    B3RPC7
# 127440
# 119846              [chick-LOX, lysyl oxidase (chicken), LOX]    Q05063
#
#                   cross_reference  \
# 137378             [PR:000038909]
# 281168                         []
# 497954                         []
# 127440  [WormBase:WBGene00001784]
# 119846                [PR:Q05063]
#
#                                                      Term NCBItaxon_id  \
# 137378  solute carrier family 2, facilitated glucose t...
# 281168                                        J2B64_MGT15
# 497954                                   TRIADDRAFT_20443
# 127440                                      gst-36 (worm)         6239
# 119846                 protein-lysine 6-oxidase (chicken)         9031
#
#                  type
# 137378       sequence
# 281168
# 497954
# 127440       external
# 119846  organism gene

# %%
documents = []
num = 0;
for i in df_final.itertuples(index=False):
    gene_document = {}
    gene_document['term'] = i[4]
    gene_document['synonyms']= i[1]
    gene_document['uniprot_id']= i[2]
    gene_document['ncbi_gene_id']= i[0]
    gene_document['ncbi_taxon_id'] = i[5]
    gene_document['type']= i[6]
    gene_document['cross_reference']= i[3]   
    documents.append(gene_document) 
    num+=1
    if num%50000 == 0:
        print(num/len(df_final)*100,'% genes processed')
# Out:
# 5.539570816211444 % genes processed
# 11.079141632422887 % genes processed
# 16.61871244863433 % genes processed
# 22.158283264845775 % genes processed
# 27.697854081057216 % genes processed
# 33.23742489726866 % genes processed
# 38.7769957134801 % genes processed
# 44.31656652969155 % genes processed
# 49.85613734590299 % genes processed
# 55.39570816211443 % genes processed
# 60.93527897832588 % genes processed
# 66.47484979453732 % genes processed
# 72.01442061074876 % genes processed
# 77.5539914269602 % genes processed
# 83.09356224317165 % genes processed
# 88.6331330593831 % genes processed
# 94.17270387559454 % genes processed
# 99.71227469180597 % genes processed

# %%
len(documents)
# Out:
# 902597

# %%
documents[22222]
# Out:
# {'term': 'ABY20_GT18',
#  'synonyms': ['tRNA'],
#  'uniprot_id': '',
#  'ncbi_gene_id': '24418917',
#  'ncbi_taxon_id': '',
#  'type': '',
#  'cross_reference': []}

# %% [markdown]
# ## Save and load resultant document

# %%
with open('data/Genetic/genetic.json', 'w') as fout:
    json.dump(documents, fout)

# %%
with open('data/Genetic/genetic.json', 'r') as fout:
    genetic = json.loads(fout.read())
    print(len(genetic))
# Out:
# 902597
