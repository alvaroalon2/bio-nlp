# %%
import pandas as pd 
import numpy as np

# %%
def set_term(column1,column2):
    if not pd.isnull(column1):
        return column1
    if not pd.isnull(column2):
        return column2
    else:
        return np.nan

# %%
def set_term_list(column1,column2):
    if isinstance(column1,list):
        return column1
    if isinstance(column2,list):
        return column2
    else:
        return np.nan

# %%
def separate_id(column,idx):
    for i in column:
        if idx in i:
            column.remove(i)
            if idx == 'MESH' or idx == 'UMLS_CUI':
                return i.split(':')[-1]
            return i
    return np.nan

# %% [markdown]
# # Mesh Diseases

# %%
mesh_df = pd.read_csv('data/MESH_with_Semantic_types.csv')
mesh_df
# Out:
#          Class ID                               Preferred Label  \
# 0      C000624633  technetium 99m hydroxyethylene-diphosphonate
# 1         D014638                                     Vanadates
# 2         C031895                                 lead chromate
# 3         C403922                         bioactive glass S53P4
# 4         C494370                  calcium phosphate, monobasic
# ...           ...                                           ...
# 87074     D007231                               Infant, Newborn
# 87075     D015394                           Molecular Structure
# 87076     D005815                                  Genetic Code
# 87077     D020296                             Animals, Congenic
# 87078     D000060                           Accidents, Aviation
#
#                                                 Synonyms  \
# 0          99mTc-HDP|99mTc-hydroxyethylene-diphosphonate
# 1      Oxyvanadium|Sodium Vanadate|Vanadyl|Decavanada...
# 2       lead chromate, Pb(2+) (1:1)|lead chromate yellow
# 3                                    BAG S53P4|BAG-S53P4
# 4      calcium superphosphate|CaH4O8P2|monocalcium or...
# ...                                                  ...
# 87074  Newborn|Infants, Newborn|Newborn Infants|Neona...
# 87075  Structures, Molecular|Molecular Structures|Str...
# 87076         Code, Genetic|Genetic Codes|Codes, Genetic
# 87077  Animals, Coisogenic|Animal, Coisogenic|Coisoge...
# 87078  Aviation Accidents|Aviation Accident|Accident,...
#
#                                                      CUI                type
# 0                                               C0305030  Inorganic Chemical
# 1      C0030103|C0042308|C0037568|C0029366|C0042305|C...  Inorganic Chemical
# 2                                      C0064717|C0892125  Inorganic Chemical
# 3                                               C0912006  Inorganic Chemical
# 4                                               C1527438  Inorganic Chemical
# ...                                                  ...                 ...
# 87074                                           C0021289           Age Group
# 87075                                           C0026383  Molecular Sequence
# 87076                                           C0017380  Molecular Sequence
# 87077                                           C0600529          Vertebrate
# 87078                                           C0000928               Event
#
# [87079 rows x 5 columns]

# %% [markdown]
# ## Obtain just diseases or related Semantic types in Mesh

# %%
disease_types = ['Indicator, Reagent, or Diagnostic Aid',
 'Virus',
 'Bacterium',
 'Disease or Syndrome',
 'Body Part, Organ, or Organ Component',
 'Diagnostic Procedure',
 'Body Location or Region',
 'Congenital Abnormality',
 'Therapeutic or Preventive Procedure',
 'Pathologic Function',
 'Health Care Activity',
 'Injury or Poisoning',
 'Finding',
 'Neoplastic Process',
 'Mental or Behavioral Dysfunction',
 'Organ or Tissue Function',
 'Anatomical Abnormality',
 'Organism Function',
 'Natural Phenomenon or Process',
 'Cell Function',
 'Genetic Function',
 'Human-caused Phenomenon or Process',
 'Phenomenon or Process',
 'Physiologic Function',
 'Sign or Symptom',
 'Mental Process',
 'Cell or Molecular Dysfunction',
 'Acquired Abnormality',
 'Experimental Model of Disease',
 'Biologic Function',
 'Behavior',
 'Event'
 ]

# %%
disease_mesh_df = mesh_df[mesh_df.type.isin(disease_types)]
disease_mesh_df
# Out:
#          Class ID                                    Preferred Label  \
# 25512  C000623720  Autographa californica multiple nuclear polyhe...
# 25513  C000624051                           Tobacco necrosis virus A
# 25514  D000071819                                         Virophages
# 25515     D018059                                       Birnaviridae
# 25516  C000624066                   Sunflower chlorotic mottle virus
# ...           ...                                                ...
# 87061     D004195                             Disease Models, Animal
# 87062     D004681        Encephalomyelitis, Autoimmune, Experimental
# 87063     D011014                                          Pneumonia
# 87064     D007942                             Leukemia, Experimental
# 87078     D000060                                Accidents, Aviation
#
#                                                 Synonyms  \
# 25512  Trichoplusia ni multiple nucleopolyhedrovirus|...
# 25513                                                NaN
# 25514                                          Virophage
# 25515                                                NaN
# 25516                                                NaN
# ...                                                  ...
# 87061  Disease Model, Animal|Animal Disease Models|An...
# 87062  Allergic Encephalomyelitis, Experimental|Exper...
# 87063  Pneumonia, Lobar|Lobar Pneumonias|Lung Inflamm...
# 87064  Leukemia Models, Animal|Experimental Leukemia|...
# 87078  Aviation Accidents|Aviation Accident|Accident,...
#
#                                        CUI                           type
# 25512                             C1629281                          Virus
# 25513                             C1187077                          Virus
# 25514                             C4277719                          Virus
# 25515                             C0206505                          Virus
# 25516                             C1062582                          Virus
# ...                                    ...                            ...
# 87061                             C0012644  Experimental Model of Disease
# 87062                             C0014072  Experimental Model of Disease
# 87063  C0032300|C0032285|C3714636|C0887898  Experimental Model of Disease
# 87064                             C0023441  Experimental Model of Disease
# 87078                             C0000928                          Event
#
# [11094 rows x 5 columns]

# %%
print(disease_mesh_df.shape)
# Out:
# (11094, 5)

# %%
disease_mesh_df.rename(columns={'Class ID':'MeshID'},inplace=True)
# Out:
# /home/alvaro/anaconda3/envs/biobert/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# ### Save and load Mesh with diseases

# %%
disease_mesh_df.to_csv('data/Disease/MESH_diseases.csv',index=False)

# %%
disease_mesh_df = pd.read_csv('data/Disease/MESH_diseases.csv')
disease_mesh_df
# Out:
#            MeshID                                    Preferred Label  \
# 0      C000623720  Autographa californica multiple nuclear polyhe...
# 1      C000624051                           Tobacco necrosis virus A
# 2      D000071819                                         Virophages
# 3         D018059                                       Birnaviridae
# 4      C000624066                   Sunflower chlorotic mottle virus
# ...           ...                                                ...
# 11089     D004195                             Disease Models, Animal
# 11090     D004681        Encephalomyelitis, Autoimmune, Experimental
# 11091     D011014                                          Pneumonia
# 11092     D007942                             Leukemia, Experimental
# 11093     D000060                                Accidents, Aviation
#
#                                                 Synonyms  \
# 0      Trichoplusia ni multiple nucleopolyhedrovirus|...
# 1                                                    NaN
# 2                                              Virophage
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11089  Disease Model, Animal|Animal Disease Models|An...
# 11090  Allergic Encephalomyelitis, Experimental|Exper...
# 11091  Pneumonia, Lobar|Lobar Pneumonias|Lung Inflamm...
# 11092  Leukemia Models, Animal|Experimental Leukemia|...
# 11093  Aviation Accidents|Aviation Accident|Accident,...
#
#                                        CUI                           type
# 0                                 C1629281                          Virus
# 1                                 C1187077                          Virus
# 2                                 C4277719                          Virus
# 3                                 C0206505                          Virus
# 4                                 C1062582                          Virus
# ...                                    ...                            ...
# 11089                             C0012644  Experimental Model of Disease
# 11090                             C0014072  Experimental Model of Disease
# 11091  C0032300|C0032285|C3714636|C0887898  Experimental Model of Disease
# 11092                             C0023441  Experimental Model of Disease
# 11093                             C0000928                          Event
#
# [11094 rows x 5 columns]

# %% [markdown]
# # CTD

# %%
important_columns_chebi = {
    'DiseaseName',
    'DiseaseID',
    'AltDiseaseIDs',
    'Synonyms',
    'SlimMappings'
}

# %%
ctd_disease_df = pd.read_csv(
    "data/Disease/CTD_diseases.csv",      # relative python path to subdirectory
    sep=',',
    usecols=important_columns_chebi,
    dtype=str
)

print(ctd_disease_df.shape)
ctd_disease_df.head()
# Out:
# (13102, 5)
#                         DiseaseName     DiseaseID    AltDiseaseIDs  \
# 0   10p Deletion Syndrome (Partial)  MESH:C538288              NaN
# 1             13q deletion syndrome  MESH:C535484              NaN
# 2               15q24 Microdeletion  MESH:C579849  DO:DOID:0060395
# 3         16p11.2 Deletion Syndrome  MESH:C579850              NaN
# 4  17,20-Lyase Deficiency, Isolated  MESH:C567076              NaN
#
#                                             Synonyms  \
# 0  Chromosome 10, 10p- Partial|Chromosome 10, mon...
# 1  Chromosome 13q deletion|Chromosome 13q deletio...
# 2  15q24 Deletion|15q24 Microdeletion Syndrome|In...
# 3                                                NaN
# 4  17-Alpha-Hydroxylase-17,20-Lyase Deficiency, C...
#
#                                         SlimMappings
# 0  Congenital abnormality|Genetic disease (inborn...
# 1  Congenital abnormality|Genetic disease (inborn...
# 2  Congenital abnormality|Genetic disease (inborn...
# 3  Congenital abnormality|Genetic disease (inborn...
# 4  Congenital abnormality|Endocrine system diseas...

# %% [markdown]
# ## Split mixed IDs in Mesh ID and others

# %%
ctd_disease_df['MeshID'] = ctd_disease_df['DiseaseID'].apply(lambda x: x if x.startswith('MESH') else '')

# %%
ctd_disease_df['Cross_reference'] = ctd_disease_df['DiseaseID'].apply(lambda x: x if not x.startswith('MESH') else '')

# %%
len(ctd_disease_df[ctd_disease_df['Cross_reference']!=''])
# Out:
# 1584

# %%
ctd_disease_df['MeshID'] = ctd_disease_df['MeshID'].apply(lambda x: x.split(':')[-1])

# %%
ctd_disease_df
# Out:
#                             DiseaseName     DiseaseID  \
# 0       10p Deletion Syndrome (Partial)  MESH:C538288
# 1                 13q deletion syndrome  MESH:C535484
# 2                   15q24 Microdeletion  MESH:C579849
# 3             16p11.2 Deletion Syndrome  MESH:C579850
# 4      17,20-Lyase Deficiency, Isolated  MESH:C567076
# ...                                 ...           ...
# 13097   Zunich neuroectodermal syndrome  MESH:C536729
# 13098                   Zuska's Disease  MESH:C536730
# 13099                     Zygodactyly 1  MESH:C565223
# 13100               Zygomatic Fractures  MESH:D015051
# 13101                       Zygomycosis  MESH:D020096
#
#                      AltDiseaseIDs  \
# 0                              NaN
# 1                              NaN
# 2                  DO:DOID:0060395
# 3                              NaN
# 4                              NaN
# ...                            ...
# 13097  DO:DOID:0112152|OMIM:280000
# 13098                          NaN
# 13099                  OMIM:609815
# 13100                          NaN
# 13101                          NaN
#
#                                                 Synonyms  \
# 0      Chromosome 10, 10p- Partial|Chromosome 10, mon...
# 1      Chromosome 13q deletion|Chromosome 13q deletio...
# 2      15q24 Deletion|15q24 Microdeletion Syndrome|In...
# 3                                                    NaN
# 4      17-Alpha-Hydroxylase-17,20-Lyase Deficiency, C...
# ...                                                  ...
# 13097  CHIME|CHIME syndrome|COLOBOMA, CONGENITAL HEAR...
# 13098  Lactation and squamous metaplasia of lactifero...
# 13099                                                ZD1
# 13100  Fractures, Zygomatic|Fracture, Zygomatic|Zygom...
# 13101  Entomophthoramycoses|Entomophthoramycosis|Phyc...
#
#                                             SlimMappings   MeshID  \
# 0      Congenital abnormality|Genetic disease (inborn...  C538288
# 1      Congenital abnormality|Genetic disease (inborn...  C535484
# 2      Congenital abnormality|Genetic disease (inborn...  C579849
# 3      Congenital abnormality|Genetic disease (inborn...  C579850
# 4      Congenital abnormality|Endocrine system diseas...  C567076
# ...                                                  ...      ...
# 13097  Cardiovascular disease|Congenital abnormality|...  C536729
# 13098  Pathology (anatomical condition)|Pathology (pr...  C536730
# 13099     Congenital abnormality|Musculoskeletal disease  C565223
# 13100         Nervous system disease|Wounds and injuries  D015051
# 13101                     Bacterial infection or mycosis  D020096
#
#       Cross_reference
# 0
# 1
# 2
# 3
# 4
# ...               ...
# 13097
# 13098
# 13099
# 13100
# 13101
#
# [13102 rows x 7 columns]

# %% [markdown]
# # Merge MESH and CTD vocabs

# %%
df_merge = disease_mesh_df.merge(ctd_disease_df,on='MeshID',how='outer')

# %%
df_merge
# Out:
#            MeshID                                    Preferred Label  \
# 0      C000623720  Autographa californica multiple nuclear polyhe...
# 1      C000624051                           Tobacco necrosis virus A
# 2      D000071819                                         Virophages
# 3         D018059                                       Birnaviridae
# 4      C000624066                   Sunflower chlorotic mottle virus
# ...           ...                                                ...
# 20842     C536728                                                NaN
# 20843     D031368                                                NaN
# 20844     C536729                                                NaN
# 20845     C565223                                                NaN
# 20846     D020096                                                NaN
#
#                                               Synonyms_x       CUI   type  \
# 0      Trichoplusia ni multiple nucleopolyhedrovirus|...  C1629281  Virus
# 1                                                    NaN  C1187077  Virus
# 2                                              Virophage  C4277719  Virus
# 3                                                    NaN  C0206505  Virus
# 4                                                    NaN  C1062582  Virus
# ...                                                  ...       ...    ...
# 20842                                                NaN       NaN    NaN
# 20843                                                NaN       NaN    NaN
# 20844                                                NaN       NaN    NaN
# 20845                                                NaN       NaN    NaN
# 20846                                                NaN       NaN    NaN
#
#                            DiseaseName     DiseaseID  \
# 0                                  NaN           NaN
# 1                                  NaN           NaN
# 2                                  NaN           NaN
# 3                                  NaN           NaN
# 4                                  NaN           NaN
# ...                                ...           ...
# 20842   Zori Stalker Williams syndrome  MESH:C536728
# 20843              Zoster Sine Herpete  MESH:D031368
# 20844  Zunich neuroectodermal syndrome  MESH:C536729
# 20845                    Zygodactyly 1  MESH:C565223
# 20846                      Zygomycosis  MESH:D020096
#
#                      AltDiseaseIDs  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 20842                          NaN
# 20843                          NaN
# 20844  DO:DOID:0112152|OMIM:280000
# 20845                  OMIM:609815
# 20846                          NaN
#
#                                               Synonyms_y  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20842  Familial short stature, developmental delay, p...
# 20843                              Zoster Sine Eruptione
# 20844  CHIME|CHIME syndrome|COLOBOMA, CONGENITAL HEAR...
# 20845                                                ZD1
# 20846  Entomophthoramycoses|Entomophthoramycosis|Phyc...
#
#                                             SlimMappings Cross_reference
# 0                                                    NaN             NaN
# 1                                                    NaN             NaN
# 2                                                    NaN             NaN
# 3                                                    NaN             NaN
# 4                                                    NaN             NaN
# ...                                                  ...             ...
# 20842  Congenital abnormality|Musculoskeletal disease...
# 20843                                      Viral disease
# 20844  Cardiovascular disease|Congenital abnormality|...
# 20845     Congenital abnormality|Musculoskeletal disease
# 20846                     Bacterial infection or mycosis
#
# [20847 rows x 11 columns]

# %% [markdown]
# ## Clean resultant DataFrame

# %%
df_merge['Term'] = df_merge.apply(lambda x: set_term(x['Preferred Label'],x.DiseaseName),axis=1)

# %%
df_merge.drop(['DiseaseID','DiseaseName','Preferred Label'],axis=1, inplace=True)

# %%
df_merge['Synonyms'] = df_merge.apply(lambda x: set_term(x.Synonyms_x,x.Synonyms_y),axis=1)

# %%
df_merge.drop(['Synonyms_x','Synonyms_y'],axis=1, inplace=True)

# %%
df_merge['Cross_reference'] = df_merge.apply(lambda x: set_term(x.Cross_reference,x.AltDiseaseIDs),axis=1)

# %%
len(df_merge[df_merge['Cross_reference'].str.len()>1])
# Out:
# 1584

# %%
df_merge.drop(['AltDiseaseIDs'],axis=1, inplace=True)

# %%
df_merge['type'] = df_merge.apply(lambda x: set_term(x.type,x.SlimMappings),axis=1)

# %%
df_merge.drop(['SlimMappings'],axis=1, inplace=True)

# %%
df_merge['type'] = df_merge['type'].apply(lambda x: x.split('|')[-1] if isinstance(x,str) else np.nan)

# %%
df_merge
# Out:
#            MeshID       CUI                              type Cross_reference  \
# 0      C000623720  C1629281                             Virus             NaN
# 1      C000624051  C1187077                             Virus             NaN
# 2      D000071819  C4277719                             Virus             NaN
# 3         D018059  C0206505                             Virus             NaN
# 4      C000624066  C1062582                             Virus             NaN
# ...           ...       ...                               ...             ...
# 20842     C536728       NaN  Pathology (anatomical condition)
# 20843     D031368       NaN                     Viral disease
# 20844     C536729       NaN                      Skin disease
# 20845     C565223       NaN           Musculoskeletal disease
# 20846     D020096       NaN    Bacterial infection or mycosis
#
#                                                     Term  \
# 0      Autographa californica multiple nuclear polyhe...
# 1                               Tobacco necrosis virus A
# 2                                             Virophages
# 3                                           Birnaviridae
# 4                       Sunflower chlorotic mottle virus
# ...                                                  ...
# 20842                     Zori Stalker Williams syndrome
# 20843                                Zoster Sine Herpete
# 20844                    Zunich neuroectodermal syndrome
# 20845                                      Zygodactyly 1
# 20846                                        Zygomycosis
#
#                                                 Synonyms
# 0      Trichoplusia ni multiple nucleopolyhedrovirus|...
# 1                                                    NaN
# 2                                              Virophage
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20842  Familial short stature, developmental delay, p...
# 20843                              Zoster Sine Eruptione
# 20844  CHIME|CHIME syndrome|COLOBOMA, CONGENITAL HEAR...
# 20845                                                ZD1
# 20846  Entomophthoramycoses|Entomophthoramycosis|Phyc...
#
# [20847 rows x 6 columns]

# %% [markdown]
# # DOID

# %%
important_columns_doid = {
    'Class ID',
    'Preferred Label',
    'Synonyms',
    'Obsolete',
    'database_cross_reference',
    'id'
}

# %%
doid_df = pd.read_csv(
    "data/Disease/DOID.csv",      # relative python path to subdirectory
    sep=',',
    usecols=important_columns_doid,
    dtype=str
)

print(doid_df.shape)
doid_df.head()
# Out:
# (17454, 6)
#                                     Class ID  \
# 0   http://purl.obolibrary.org/obo/DOID_8986
# 1   http://purl.obolibrary.org/obo/DOID_7233
# 2  http://purl.obolibrary.org/obo/HP_0011138
# 3   http://purl.obolibrary.org/obo/DOID_5236
# 4   http://purl.obolibrary.org/obo/DOID_1934
#
#                                     Preferred Label  \
# 0                                        narcolepsy
# 1  adult central nervous system embryonal carcinoma
# 2             Abnormality of skin adnexa morphology
# 3                            subungual glomus tumor
# 4                                        dysostosis
#
#                                             Synonyms Obsolete  \
# 0     Narcolepsy, without cataplexy|paroxysmal sleep    false
# 1  Embryonal carcinoma of the adult central nervo...    false
# 2                                                NaN    false
# 3  Subungual Glomus tumour|Subungual Glomus tumor...    false
# 4                                                NaN    false
#
#                             database_cross_reference          id
# 0  EFO:0000614|MESH:D009290|GARD:7162|ICD10CM:G47...   DOID:8986
# 1                        NCI:C5790|UMLS_CUI:C1370503   DOID:7233
# 2                                                NaN  HP:0011138
# 3  UMLS_CUI:C1304510|NCI:C36079|SNOMEDCT_US_2020_...   DOID:5236
# 4  SNOMEDCT_US_2020_09_01:109420003|NCI:C34560|ME...   DOID:1934

# %% [markdown]
# ## Clean DataFrame

# %%
doid_df = doid_df[doid_df['Obsolete']=='false']
print(doid_df.shape)
# Out:
# (15002, 6)

# %%
doid_df = doid_df.drop(['Class ID','Obsolete'],axis=1)

# %%
doid_df['database_cross_reference'] = doid_df['database_cross_reference'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else np.nan)

# %%
doid_df
# Out:
#                                         Preferred Label  \
# 0                                            narcolepsy
# 1      adult central nervous system embryonal carcinoma
# 2                 Abnormality of skin adnexa morphology
# 3                                subungual glomus tumor
# 4                                            dysostosis
# ...                                                 ...
# 17448                                         keratosis
# 17450                           coloboma of optic nerve
# 17451                      acute gonococcal salpingitis
# 17452                      atrial heart septal defect 4
# 17453                             acrocallosal syndrome
#
#                                                 Synonyms  \
# 0         Narcolepsy, without cataplexy|paroxysmal sleep
# 1      Embryonal carcinoma of the adult central nervo...
# 2                                                    NaN
# 3      Subungual Glomus tumour|Subungual Glomus tumor...
# 4                                                    NaN
# ...                                                  ...
# 17448                                                NaN
# 17450      Coloboma of optic disc|Morning glory syndrome
# 17451         Gonococcal salpingitis, specified as acute
# 17452                        ASD4|atrial septal defect 4
# 17453  Schinzel syndrome 1|SCHINZEL ACROCALLOSAL SYND...
#
#                                 database_cross_reference            id
# 0      [EFO:0000614, MESH:D009290, GARD:7162, ICD10CM...     DOID:8986
# 1                         [NCI:C5790, UMLS_CUI:C1370503]     DOID:7233
# 2                                                    NaN    HP:0011138
# 3      [UMLS_CUI:C1304510, NCI:C36079, SNOMEDCT_US_20...     DOID:5236
# 4      [SNOMEDCT_US_2020_09_01:109420003, NCI:C34560,...     DOID:1934
# ...                                                  ...           ...
# 17448  [UMLS_CUI:C0022593, MESH:D007642, SNOMEDCT_US_...      DOID:161
# 17450  [OMIM:120430, ICD9CM:377.23, GARD:13354, GARD:...    DOID:11975
# 17451  [ICD9CM:098.17, SNOMEDCT_US_2020_09_01:4537700...    DOID:13942
# 17452                       [ICD10CM:Q21.1, OMIM:611363]  DOID:0110109
# 17453  [GARD:5721, OMIM:200990, MESH:D055673, UMLS_CU...     DOID:9250
#
# [15002 rows x 4 columns]

# %% [markdown]
# ## Extract Mesh and CUI IDs

# %%
doid_df['MeshID'] = doid_df.apply(lambda x: separate_id(x.database_cross_reference,'MESH') if isinstance(x.database_cross_reference,list) else np.nan,axis=1)

# %%
doid_df['CUI'] = doid_df.apply(lambda x: separate_id(x.database_cross_reference,'UMLS_CUI') if isinstance(x.database_cross_reference,list) else np.nan,axis=1)

# %%
doid_df
# Out:
#                                         Preferred Label  \
# 0                                            narcolepsy
# 1      adult central nervous system embryonal carcinoma
# 2                 Abnormality of skin adnexa morphology
# 3                                subungual glomus tumor
# 4                                            dysostosis
# ...                                                 ...
# 17448                                         keratosis
# 17450                           coloboma of optic nerve
# 17451                      acute gonococcal salpingitis
# 17452                      atrial heart septal defect 4
# 17453                             acrocallosal syndrome
#
#                                                 Synonyms  \
# 0         Narcolepsy, without cataplexy|paroxysmal sleep
# 1      Embryonal carcinoma of the adult central nervo...
# 2                                                    NaN
# 3      Subungual Glomus tumour|Subungual Glomus tumor...
# 4                                                    NaN
# ...                                                  ...
# 17448                                                NaN
# 17450      Coloboma of optic disc|Morning glory syndrome
# 17451         Gonococcal salpingitis, specified as acute
# 17452                        ASD4|atrial septal defect 4
# 17453  Schinzel syndrome 1|SCHINZEL ACROCALLOSAL SYND...
#
#                                 database_cross_reference            id  \
# 0      [EFO:0000614, GARD:7162, ICD10CM:G47.41, OMIM:...     DOID:8986
# 1                                            [NCI:C5790]     DOID:7233
# 2                                                    NaN    HP:0011138
# 3         [NCI:C36079, SNOMEDCT_US_2020_09_01:403973004]     DOID:5236
# 4         [SNOMEDCT_US_2020_09_01:109420003, NCI:C34560]     DOID:1934
# ...                                                  ...           ...
# 17448     [SNOMEDCT_US_2020_09_01:254666005, NCI:C34747]      DOID:161
# 17450  [OMIM:120430, ICD9CM:377.23, GARD:13354, GARD:...    DOID:11975
# 17451   [ICD9CM:098.17, SNOMEDCT_US_2020_09_01:45377007]    DOID:13942
# 17452                       [ICD10CM:Q21.1, OMIM:611363]  DOID:0110109
# 17453  [GARD:5721, OMIM:200990, NCI:C84531, SNOMEDCT_...     DOID:9250
#
#         MeshID       CUI
# 0      D009290  C0027404
# 1          NaN  C1370503
# 2          NaN       NaN
# 3          NaN  C1304510
# 4      D004413  C0013393
# ...        ...       ...
# 17448  D007642  C0022593
# 17450  C535970  C0155299
# 17451      NaN  C0275654
# 17452      NaN       NaN
# 17453  D055673  C0796147
#
# [15002 rows x 6 columns]

# %% [markdown]
# # Merge DOID with CTD and MESH

# %%
df1 = df_merge.merge(doid_df, on='MeshID', how='outer')

# %%
df1
# Out:
#            MeshID     CUI_x   type Cross_reference  \
# 0      C000623720  C1629281  Virus             NaN
# 1      C000624051  C1187077  Virus             NaN
# 2      D000071819  C4277719  Virus             NaN
# 3         D018059  C0206505  Virus             NaN
# 4      C000624066  C1062582  Virus             NaN
# ...           ...       ...    ...             ...
# 32688     C537935       NaN    NaN             NaN
# 32689     D003861       NaN    NaN             NaN
# 32690     D003863       NaN    NaN             NaN
# 32691     C537330       NaN    NaN             NaN
# 32692     D001787       NaN    NaN             NaN
#
#                                                     Term  \
# 0      Autographa californica multiple nuclear polyhe...
# 1                               Tobacco necrosis virus A
# 2                                             Virophages
# 3                                           Birnaviridae
# 4                       Sunflower chlorotic mottle virus
# ...                                                  ...
# 32688                                                NaN
# 32689                                                NaN
# 32690                                                NaN
# 32691                                                NaN
# 32692                                                NaN
#
#                                               Synonyms_x  \
# 0      Trichoplusia ni multiple nucleopolyhedrovirus|...
# 1                                                    NaN
# 2                                              Virophage
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32688                                                NaN
# 32689                                                NaN
# 32690                                                NaN
# 32691                                                NaN
# 32692                                                NaN
#
#                    Preferred Label  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 32688    lattice corneal dystrophy
# 32689   depersonalization disorder
# 32690            mental depression
# 32691   Shwachman-Diamond syndrome
# 32692  blood group incompatibility
#
#                                               Synonyms_y  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32688          familial amyloid neuropathy, Finnish type
# 32689                             Neurotic derealization
# 32690                                                NaN
# 32691  Shwachman-Diamond type metaphyseal dysplasia|p...
# 32692                                                NaN
#
#                                 database_cross_reference            id  \
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 32688                                      [OMIM:122200]     DOID:8943
# 32689  [NCI:C94331, SNOMEDCT_US_2020_09_01:70764005, ...    DOID:11038
# 32690  [ICD10CM:F32.9, SNOMEDCT_US_2020_09_01:4100600...     DOID:1596
# 32691            [OMIM:260400, GARD:4863, ICD10CM:D61.0]  DOID:0060479
# 32692                                                 []     DOID:4176
#
#           CUI_y
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 32688       NaN
# 32689  C0683416
# 32690  C0011570
# 32691       NaN
# 32692  C0005806
#
# [32693 rows x 11 columns]

# %% [markdown]
# ## Cleaning resultant merge

# %%
len(df1[df1['CUI_x'].str.len()>0])
# Out:
# 11191

# %%
len(df1[df1['CUI_y'].str.len()>0])
# Out:
# 6260

# %%
df1['CUI'] = df1.apply(lambda x: set_term(x.CUI_x,x.CUI_y),axis=1)

# %%
len(df1[df1['CUI'].str.len()>0])
# Out:
# 16491

# %%
df1['Synonyms_x'].fillna('',inplace=True)
df1['Synonyms_y'].fillna('',inplace=True)

# %%
df1['Synonyms_x'] = df1['Synonyms_x'].apply(lambda x: [i for i in x.split('|')])

# %%
df1['Synonyms_y'] = df1['Synonyms_y'].apply(lambda x: [i for i in x.split('|')])

# %%
df1['Synonyms'] = df1.apply(lambda x: x.Synonyms_x + x.Synonyms_y if len(x.Synonyms_x)>1 or len(x.Synonyms_y)>1 else np.nan,axis=1 )

# %%
df1['Synonyms'] = df1['Synonyms'].apply(lambda x: [string for string in x if string != ""] if isinstance(x,list) else np.nan )

# %%
df1.sample(5)
# Out:
#            MeshID     CUI_x                                   type  \
# 14759  C000711430       NaN                          Viral disease
# 3766   D000069996  C0317593                              Bacterium
# 8817      C024945  C0073569  Indicator, Reagent, or Diagnostic Aid
# 7669      C537082  C1862172                    Disease or Syndrome
# 5461   C000647002  C2989361                              Bacterium
#
#       Cross_reference                       Term  \
# 14759                   COVID-19 stress syndrome
# 3766              NaN   Lactobacillus salivarius
# 8817              NaN      Ronpacon Cerebral 280
# 7669                    Weismann Netter syndrome
# 5461              NaN  Jeotgalibacillus salarius
#
#                                               Synonyms_x Preferred Label  \
# 14759   [COVID19 stress syndrome, COVID stress syndrome]             NaN
# 3766                                                  []             NaN
# 8817                                                  []             NaN
# 7669   [Toxopachyoteose diaphysaire tibio peroniere, ...             NaN
# 5461                                                  []             NaN
#
#       Synonyms_y database_cross_reference   id CUI_y       CUI  \
# 14759         []                      NaN  NaN   NaN       NaN
# 3766          []                      NaN  NaN   NaN  C0317593
# 8817          []                      NaN  NaN   NaN  C0073569
# 7669          []                      NaN  NaN   NaN  C1862172
# 5461          []                      NaN  NaN   NaN  C2989361
#
#                                                 Synonyms
# 14759   [COVID19 stress syndrome, COVID stress syndrome]
# 3766                                                 NaN
# 8817                                                 NaN
# 7669   [Toxopachyoteose diaphysaire tibio peroniere, ...
# 5461                                                 NaN

# %%
df1['Term'] = df1.apply(lambda x: set_term(x.Term,x['Preferred Label']),axis=1)

# %%
df1
# Out:
#            MeshID     CUI_x   type Cross_reference  \
# 0      C000623720  C1629281  Virus             NaN
# 1      C000624051  C1187077  Virus             NaN
# 2      D000071819  C4277719  Virus             NaN
# 3         D018059  C0206505  Virus             NaN
# 4      C000624066  C1062582  Virus             NaN
# ...           ...       ...    ...             ...
# 32688     C537935       NaN    NaN             NaN
# 32689     D003861       NaN    NaN             NaN
# 32690     D003863       NaN    NaN             NaN
# 32691     C537330       NaN    NaN             NaN
# 32692     D001787       NaN    NaN             NaN
#
#                                                     Term  \
# 0      Autographa californica multiple nuclear polyhe...
# 1                               Tobacco necrosis virus A
# 2                                             Virophages
# 3                                           Birnaviridae
# 4                       Sunflower chlorotic mottle virus
# ...                                                  ...
# 32688                          lattice corneal dystrophy
# 32689                         depersonalization disorder
# 32690                                  mental depression
# 32691                         Shwachman-Diamond syndrome
# 32692                        blood group incompatibility
#
#                                               Synonyms_x  \
# 0      [Trichoplusia ni multiple nucleopolyhedrovirus...
# 1                                                     []
# 2                                            [Virophage]
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 32688                                                 []
# 32689                                                 []
# 32690                                                 []
# 32691                                                 []
# 32692                                                 []
#
#                    Preferred Label  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 32688    lattice corneal dystrophy
# 32689   depersonalization disorder
# 32690            mental depression
# 32691   Shwachman-Diamond syndrome
# 32692  blood group incompatibility
#
#                                               Synonyms_y  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 32688        [familial amyloid neuropathy, Finnish type]
# 32689                           [Neurotic derealization]
# 32690                                                 []
# 32691  [Shwachman-Diamond type metaphyseal dysplasia,...
# 32692                                                 []
#
#                                 database_cross_reference            id  \
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 32688                                      [OMIM:122200]     DOID:8943
# 32689  [NCI:C94331, SNOMEDCT_US_2020_09_01:70764005, ...    DOID:11038
# 32690  [ICD10CM:F32.9, SNOMEDCT_US_2020_09_01:4100600...     DOID:1596
# 32691            [OMIM:260400, GARD:4863, ICD10CM:D61.0]  DOID:0060479
# 32692                                                 []     DOID:4176
#
#           CUI_y       CUI                                           Synonyms
# 0           NaN  C1629281  [Trichoplusia ni multiple nucleopolyhedrovirus...
# 1           NaN  C1187077                                                NaN
# 2           NaN  C4277719                                                NaN
# 3           NaN  C0206505                                                NaN
# 4           NaN  C1062582                                                NaN
# ...         ...       ...                                                ...
# 32688       NaN       NaN                                                NaN
# 32689  C0683416  C0683416                                                NaN
# 32690  C0011570  C0011570                                                NaN
# 32691       NaN       NaN  [Shwachman-Diamond type metaphyseal dysplasia,...
# 32692  C0005806  C0005806                                                NaN
#
# [32693 rows x 13 columns]

# %%
len(df1[df1['Term'].str.len()>0])
# Out:
# 32693

# %%
df1.drop(['CUI_x','Synonyms_x','Preferred Label','Synonyms_y','CUI_y'],axis=1,inplace=True)

# %%
df1
# Out:
#            MeshID   type Cross_reference  \
# 0      C000623720  Virus             NaN
# 1      C000624051  Virus             NaN
# 2      D000071819  Virus             NaN
# 3         D018059  Virus             NaN
# 4      C000624066  Virus             NaN
# ...           ...    ...             ...
# 32688     C537935    NaN             NaN
# 32689     D003861    NaN             NaN
# 32690     D003863    NaN             NaN
# 32691     C537330    NaN             NaN
# 32692     D001787    NaN             NaN
#
#                                                     Term  \
# 0      Autographa californica multiple nuclear polyhe...
# 1                               Tobacco necrosis virus A
# 2                                             Virophages
# 3                                           Birnaviridae
# 4                       Sunflower chlorotic mottle virus
# ...                                                  ...
# 32688                          lattice corneal dystrophy
# 32689                         depersonalization disorder
# 32690                                  mental depression
# 32691                         Shwachman-Diamond syndrome
# 32692                        blood group incompatibility
#
#                                 database_cross_reference            id  \
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 32688                                      [OMIM:122200]     DOID:8943
# 32689  [NCI:C94331, SNOMEDCT_US_2020_09_01:70764005, ...    DOID:11038
# 32690  [ICD10CM:F32.9, SNOMEDCT_US_2020_09_01:4100600...     DOID:1596
# 32691            [OMIM:260400, GARD:4863, ICD10CM:D61.0]  DOID:0060479
# 32692                                                 []     DOID:4176
#
#             CUI                                           Synonyms
# 0      C1629281  [Trichoplusia ni multiple nucleopolyhedrovirus...
# 1      C1187077                                                NaN
# 2      C4277719                                                NaN
# 3      C0206505                                                NaN
# 4      C1062582                                                NaN
# ...         ...                                                ...
# 32688       NaN                                                NaN
# 32689  C0683416                                                NaN
# 32690  C0011570                                                NaN
# 32691       NaN  [Shwachman-Diamond type metaphyseal dysplasia,...
# 32692  C0005806                                                NaN
#
# [32693 rows x 8 columns]

# %%
len(df1[df1['type'].str.len()>0])
# Out:
# 21148

# %%
df1['Cross_reference'].fillna('',inplace=True)
df1['database_cross_reference'].fillna('',inplace=True)
df1['id'].fillna('',inplace=True)

# %%
df1['database_cross_reference'] = df1['database_cross_reference'].apply(lambda x: [''] if x =='' else x)

# %%
df1['Cross_reference'] = df1.apply(lambda x: [x.Cross_reference] + x.database_cross_reference + [x.id] if len(x.Cross_reference)>0 or len(x.database_cross_reference)>0 or len(x.id)>0 else np.nan,axis=1 )

# %%
df1['Cross_reference'] = df1['Cross_reference'].apply(lambda x: [string for string in x if string != ""] if isinstance(x,list) else np.nan )

# %%
df1['Cross_reference'] = df1['Cross_reference'].apply(lambda x: np.nan if x ==[] else x)

# %%
df1.drop(['database_cross_reference','id'],axis=1,inplace=True)

# %%
df1.sample(10)
# Out:
#            MeshID                       type  \
# 4401   C000648838                  Bacterium
# 18432     D018330                     Cancer
# 598    C000647908                  Bacterium
# 28603         NaN                        NaN
# 16295     D054144     Cardiovascular disease
# 24286         NaN                        NaN
# 29621         NaN                        NaN
# 16774     C565475  Urogenital disease (male)
# 18164     D020190     Nervous system disease
# 20518     C536508    Musculoskeletal disease
#
#                                          Cross_reference  \
# 4401                                                 NaN
# 18432                                                NaN
# 598                                                  NaN
# 28603                            [NCI:C39821, DOID:7600]
# 16295  [SNOMEDCT_US_2020_09_01:418304008, ICD10CM:I50...
# 24286                                     [DOID:0060525]
# 29621         [OMIM:601317, ICD10CM:H90.3, DOID:0110543]
# 16774                                                NaN
# 18164  [NCI:C84796, GARD:6808, OMIM:254770, ORDO:307,...
# 20518                                                NaN
#
#                                                     Term       CUI  \
# 4401                        Fervidobacterium gondwanense  C1011640
# 18432                                 Nevus, Intradermal       NaN
# 598                            Acinetobacter courvalinii  C1679926
# 28603  infiltrating bladder lymphoepithelioma-like ca...  C1512736
# 16295                           Heart Failure, Diastolic  C1135196
# 24286                               brown shrimp allergy       NaN
# 29621        autosomal dominant nonsyndromic deafness 11       NaN
# 16774  Hypouricemia, Hypercalcinuria, and Decreased B...       NaN
# 18164                       Myoclonic Epilepsy, Juvenile  C0270853
# 20518                    Thanatophoric dysplasia, type 2       NaN
#
#                                                 Synonyms
# 4401                                                 NaN
# 18432  [Intradermal Nevi, Intradermal Nevus, Nevi, In...
# 598                                                  NaN
# 28603                                                NaN
# 16295  [Diastolic Heart Failure, Diastolic Heart Fail...
# 24286                                                NaN
# 29621           [DFNA11, autosomal dominant deafness 11]
# 16774                                                NaN
# 18164  [Adolescent Myoclonic Epilepsy, ECA4, INCLUDED...
# 20518  [Cloverleaf skull with thanatophoric dwarfism,...

# %% [markdown]
# ## Save and load Merged Diseases

# %%
df1.to_csv('data/Disease/diseases.csv',index=False)

# %%
df1 = pd.read_csv('data/Disease/diseases.csv')

# %%
df1
# Out:
#            MeshID   type                                    Cross_reference  \
# 0      C000623720  Virus                                                NaN
# 1      C000624051  Virus                                                NaN
# 2      D000071819  Virus                                                NaN
# 3         D018059  Virus                                                NaN
# 4      C000624066  Virus                                                NaN
# ...           ...    ...                                                ...
# 32688     C537935    NaN                       ['OMIM:122200', 'DOID:8943']
# 32689     D003861    NaN  ['NCI:C94331', 'SNOMEDCT_US_2020_09_01:7076400...
# 32690     D003863    NaN  ['ICD10CM:F32.9', 'SNOMEDCT_US_2020_09_01:4100...
# 32691     C537330    NaN  ['OMIM:260400', 'GARD:4863', 'ICD10CM:D61.0', ...
# 32692     D001787    NaN                                      ['DOID:4176']
#
#                                                     Term       CUI  \
# 0      Autographa californica multiple nuclear polyhe...  C1629281
# 1                               Tobacco necrosis virus A  C1187077
# 2                                             Virophages  C4277719
# 3                                           Birnaviridae  C0206505
# 4                       Sunflower chlorotic mottle virus  C1062582
# ...                                                  ...       ...
# 32688                          lattice corneal dystrophy       NaN
# 32689                         depersonalization disorder  C0683416
# 32690                                  mental depression  C0011570
# 32691                         Shwachman-Diamond syndrome       NaN
# 32692                        blood group incompatibility  C0005806
#
#                                                 Synonyms
# 0      ['Trichoplusia ni multiple nucleopolyhedroviru...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32688                                                NaN
# 32689                                                NaN
# 32690                                                NaN
# 32691  ['Shwachman-Diamond type metaphyseal dysplasia...
# 32692                                                NaN
#
# [32693 rows x 6 columns]

# %% [markdown]
# # ICD 10 Ontology

# %%
important_columns_icd = ['Class ID','Preferred Label','Synonyms','Obsolete','CUI','Semantic Types']

# %%
icd_df = pd.read_csv(
    "data/Disease/ICD10CM.csv",      # relative python path to subdirectory
    sep=',',
    usecols=important_columns_icd,
    dtype=str
)

print(icd_df.shape)
icd_df.head()
# Out:
# (95798, 6)
#                                             Class ID  \
# 0  http://purl.bioontology.org/ontology/ICD10CM/T...
# 1  http://purl.bioontology.org/ontology/ICD10CM/T...
# 2  http://purl.bioontology.org/ontology/ICD10CM/J...
# 3  http://purl.bioontology.org/ontology/ICD10CM/G...
# 4  http://purl.bioontology.org/ontology/ICD10CM/S...
#
#                                      Preferred Label  \
# 0  Underdosing of stimulant laxatives, subsequent...
# 1  Underdosing of histamine H2-receptor blockers,...
# 2              Acute and chronic respiratory failure
# 3                       Neuromyelitis optica [Devic]
# 4  Dislocation of interphalangeal joint of unspec...
#
#                                Synonyms Obsolete                CUI  \
# 0                                   NaN    false           C2879738
# 1                                   NaN    false           C2879688
# 2  Acute on chronic respiratory failure    false           C0264491
# 3       Demyelination in optic neuritis    false  C0027873|C1395170
# 4                                   NaN    false           C2868672
#
#                                   Semantic Types
# 0  http://purl.bioontology.org/ontology/STY/T037
# 1  http://purl.bioontology.org/ontology/STY/T037
# 2  http://purl.bioontology.org/ontology/STY/T047
# 3  http://purl.bioontology.org/ontology/STY/T047
# 4  http://purl.bioontology.org/ontology/STY/T037

# %%
icd_df = icd_df[icd_df['Obsolete']=='false']
icd_df.drop('Obsolete',inplace=True,axis=1)
print(icd_df.shape)
# Out:
# (95798, 5)

# %%
icd_df['ICD_id'] = icd_df['Class ID'].apply(lambda x: x.split('/')[-1])
icd_df.drop('Class ID',inplace=True,axis=1)

# %%
icd_df['Semantic Types'] = icd_df['Semantic Types'].apply(lambda x: x.split('/')[-1] if isinstance(x,str) else np.nan)

# %%
icd_df
# Out:
#                                          Preferred Label  \
# 0      Underdosing of stimulant laxatives, subsequent...
# 1      Underdosing of histamine H2-receptor blockers,...
# 2                  Acute and chronic respiratory failure
# 3                           Neuromyelitis optica [Devic]
# 4      Dislocation of interphalangeal joint of unspec...
# ...                                                  ...
# 95793  Incomplete lesion of L1 level of lumbar spinal...
# 95794  Nondisplaced fracture of neck of scapula, righ...
# 95795         Poisoning by other viral vaccines, assault
# 95796  Other shellfish poisoning, undetermined, subse...
# 95797  Other fall on same level due to collision with...
#
#                                               Synonyms                CUI  \
# 0                                                  NaN           C2879738
# 1                                                  NaN           C2879688
# 2                 Acute on chronic respiratory failure           C0264491
# 3                      Demyelination in optic neuritis  C0027873|C1395170
# 4                                                  NaN           C2868672
# ...                                                ...                ...
# 95793  Incomplete lesion of lumbar spinal cord level 1           C2838665
# 95794                                              NaN           C2840799
# 95795                                              NaN           C2883915
# 95796                                              NaN           C2885182
# 95797                                              NaN           C2900209
#
#       Semantic Types    ICD_id
# 0               T037  T47.2X6D
# 1               T037  T47.0X6D
# 2               T047     J96.2
# 3               T047     G36.0
# 4               T037   S93.119
# ...              ...       ...
# 95793           T037   S34.121
# 95794           T037  S42.154A
# 95795           T037   T50.B93
# 95796           T037  T61.784D
# 95797           T037  W03.XXXD
#
# [95798 rows x 5 columns]

# %% [markdown]
# ## Add semantic type

# %%
semantic_type_df = pd.read_csv(
    "data/STY.csv",      # relative python path to subdirectory
    sep=',',
    dtype=str,
    usecols=['Class ID','Preferred Label']
)
semantic_type_df
# Out:
#                                           Class ID  \
# 0    http://purl.bioontology.org/ontology/STY/T057
# 1    http://purl.bioontology.org/ontology/STY/T047
# 2    http://purl.bioontology.org/ontology/STY/T167
# 3    http://purl.bioontology.org/ontology/STY/T066
# 4    http://purl.bioontology.org/ontology/STY/T184
# ..                                             ...
# 122  http://purl.bioontology.org/ontology/STY/T194
# 123  http://purl.bioontology.org/ontology/STY/T012
# 124  http://purl.bioontology.org/ontology/STY/T087
# 125  http://purl.bioontology.org/ontology/STY/T122
# 126  http://purl.bioontology.org/ontology/STY/T197
#
#                    Preferred Label
# 0            Occupational Activity
# 1              Disease or Syndrome
# 2                        Substance
# 3                 Machine Activity
# 4                  Sign or Symptom
# ..                             ...
# 122                       Archaeon
# 123                           Bird
# 124            Amino Acid Sequence
# 125  Biomedical or Dental Material
# 126             Inorganic Chemical
#
# [127 rows x 2 columns]

# %%
semantic_type_df.rename(columns={'Class ID': 'Semantic Types','Preferred Label':'type'}, inplace=True)

# %%
semantic_type_df['Semantic Types'] = semantic_type_df['Semantic Types'].apply(lambda x: x.split('/')[-1])

# %%
semantic_type_df
# Out:
#     Semantic Types                           type
# 0             T057          Occupational Activity
# 1             T047            Disease or Syndrome
# 2             T167                      Substance
# 3             T066               Machine Activity
# 4             T184                Sign or Symptom
# ..             ...                            ...
# 122           T194                       Archaeon
# 123           T012                           Bird
# 124           T087            Amino Acid Sequence
# 125           T122  Biomedical or Dental Material
# 126           T197             Inorganic Chemical
#
# [127 rows x 2 columns]

# %%
icd_df = pd.merge(icd_df,semantic_type_df,on='Semantic Types',how='inner')

# %%
icd_df.drop('Semantic Types',inplace=True,axis=1)

# %%
icd_df
# Out:
#                                          Preferred Label  \
# 0      Underdosing of stimulant laxatives, subsequent...
# 1      Underdosing of histamine H2-receptor blockers,...
# 2      Dislocation of interphalangeal joint of unspec...
# 3      Pedestrian on skateboard injured in collision ...
# 4                    Water transport accidents (V90-V94)
# ...                                                  ...
# 95666                                          Hostility
# 95667                               Adjustment disorders
# 95668                                     Transsexualism
# 95669                              Transvestic fetishism
# 95670                             Dual role transvestism
#
#                                                 Synonyms  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 95666                                                NaN
# 95667  Culture shock|Hospitalism in children|Grief re...
# 95668  Gender dysphoria in adolescents and adults|Gen...
# 95669      Fetishistic transvestism|Transvestic disorder
# 95670                                                NaN
#
#                                        CUI    ICD_id                 type
# 0                                 C2879738  T47.2X6D  Injury or Poisoning
# 1                                 C2879688  T47.0X6D  Injury or Poisoning
# 2                                 C2868672   S93.119  Injury or Poisoning
# 3                                 C2891755  V03.12XA  Injury or Poisoning
# 4                                 C4721415   V90-V94  Injury or Poisoning
# ...                                    ...       ...                  ...
# 95666                             C0020039     R45.5       Mental Process
# 95667  C0221521|C0018235|C0865406|C0001546     F43.2       Mental Process
# 95668           C4268305|C4237136|C0040765     F64.0   Organism Attribute
# 95669                    C0040774|C4237450     F65.1   Organism Attribute
# 95670                             C0040774     F64.1   Organism Attribute
#
# [95671 rows x 5 columns]

# %% [markdown]
# # Merge all ontologies

# %%
df = pd.merge(icd_df,df1,on='CUI',how='outer')

# %%
df
# Out:
#                                           Preferred Label Synonyms_x  \
# 0       Underdosing of stimulant laxatives, subsequent...        NaN
# 1       Underdosing of histamine H2-receptor blockers,...        NaN
# 2       Dislocation of interphalangeal joint of unspec...        NaN
# 3       Pedestrian on skateboard injured in collision ...        NaN
# 4                     Water transport accidents (V90-V94)        NaN
# ...                                                   ...        ...
# 126980                                                NaN        NaN
# 126981                                                NaN        NaN
# 126982                                                NaN        NaN
# 126983                                                NaN        NaN
# 126984                                                NaN        NaN
#
#              CUI    ICD_id               type_x   MeshID type_y  \
# 0       C2879738  T47.2X6D  Injury or Poisoning      NaN    NaN
# 1       C2879688  T47.0X6D  Injury or Poisoning      NaN    NaN
# 2       C2868672   S93.119  Injury or Poisoning      NaN    NaN
# 3       C2891755  V03.12XA  Injury or Poisoning      NaN    NaN
# 4       C4721415   V90-V94  Injury or Poisoning      NaN    NaN
# ...          ...       ...                  ...      ...    ...
# 126980  C0275654       NaN                  NaN      NaN    NaN
# 126981  C0035404       NaN                  NaN  D012203    NaN
# 126982  C0683416       NaN                  NaN  D003861    NaN
# 126983  C0011570       NaN                  NaN  D003863    NaN
# 126984  C0005806       NaN                  NaN  D001787    NaN
#
#                                           Cross_reference  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 126980  [ICD9CM:098.17, SNOMEDCT_US_2020_09_01:4537700...
# 126981  [NCI:C113150, SNOMEDCT_US_2020_09_01:199580004...
# 126982  [NCI:C94331, SNOMEDCT_US_2020_09_01:70764005, ...
# 126983  [ICD10CM:F32.9, SNOMEDCT_US_2020_09_01:4100600...
# 126984                                        [DOID:4176]
#
#                                 Term Synonyms_y
# 0                                NaN        NaN
# 1                                NaN        NaN
# 2                                NaN        NaN
# 3                                NaN        NaN
# 4                                NaN        NaN
# ...                              ...        ...
# 126980  acute gonococcal salpingitis        NaN
# 126981            Rh isoimmunization        NaN
# 126982    depersonalization disorder        NaN
# 126983             mental depression        NaN
# 126984   blood group incompatibility        NaN
#
# [126985 rows x 10 columns]

# %%
df['Term'] = df.apply(lambda x: set_term(x['Preferred Label'],x.Term),axis=1)

# %%
df['Synonyms_x'] = df['Synonyms_x'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else np.nan)

# %%
df['Synonyms'] = df.apply(lambda x: set_term_list(x.Synonyms_x,x.Synonyms_y),axis=1)

# %%
df['type'] = df.apply(lambda x: set_term(x.type_x,x.type_y),axis=1)

# %%
df.sample(10)
# Out:
#                                          Preferred Label Synonyms_x       CUI  \
# 45116  Corrosion of second degree of left thumb (nail...        NaN  C2872450
# 4776   Nondisplaced fracture of navicular [scaphoid] ...        NaN  C2867853
# 21261  Nondisplaced dome fracture of unspecified talu...        NaN  C2867525
# 36594  Subluxation of distal interphalangeal joint of...        NaN  C2853220
# 54587  Burn of second degree of unspecified multiple ...        NaN  C2872026
# 12426  Burn of third degree of multiple sites of left...        NaN  C2873343
# 53804  Puncture wound with foreign body, left lower l...        NaN  C2860639
# 51130  Unspecified car occupant injured in collision ...        NaN  C2896860
# 2455   Unspecified injury of muscle and tendon of lon...        NaN  C2869333
# 59684  Legal intervention involving other gas, law en...        NaN  C2906377
#
#          ICD_id               type_x MeshID type_y Cross_reference  \
# 45116  T23.612S  Injury or Poisoning    NaN    NaN             NaN
# 4776   S92.254S  Injury or Poisoning    NaN    NaN             NaN
# 21261  S92.146P  Injury or Poisoning    NaN    NaN             NaN
# 36594  S63.240A  Injury or Poisoning    NaN    NaN             NaN
# 54587  T23.239S  Injury or Poisoning    NaN    NaN             NaN
# 12426  T25.392D  Injury or Poisoning    NaN    NaN             NaN
# 53804  S81.842S  Injury or Poisoning    NaN    NaN             NaN
# 51130  V46.3XXS  Injury or Poisoning    NaN    NaN             NaN
# 2455    S96.009  Injury or Poisoning    NaN    NaN             NaN
# 59684  Y35.291A  Injury or Poisoning    NaN    NaN             NaN
#
#                                                     Term Synonyms_y Synonyms  \
# 45116  Corrosion of second degree of left thumb (nail...        NaN      NaN
# 4776   Nondisplaced fracture of navicular [scaphoid] ...        NaN      NaN
# 21261  Nondisplaced dome fracture of unspecified talu...        NaN      NaN
# 36594  Subluxation of distal interphalangeal joint of...        NaN      NaN
# 54587  Burn of second degree of unspecified multiple ...        NaN      NaN
# 12426  Burn of third degree of multiple sites of left...        NaN      NaN
# 53804  Puncture wound with foreign body, left lower l...        NaN      NaN
# 51130  Unspecified car occupant injured in collision ...        NaN      NaN
# 2455   Unspecified injury of muscle and tendon of lon...        NaN      NaN
# 59684  Legal intervention involving other gas, law en...        NaN      NaN
#
#                       type
# 45116  Injury or Poisoning
# 4776   Injury or Poisoning
# 21261  Injury or Poisoning
# 36594  Injury or Poisoning
# 54587  Injury or Poisoning
# 12426  Injury or Poisoning
# 53804  Injury or Poisoning
# 51130  Injury or Poisoning
# 2455   Injury or Poisoning
# 59684  Injury or Poisoning

# %%
df.drop(['Preferred Label','Synonyms_x','Synonyms_y','type_y','type_x'],inplace=True,axis=1)

# %%
df.count()
# Out:
# CUI                110783
# ICD_id              95688
# MeshID              21431
# Cross_reference     15442
# Term               126985
# Synonyms            19586
# type               115927
# dtype: int64

# %%
df
# Out:
#              CUI    ICD_id   MeshID  \
# 0       C2879738  T47.2X6D      NaN
# 1       C2879688  T47.0X6D      NaN
# 2       C2868672   S93.119      NaN
# 3       C2891755  V03.12XA      NaN
# 4       C4721415   V90-V94      NaN
# ...          ...       ...      ...
# 126980  C0275654       NaN      NaN
# 126981  C0035404       NaN  D012203
# 126982  C0683416       NaN  D003861
# 126983  C0011570       NaN  D003863
# 126984  C0005806       NaN  D001787
#
#                                           Cross_reference  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 126980  [ICD9CM:098.17, SNOMEDCT_US_2020_09_01:4537700...
# 126981  [NCI:C113150, SNOMEDCT_US_2020_09_01:199580004...
# 126982  [NCI:C94331, SNOMEDCT_US_2020_09_01:70764005, ...
# 126983  [ICD10CM:F32.9, SNOMEDCT_US_2020_09_01:4100600...
# 126984                                        [DOID:4176]
#
#                                                      Term Synonyms  \
# 0       Underdosing of stimulant laxatives, subsequent...      NaN
# 1       Underdosing of histamine H2-receptor blockers,...      NaN
# 2       Dislocation of interphalangeal joint of unspec...      NaN
# 3       Pedestrian on skateboard injured in collision ...      NaN
# 4                     Water transport accidents (V90-V94)      NaN
# ...                                                   ...      ...
# 126980                       acute gonococcal salpingitis      NaN
# 126981                                 Rh isoimmunization      NaN
# 126982                         depersonalization disorder      NaN
# 126983                                  mental depression      NaN
# 126984                        blood group incompatibility      NaN
#
#                        type
# 0       Injury or Poisoning
# 1       Injury or Poisoning
# 2       Injury or Poisoning
# 3       Injury or Poisoning
# 4       Injury or Poisoning
# ...                     ...
# 126980                  NaN
# 126981                  NaN
# 126982                  NaN
# 126983                  NaN
# 126984                  NaN
#
# [126985 rows x 7 columns]

# %% [markdown]
# # To JSON Disease document

# %%
df.fillna('',inplace=True)

# %%
df.sample(5)
# Out:
#              CUI    ICD_id   MeshID Cross_reference  \
# 47128   C2845610  S52.323J
# 24785   C2847863  S56.116A
# 56705   C2886884  T81.503S
# 21968   C2855468   S66.502
# 112828                      D011018
#
#                                                      Term  \
# 47128   Displaced transverse fracture of shaft of unsp...
# 24785   Strain of flexor muscle, fascia and tendon of ...
# 56705   Unspecified complication of foreign body accid...
# 21968   Unspecified injury of intrinsic muscle, fascia...
# 112828                            Pneumonia, Pneumococcal
#
#                                                  Synonyms  \
# 47128
# 24785
# 56705
# 21968
# 112828  [Pneumococcal Pneumonia, Pneumococcal Pneumoni...
#
#                              type
# 47128         Injury or Poisoning
# 24785         Injury or Poisoning
# 56705         Injury or Poisoning
# 21968         Injury or Poisoning
# 112828  Respiratory tract disease

# %%
documents = []
num = 0;
for i in df.itertuples(index=False):
    disease_document = {}
    disease_document['term'] = i[4]
    disease_document['synonyms']= i[5]
    disease_document['mesh_id']= i[2]
    disease_document['cui']= i[0]
    disease_document['ICD10_id'] = i[1]
    disease_document['semantic_type']= i[6]
    disease_document['cross_reference']= i[3]   
    documents.append(disease_document) 
    num+=1
    if num%10000 == 0:
        print(num/len(df)*100,'% diseases processed')
# Out:
# 7.874945859747213 % diseases processed
# 15.749891719494427 % diseases processed
# 23.624837579241643 % diseases processed
# 31.499783438988853 % diseases processed
# 39.37472929873607 % diseases processed
# 47.249675158483285 % diseases processed
# 55.1246210182305 % diseases processed
# 62.999566877977706 % diseases processed
# 70.87451273772493 % diseases processed
# 78.74945859747214 % diseases processed
# 86.62440445721936 % diseases processed
# 94.49935031696657 % diseases processed

# %%
len(documents)
# Out:
# 126985

# %%
documents[534]
# Out:
# {'term': 'Fracture of shaft of tibia',
#  'synonyms': '',
#  'mesh_id': '',
#  'cui': 'C0272767',
#  'ICD10_id': 'S82.2',
#  'semantic_type': 'Injury or Poisoning',
#  'cross_reference': ''}

# %% [markdown]
# ## Save and load resultant document

# %%
with open('data/Disease/diseases.json', 'w') as fout:
    json.dump(documents, fout)

# %%
with open('data/Disease/diseases.json', 'r') as fout:
    diseases = json.loads(fout.read())
    print(len(diseases))
# Out:
# 32693
