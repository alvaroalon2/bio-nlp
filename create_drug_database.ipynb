# %%
import pandas as pd 
import numpy as np

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %% [markdown]
# # PubChem

# %%
important_columns = {
    'cid',
    'cmpdname',
    'cmpdsynonym',
    'inchikey',
    'meshheadings'
}

# %%
pubchem_df = pd.read_csv(
    "data/PubChem.csv",      # relative python path to subdirectory
    sep=',',
    usecols=important_columns,
    dtype=str
)

print(pubchem_df.shape)
pubchem_df.head()
# Out:
# (130173, 5)
#   cid                              cmpdname  \
# 0   1                       Acetylcarnitine
# 1   4                    1-Aminopropan-2-ol
# 2   6           1-Chloro-2,4-dinitrobenzene
# 3   7                        9-Ethyladenine
# 4   8  2,3-Dihydroxy-3-methylpentanoic acid
#
#                                          cmpdsynonym  \
# 0  Acetyl-DL-carnitine|acetylcarnitine|DL-O-Acety...
# 1  1-Aminopropan-2-ol|1-AMINO-2-PROPANOL|78-96-6|...
# 2  1-chloro-2,4-dinitrobenzene|2,4-Dinitrochlorob...
# 3  9-Ethyladenine|2715-68-6|9-ethyl-9h-purin-6-am...
# 4  2,3-Dihydroxy-3-methylpentanoic acid|2,3-dihyd...
#
#                       inchikey          meshheadings
# 0  RDHQFKQIGNGIED-UHFFFAOYSA-N       Acetylcarnitine
# 1  HXKKHQJGJAFBHI-UHFFFAOYSA-N                   NaN
# 2  VYZAHLCBVHPDDF-UHFFFAOYSA-N  Dinitrochlorobenzene
# 3  MUIPLRMGAXZWSQ-UHFFFAOYSA-N                   NaN
# 4  PDGXJDXVGMHUIR-UHFFFAOYSA-N                   NaN

# %%
pubchem_df.fillna('', inplace=True)

# %%
pubchem_df.sample(5)
# Out:
#               cid                                           cmpdname  \
# 93537    23681230                          Omeprazole sodium hydrate
# 71642     9808654                                        CID 9808654
# 115267  101950409  (2S)-2-[[(2S)-2-[[(2S)-2-[[(2S)-2-[[(2S)-2-[[(...
# 19601       95955                                Dibenzyl diselenide
# 125707  136900208                                        Prianosin A
#
#                                               cmpdsynonym  \
# 93537   OMEPRAZOLE SODIUM|Omeprazole sodium hydrate|95...
# 71642   u-83836e|U83836E|137018-55-4|PNU-83836E|(2R)-2...
# 115267                                              T-241
# 19601   Dibenzyl diselenide|1482-82-2|1,2-Dibenzyldise...
# 125707                                        Prianosin A
#
#                            inchikey meshheadings
# 93537   RRFCKCAQHRITRG-UHFFFAOYSA-N   Omeprazole
# 71642   KJGXSMZHYBXPIS-ZHXNKHNVSA-N
# 115267  QTWWWOBSQULXHE-MTVPJWGZSA-N
# 19601   HYAVEDMFTNAZQE-UHFFFAOYSA-N
# 125707  XJZVECLAJOTPHE-YRUZYCQGSA-N

# %% [markdown]
# # CHEBI

# %%
important_columns_chebi = {
    'Class ID',
    'Preferred Label',
    'Synonyms',
    'Obsolete',
    'Parents',
    'database_cross_reference',
    'http://purl.obolibrary.org/obo/chebi/inchikey',
    'http://www.w3.org/2004/02/skos/core#notation'
}

# %%
chebi_df = pd.read_csv(
    "data/CHEBI.csv",      # relative python path to subdirectory
    sep=',',
    usecols=important_columns_chebi,
    dtype=str
)

print(chebi_df.shape)
chebi_df.head()
# Out:
# (156098, 8)
#                                       Class ID  \
# 0  http://purl.obolibrary.org/obo/CHEBI_101465
# 1  http://purl.obolibrary.org/obo/CHEBI_159237
# 2  http://purl.obolibrary.org/obo/CHEBI_101448
# 3   http://purl.obolibrary.org/obo/CHEBI_85476
# 4   http://purl.obolibrary.org/obo/CHEBI_87468
#
#                                      Preferred Label  \
# 0  (2S,3S,4R)-4-(hydroxymethyl)-1-(2-methoxy-1-ox...
# 1                                        Leu-His-Glu
# 2  2-fluoro-N-[(4S,7R,8S)-8-methoxy-4,7,10-trimet...
# 3                      O-hydroxyvaleroyl-L-carnitine
# 4                                 benzo scarlet 4BNS
#
#                                             Synonyms Obsolete  \
# 0                                                NaN    false
# 1  (2S)-2-[[(2S)-2-[[(2S)-2-amino-4-methylpentano...    false
# 2                                                NaN    false
# 3  O-hydroxyvaleroyl-L-carnitines|O-hydroxyvalero...    false
# 4  trisodium 4-hydroxy-7-[({5-hydroxy-6-[(3-metho...    false
#
#                                              Parents database_cross_reference  \
# 0         http://purl.obolibrary.org/obo/CHEBI_38193          LINCS:LSM-12828
# 1         http://purl.obolibrary.org/obo/CHEBI_25676      Chemspider:58808728
# 2  http://purl.obolibrary.org/obo/CHEBI_52898|htt...          LINCS:LSM-12811
# 3        http://purl.obolibrary.org/obo/CHEBI_133449                      NaN
# 4         http://purl.obolibrary.org/obo/CHEBI_38700                      NaN
#
#   http://purl.obolibrary.org/obo/chebi/inchikey  \
# 0                   NONDGOMIDWLUNU-AOIWGVFYSA-N
# 1                   KXODZBLFVFSLAI-AVGNSLFASA-N
# 2                   ULFQVHHILZHREN-ZMPRRUGASA-N
# 3                                           NaN
# 4                   ARFFDLGGWDRGGT-UHFFFAOYSA-K
#
#   http://www.w3.org/2004/02/skos/core#notation
# 0                                 CHEBI:101465
# 1                                 CHEBI:159237
# 2                                 CHEBI:101448
# 3                                  CHEBI:85476
# 4                                  CHEBI:87468

# %%
chebi_df = chebi_df[chebi_df['Obsolete']=='false']
chebi_df.drop(['Obsolete','Class ID'],axis = 1, inplace=True)
print(chebi_df.shape)
chebi_df.head()
# Out:
# (137592, 6)
#                                      Preferred Label  \
# 0  (2S,3S,4R)-4-(hydroxymethyl)-1-(2-methoxy-1-ox...
# 1                                        Leu-His-Glu
# 2  2-fluoro-N-[(4S,7R,8S)-8-methoxy-4,7,10-trimet...
# 3                      O-hydroxyvaleroyl-L-carnitine
# 4                                 benzo scarlet 4BNS
#
#                                             Synonyms  \
# 0                                                NaN
# 1  (2S)-2-[[(2S)-2-[[(2S)-2-amino-4-methylpentano...
# 2                                                NaN
# 3  O-hydroxyvaleroyl-L-carnitines|O-hydroxyvalero...
# 4  trisodium 4-hydroxy-7-[({5-hydroxy-6-[(3-metho...
#
#                                              Parents database_cross_reference  \
# 0         http://purl.obolibrary.org/obo/CHEBI_38193          LINCS:LSM-12828
# 1         http://purl.obolibrary.org/obo/CHEBI_25676      Chemspider:58808728
# 2  http://purl.obolibrary.org/obo/CHEBI_52898|htt...          LINCS:LSM-12811
# 3        http://purl.obolibrary.org/obo/CHEBI_133449                      NaN
# 4         http://purl.obolibrary.org/obo/CHEBI_38700                      NaN
#
#   http://purl.obolibrary.org/obo/chebi/inchikey  \
# 0                   NONDGOMIDWLUNU-AOIWGVFYSA-N
# 1                   KXODZBLFVFSLAI-AVGNSLFASA-N
# 2                   ULFQVHHILZHREN-ZMPRRUGASA-N
# 3                                           NaN
# 4                   ARFFDLGGWDRGGT-UHFFFAOYSA-K
#
#   http://www.w3.org/2004/02/skos/core#notation
# 0                                 CHEBI:101465
# 1                                 CHEBI:159237
# 2                                 CHEBI:101448
# 3                                  CHEBI:85476
# 4                                  CHEBI:87468

# %%
renamed_columns_chebi = {
    'Preferred Label':'ChEBI_label',
    'Synonyms': 'ChEBI_synonyms',
    'Parents':'ChEBI_parents',
    'database_cross_reference':'ChEBI_cross_reference',
    'http://purl.obolibrary.org/obo/chebi/inchikey':'inchikey',
    'http://www.w3.org/2004/02/skos/core#notation':'ChEBI_id'
}

# %%
chebi_df = chebi_df.rename(renamed_columns_chebi,axis=1)

# %% [markdown]
# # MESH

# %%
important_columns_mesh = [
    'Class ID',
    'Preferred Label',
    'Synonyms',
    'Obsolete',
    'Semantic Types'
]

# %%
mesh_df = pd.read_csv(
    "data/MESH.csv",      # relative python path to subdirectory
    sep=',',
    usecols=important_columns_mesh,
    dtype=str
)
mesh_df
# Out:
#                                                 Class ID  \
# 0      http://purl.bioontology.org/ontology/MESH/C000...
# 1      http://purl.bioontology.org/ontology/MESH/C585345
# 2      http://purl.bioontology.org/ontology/MESH/C000...
# 3      http://purl.bioontology.org/ontology/MESH/C000...
# 4      http://purl.bioontology.org/ontology/MESH/C049340
# ...                                                  ...
# 87269  http://purl.bioontology.org/ontology/MESH/C088692
# 87270  http://purl.bioontology.org/ontology/MESH/C481277
# 87271  http://purl.bioontology.org/ontology/MESH/C111764
# 87272  http://purl.bioontology.org/ontology/MESH/C000...
# 87273                           http://purl.bioontology.
#
#                                          Preferred Label  \
# 0           technetium 99m hydroxyethylene-diphosphonate
# 1                              Tardbp protein, zebrafish
# 2      Autographa californica multiple nuclear polyhe...
# 3                            Leeuwenhoekiella blandensis
# 4                                    N-demethylmenogaril
# ...                                                  ...
# 87269  2-(4-(biscarboxymethyl)amino-3-(carboxymethoxy...
# 87270                         Yrr1 protein, S cerevisiae
# 87271                                  3-epi-actinobolin
# 87272                    2-tridecanyl-1,4-naphthoquinone
# 87273                                                NaN
#
#                                                 Synonyms Obsolete  \
# 0          99mTc-HDP|99mTc-hydroxyethylene-diphosphonate    false
# 1      Tardbpl-FL protein, zebrafish|Tardbpl protein,...    false
# 2      Trichoplusia ni multiple nucleopolyhedrovirus|...    false
# 3                                                    NaN    false
# 4                                                    NaN    false
# ...                                                  ...      ...
# 87269                                         Mag-indo-1    false
# 87270                      Yor162c protein, S cerevisiae    false
# 87271                                   3-epiactinobolin    false
# 87272                                                NaN    false
# 87273                                                NaN      NaN
#
#                                           Semantic Types
# 0      http://purl.bioontology.org/ontology/STY/T130|...
# 1      http://purl.bioontology.org/ontology/STY/T123|...
# 2          http://purl.bioontology.org/ontology/STY/T005
# 3          http://purl.bioontology.org/ontology/STY/T007
# 4          http://purl.bioontology.org/ontology/STY/T109
# ...                                                  ...
# 87269  http://purl.bioontology.org/ontology/STY/T109|...
# 87270      http://purl.bioontology.org/ontology/STY/T116
# 87271      http://purl.bioontology.org/ontology/STY/T109
# 87272      http://purl.bioontology.org/ontology/STY/T109
# 87273                                                NaN
#
# [87274 rows x 5 columns]

# %%
mesh_df['Class ID'] = mesh_df['Class ID'].apply(lambda x: x.split('/')[-1])

# %%
print(mesh_df.shape)
# Out:
# (87274, 5)

# %%
mesh_df = mesh_df[mesh_df['Obsolete']=='false']
mesh_df = mesh_df.drop('Obsolete',axis=1)
print(mesh_df.shape)
# Out:
# (87273, 4)

# %%
mesh_df[['ST1','ST2']] = mesh_df['Semantic Types'].str.split('|', 1, expand=True)
mesh_df[['ST2','ST3']] = mesh_df['ST2'].str.split('|', 1, expand=True)
mesh_df
# Out:
#          Class ID                                    Preferred Label  \
# 0      C000624633       technetium 99m hydroxyethylene-diphosphonate
# 1         C585345                          Tardbp protein, zebrafish
# 2      C000623720  Autographa californica multiple nuclear polyhe...
# 3      C000644313                        Leeuwenhoekiella blandensis
# 4         C049340                                N-demethylmenogaril
# ...           ...                                                ...
# 87268     C503576  bis di-N,N'-1-deoxyfructosyl glutathione disul...
# 87269     C088692  2-(4-(biscarboxymethyl)amino-3-(carboxymethoxy...
# 87270     C481277                         Yrr1 protein, S cerevisiae
# 87271     C111764                                  3-epi-actinobolin
# 87272  C000595691                    2-tridecanyl-1,4-naphthoquinone
#
#                                                 Synonyms  \
# 0          99mTc-HDP|99mTc-hydroxyethylene-diphosphonate
# 1      Tardbpl-FL protein, zebrafish|Tardbpl protein,...
# 2      Trichoplusia ni multiple nucleopolyhedrovirus|...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 87268         bis di-N,N'-1-deoxyfructosyl GSSG|F-GSSG-F
# 87269                                         Mag-indo-1
# 87270                      Yor162c protein, S cerevisiae
# 87271                                   3-epiactinobolin
# 87272                                                NaN
#
#                                           Semantic Types  \
# 0      http://purl.bioontology.org/ontology/STY/T130|...
# 1      http://purl.bioontology.org/ontology/STY/T123|...
# 2          http://purl.bioontology.org/ontology/STY/T005
# 3          http://purl.bioontology.org/ontology/STY/T007
# 4          http://purl.bioontology.org/ontology/STY/T109
# ...                                                  ...
# 87268  http://purl.bioontology.org/ontology/STY/T116|...
# 87269  http://purl.bioontology.org/ontology/STY/T109|...
# 87270      http://purl.bioontology.org/ontology/STY/T116
# 87271      http://purl.bioontology.org/ontology/STY/T109
# 87272      http://purl.bioontology.org/ontology/STY/T109
#
#                                                  ST1  \
# 0      http://purl.bioontology.org/ontology/STY/T130
# 1      http://purl.bioontology.org/ontology/STY/T123
# 2      http://purl.bioontology.org/ontology/STY/T005
# 3      http://purl.bioontology.org/ontology/STY/T007
# 4      http://purl.bioontology.org/ontology/STY/T109
# ...                                              ...
# 87268  http://purl.bioontology.org/ontology/STY/T116
# 87269  http://purl.bioontology.org/ontology/STY/T109
# 87270  http://purl.bioontology.org/ontology/STY/T116
# 87271  http://purl.bioontology.org/ontology/STY/T109
# 87272  http://purl.bioontology.org/ontology/STY/T109
#
#                                                  ST2   ST3
# 0      http://purl.bioontology.org/ontology/STY/T197  None
# 1      http://purl.bioontology.org/ontology/STY/T116  None
# 2                                               None  None
# 3                                               None  None
# 4                                               None  None
# ...                                              ...   ...
# 87268  http://purl.bioontology.org/ontology/STY/T121  None
# 87269  http://purl.bioontology.org/ontology/STY/T121  None
# 87270                                           None  None
# 87271                                           None  None
# 87272                                           None  None
#
# [87273 rows x 7 columns]

# %%
mesh_df = mesh_df.drop('Semantic Types',axis=1)

# %%
mesh_df.sample(10)
# Out:
#          Class ID                            Preferred Label  \
# 18962  C000615401                                  Nickel-49
# 58825     C504819                 Fmc1 protein, S cerevisiae
# 24581     C409038  nucleus-encoded phage-type RNA polymerase
# 36420     C479695                   CED-2 protein, C elegans
# 1837      C006469                     allyl propyl disulfide
# 72215     D008828                 Microbiological Techniques
# 51429     C031315                    2,9-dibromobenzanthrone
# 5188      C531259                      C4a-hydroperoxyflavin
# 49403     C520224                 Cfd1 protein, S cerevisiae
# 21010     C476798                         Crk protein, mouse
#
#                                                 Synonyms  \
# 18962               49Ni radioisotope|Ni-49 radioisotope
# 58825                                                NaN
# 24581                          NEP-1 enzyme|NEP-2 enzyme
# 36420                                                NaN
# 1837                                                 NaN
# 72215  Microbiologic Techniques|Microbiologic Technic...
# 51429           7H-Benz(de)anthracen-7-one, 2,9-dibromo-
# 5188                                                 NaN
# 49403                      YIL003W protein, S cerevisiae
# 21010  v-crk sarcoma virus CT10 oncogene homolog (avi...
#
#                                                  ST1  \
# 18962  http://purl.bioontology.org/ontology/STY/T196
# 58825  http://purl.bioontology.org/ontology/STY/T123
# 24581  http://purl.bioontology.org/ontology/STY/T126
# 36420  http://purl.bioontology.org/ontology/STY/T123
# 1837   http://purl.bioontology.org/ontology/STY/T109
# 72215  http://purl.bioontology.org/ontology/STY/T059
# 51429  http://purl.bioontology.org/ontology/STY/T109
# 5188   http://purl.bioontology.org/ontology/STY/T109
# 49403  http://purl.bioontology.org/ontology/STY/T123
# 21010  http://purl.bioontology.org/ontology/STY/T123
#
#                                                  ST2   ST3
# 18962                                           None  None
# 58825  http://purl.bioontology.org/ontology/STY/T116  None
# 24581  http://purl.bioontology.org/ontology/STY/T116  None
# 36420  http://purl.bioontology.org/ontology/STY/T116  None
# 1837   http://purl.bioontology.org/ontology/STY/T121  None
# 72215                                           None  None
# 51429                                           None  None
# 5188                                            None  None
# 49403  http://purl.bioontology.org/ontology/STY/T116  None
# 21010  http://purl.bioontology.org/ontology/STY/T116  None

# %% [markdown]
# ## Semantic Types

# %%
semantic_type_df = pd.read_csv(
    "data/STY.csv",      # relative python path to subdirectory
    sep=',',
    dtype=str,
    usecols=['Class ID','Preferred Label']
)
semantic_type_df
# Out:
#                                           Class ID  \
# 0    http://purl.bioontology.org/ontology/STY/T057
# 1    http://purl.bioontology.org/ontology/STY/T047
# 2    http://purl.bioontology.org/ontology/STY/T167
# 3    http://purl.bioontology.org/ontology/STY/T066
# 4    http://purl.bioontology.org/ontology/STY/T184
# ..                                             ...
# 122  http://purl.bioontology.org/ontology/STY/T194
# 123  http://purl.bioontology.org/ontology/STY/T012
# 124  http://purl.bioontology.org/ontology/STY/T087
# 125  http://purl.bioontology.org/ontology/STY/T122
# 126  http://purl.bioontology.org/ontology/STY/T197
#
#                    Preferred Label
# 0            Occupational Activity
# 1              Disease or Syndrome
# 2                        Substance
# 3                 Machine Activity
# 4                  Sign or Symptom
# ..                             ...
# 122                       Archaeon
# 123                           Bird
# 124            Amino Acid Sequence
# 125  Biomedical or Dental Material
# 126             Inorganic Chemical
#
# [127 rows x 2 columns]

# %%
semantic_type_df.rename(columns={'Class ID': 'Semantic_type_url','Preferred Label':'type'}, inplace=True)

# %%
mesh_df = pd.merge(mesh_df,semantic_type_df,left_on='ST1',right_on='Semantic_type_url',how='inner')

# %%
mesh_df = pd.merge(mesh_df,semantic_type_df,left_on='ST2',right_on='Semantic_type_url',how='outer')

# %%
mesh_df = pd.merge(mesh_df,semantic_type_df,left_on='ST3',right_on='Semantic_type_url',how='outer')

# %%
print(mesh_df.shape)
# Out:
# (87350, 12)

# %%
mesh_df.sample(10)
# Out:
#       Class ID             Preferred Label  \
# 55119  C034427                      HB 180
# 18280  C570570                 clauraila A
# 42501  D002534              Hypoxia, Brain
# 29809  C110304                   SR 144190
# 54878  C064076               compound 1929
# 68467  C518612        RSRC2 protein, human
# 66510  C496303          hemoglobin Tripoli
# 85410  C524644                  Yi-Gan San
# 54886  C045046  3-(4-fluorobenzoyl)tropane
# 65636  C556345  CIB22 protein, Arabidopsis
#
#                                                 Synonyms  \
# 55119                                                NaN
# 18280                                                NaN
# 42501  Hypoxic Encephalopathy|Brain Anoxia|Cerebral H...
# 29809  3-(1-(2-(4-benzoyl-2-(3,4-difluorophenyl)morph...
# 54878                                                NaN
# 68467  arginine-serine-rich coiled-coil 2 protein, human
# 66510                                         Hb Tripoli
# 85410            yokukansan|YiGan San|TJ-54|yoku-kan-san
# 54886                                             3-FBOT
# 65636                       AtCIB22 protein, Arabidopsis
#
#                                                  ST1  \
# 55119  http://purl.bioontology.org/ontology/STY/T109
# 18280  http://purl.bioontology.org/ontology/STY/T109
# 42501  http://purl.bioontology.org/ontology/STY/T046
# 29809  http://purl.bioontology.org/ontology/STY/T109
# 54878  http://purl.bioontology.org/ontology/STY/T109
# 68467  http://purl.bioontology.org/ontology/STY/T123
# 66510  http://purl.bioontology.org/ontology/STY/T123
# 85410  http://purl.bioontology.org/ontology/STY/T123
# 54886  http://purl.bioontology.org/ontology/STY/T109
# 65636  http://purl.bioontology.org/ontology/STY/T123
#
#                                                  ST2  \
# 55119  http://purl.bioontology.org/ontology/STY/T121
# 18280                                           None
# 42501                                           None
# 29809                                           None
# 54878  http://purl.bioontology.org/ontology/STY/T121
# 68467  http://purl.bioontology.org/ontology/STY/T116
# 66510  http://purl.bioontology.org/ontology/STY/T116
# 85410  http://purl.bioontology.org/ontology/STY/T109
# 54886  http://purl.bioontology.org/ontology/STY/T121
# 65636  http://purl.bioontology.org/ontology/STY/T116
#
#                                                  ST3  \
# 55119                                           None
# 18280                                           None
# 42501                                           None
# 29809                                           None
# 54878                                           None
# 68467                                           None
# 66510                                           None
# 85410  http://purl.bioontology.org/ontology/STY/T121
# 54886                                           None
# 65636                                           None
#
#                                  Semantic_type_url_x  \
# 55119  http://purl.bioontology.org/ontology/STY/T109
# 18280  http://purl.bioontology.org/ontology/STY/T109
# 42501  http://purl.bioontology.org/ontology/STY/T046
# 29809  http://purl.bioontology.org/ontology/STY/T109
# 54878  http://purl.bioontology.org/ontology/STY/T109
# 68467  http://purl.bioontology.org/ontology/STY/T123
# 66510  http://purl.bioontology.org/ontology/STY/T123
# 85410  http://purl.bioontology.org/ontology/STY/T123
# 54886  http://purl.bioontology.org/ontology/STY/T109
# 65636  http://purl.bioontology.org/ontology/STY/T123
#
#                               type_x  \
# 55119               Organic Chemical
# 18280               Organic Chemical
# 42501            Pathologic Function
# 29809               Organic Chemical
# 54878               Organic Chemical
# 68467  Biologically Active Substance
# 66510  Biologically Active Substance
# 85410  Biologically Active Substance
# 54886               Organic Chemical
# 65636  Biologically Active Substance
#
#                                  Semantic_type_url_y  \
# 55119  http://purl.bioontology.org/ontology/STY/T121
# 18280                                            NaN
# 42501                                            NaN
# 29809                                            NaN
# 54878  http://purl.bioontology.org/ontology/STY/T121
# 68467  http://purl.bioontology.org/ontology/STY/T116
# 66510  http://purl.bioontology.org/ontology/STY/T116
# 85410  http://purl.bioontology.org/ontology/STY/T109
# 54886  http://purl.bioontology.org/ontology/STY/T121
# 65636  http://purl.bioontology.org/ontology/STY/T116
#
#                                 type_y  \
# 55119          Pharmacologic Substance
# 18280                              NaN
# 42501                              NaN
# 29809                              NaN
# 54878          Pharmacologic Substance
# 68467  Amino Acid, Peptide, or Protein
# 66510  Amino Acid, Peptide, or Protein
# 85410                 Organic Chemical
# 54886          Pharmacologic Substance
# 65636  Amino Acid, Peptide, or Protein
#
#                                    Semantic_type_url                     type
# 55119                                            NaN                      NaN
# 18280                                            NaN                      NaN
# 42501                                            NaN                      NaN
# 29809                                            NaN                      NaN
# 54878                                            NaN                      NaN
# 68467                                            NaN                      NaN
# 66510                                            NaN                      NaN
# 85410  http://purl.bioontology.org/ontology/STY/T121  Pharmacologic Substance
# 54886                                            NaN                      NaN
# 65636                                            NaN                      NaN

# %%
mesh_df.columns
# Out:
# Index(['Class ID', 'Preferred Label', 'Synonyms', 'ST1', 'ST2', 'ST3',
#        'Semantic_type_url_x', 'type_x', 'Semantic_type_url_y', 'type_y',
#        'Semantic_type_url', 'type'],
#       dtype='object')

# %%
mesh_df= mesh_df[['Class ID','Preferred Label','Synonyms','type_x','type_y','type']]

# %%
mesh_df.sample(10)
# Out:
#          Class ID                           Preferred Label  \
# 31864     C050934                 neurofilament protein 150
# 17925     C534405                            cespihypotin T
# 49460     C014507  N,N-dimethyl-N-(3-chlorophenyl)guanidine
# 78617     C534960                UNC-108 protein, C elegans
# 70323     C572196                    TTC25 protein, Xenopus
# 41624     D000494                     Allosteric Regulation
# 73868  C000597542   (Dpr3(octanoyl)Lys19(Cy5))ghrelin(1-19)
# 17593     C022855             (tetraphenylthio)oxymolybdate
# 69796     C082717       cppC protein, Neisseria gonorrhoeae
# 67874     C099483             CB protein, N15 bacteriophage
#
#                                                 Synonyms  \
# 31864                neurofilament protein NF 150|NF-150
# 17925                                                NaN
# 49460  N,N-dimethyl-N-3-chlorophenylguanidine|N,N-dim...
# 78617  Unc108 protein, C elegans|RAB-2 protein, C ele...
# 70323  TTC25.S protein, Xenopus|TTC25.L protein, Xenopus
# 41624  Regulations, Allosteric|Regulation, Allosteric...
# 73868                                                NaN
# 17593  tetraphenylarsonium tetrakis(benzenethiolato)o...
# 69796   cryptic plasmid protein C, Neisseria gonorrhoeae
# 67874                                                NaN
#
#                                 type_x                           type_y type
# 31864  Amino Acid, Peptide, or Protein                              NaN  NaN
# 17925                 Organic Chemical                              NaN  NaN
# 49460                 Organic Chemical          Pharmacologic Substance  NaN
# 78617                           Enzyme  Amino Acid, Peptide, or Protein  NaN
# 70323    Biologically Active Substance  Amino Acid, Peptide, or Protein  NaN
# 41624               Molecular Function                              NaN  NaN
# 73868    Biologically Active Substance  Amino Acid, Peptide, or Protein  NaN
# 17593                 Organic Chemical                              NaN  NaN
# 69796    Biologically Active Substance  Amino Acid, Peptide, or Protein  NaN
# 67874    Biologically Active Substance  Amino Acid, Peptide, or Protein  NaN

# %%
print(mesh_df.shape)
# Out:
# (87350, 6)

# %%
mesh_df.rename(columns={'type': 'type_z'}, inplace=True)
mesh_df
# Out:
#          Class ID                               Preferred Label  \
# 0      C000624633  technetium 99m hydroxyethylene-diphosphonate
# 1         C020354                           hexacyanoferrate II
# 2         C044522                             neptunium nitrate
# 3         D010772                          Phosphotungstic Acid
# 4         C045076                              Fenton's reagent
# ...           ...                                           ...
# 87345         NaN                                           NaN
# 87346         NaN                                           NaN
# 87347         NaN                                           NaN
# 87348         NaN                                           NaN
# 87349         NaN                                           NaN
#
#                                                 Synonyms  \
# 0          99mTc-HDP|99mTc-hydroxyethylene-diphosphonate
# 1      hexacyanoiron(II)|ferrocyanate|ferrocyanide io...
# 2      neptunium nitrate, 237Np-labeled cpd Np(5+)|ne...
# 3      Tungsten hydroxide oxide phosphate|Acid, Phosp...
# 4                                         Fenton reagent
# ...                                                  ...
# 87345                                                NaN
# 87346                                                NaN
# 87347                                                NaN
# 87348                                                NaN
# 87349                                                NaN
#
#                                       type_x              type_y  \
# 0      Indicator, Reagent, or Diagnostic Aid  Inorganic Chemical
# 1      Indicator, Reagent, or Diagnostic Aid  Inorganic Chemical
# 2      Indicator, Reagent, or Diagnostic Aid  Inorganic Chemical
# 3      Indicator, Reagent, or Diagnostic Aid  Inorganic Chemical
# 4      Indicator, Reagent, or Diagnostic Aid  Inorganic Chemical
# ...                                      ...                 ...
# 87345                                    NaN                 NaN
# 87346                                    NaN                 NaN
# 87347                                    NaN                 NaN
# 87348                                    NaN                 NaN
# 87349                                    NaN                 NaN
#
#                                    type_z
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 87345                  Organism Attribute
# 87346  Professional or Occupational Group
# 87347                     Group Attribute
# 87348                            Archaeon
# 87349                                Bird
#
# [87350 rows x 6 columns]

# %%
mesh_df.isnull().sum(axis = 0)
# Out:
# Class ID               0
# Preferred Label        0
# Synonyms           28522
# type_x                 0
# type_y             41464
# type_z             85368
# dtype: int64

# %%
mesh_df = mesh_df[mesh_df['Class ID'].notna()]

# %%
mesh_df
# Out:
#          Class ID                               Preferred Label  \
# 0      C000624633  technetium 99m hydroxyethylene-diphosphonate
# 1         C020354                           hexacyanoferrate II
# 2         C044522                             neptunium nitrate
# 3         D010772                          Phosphotungstic Acid
# 4         C045076                              Fenton's reagent
# ...           ...                                           ...
# 87265     D008393                                      Marriage
# 87266     D004868                             Equipment Failure
# 87267     D005298                                     Fertility
# 87268     D016247             Information Storage and Retrieval
# 87269  D000068616                               Professionalism
#
#                                                 Synonyms  \
# 0          99mTc-HDP|99mTc-hydroxyethylene-diphosphonate
# 1      hexacyanoiron(II)|ferrocyanate|ferrocyanide io...
# 2      neptunium nitrate, 237Np-labeled cpd Np(5+)|ne...
# 3      Tungsten hydroxide oxide phosphate|Acid, Phosp...
# 4                                         Fenton reagent
# ...                                                  ...
# 87265  Union, Consensual|Age, Marriage|Ages, Marriage...
# 87266  Misuses, Equipment|Failures, Equipment|Equipme...
# 87267  Fertility Preferences|Fertility Preference|Mar...
# 87268  Data Source|Retrieval, Data|Machine-Readable D...
# 87269  Professionalism, Surgical|Education, Professio...
#
#                                       type_x                 type_y  \
# 0      Indicator, Reagent, or Diagnostic Aid     Inorganic Chemical
# 1      Indicator, Reagent, or Diagnostic Aid     Inorganic Chemical
# 2      Indicator, Reagent, or Diagnostic Aid     Inorganic Chemical
# 3      Indicator, Reagent, or Diagnostic Aid     Inorganic Chemical
# 4      Indicator, Reagent, or Diagnostic Aid     Inorganic Chemical
# ...                                      ...                    ...
# 87265                    Qualitative Concept       Temporal Concept
# 87266                       Machine Activity  Phenomenon or Process
# 87267                      Organism Function                 Entity
# 87268                  Occupational Activity       Machine Activity
# 87269                  Occupational Activity        Idea or Concept
#
#                     type_z
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 87265                  NaN
# 87266             Activity
# 87267                  NaN
# 87268                  NaN
# 87269  Qualitative Concept
#
# [87233 rows x 6 columns]

# %%
def set_specific_type(type_x,type_y,type_z):
    if not pd.isnull(type_z):
        return type_z
    if not pd.isnull(type_y):
        return type_y
    return type_x

# %%
mesh_df['type'] = mesh_df.apply(lambda x: set_specific_type(x.type_x,x.type_y,x.type_z),axis=1)

# %%
mesh_df.sample(10)
# Out:
#          Class ID                             Preferred Label  \
# 55888     C575821  5,7-dihydroxy-4'-methoxy-8-prenylflavanone
# 79631     D010625      Phenylethanolamine N-Methyltransferase
# 71274     C486597                         Nub1 protein, mouse
# 7370   C000639493                        Sphingorhabdus rigui
# 1183      C467528                               rhizophorin E
# 54993     C012148                                     A28695A
# 62628     C514504                       Dynll2 protein, mouse
# 69781     C077032                 FcrV protein, Streptococcus
# 2414      C027329                         naringenin chalcone
# 34427     C082338                           FN-C-H II peptide
#
#                                                 Synonyms  \
# 55888                                                NaN
# 79631  Phenethanolamine N Methyltransferase|Noradrena...
# 71274  negative regulator of ubiquitin-like proteins ...
# 7370                                  Sphingopyxis rigui
# 1183   3beta,6alpha-diacetoxy-8(14),15-isopimaradien-...
# 54993             septamycin, 6,16-didemethyl-27-methyl-
# 62628       dynein light chain LC8-type 2 protein, mouse
# 69781                                                NaN
# 2414   2',4,4',6'-tetrahydroxychalcone|chalconaringen...
# 34427                                                NaN
#
#                                 type_x                           type_y  \
# 55888                 Organic Chemical          Pharmacologic Substance
# 79631                           Enzyme  Amino Acid, Peptide, or Protein
# 71274    Biologically Active Substance  Amino Acid, Peptide, or Protein
# 7370                         Bacterium                              NaN
# 1183     Biologically Active Substance                 Organic Chemical
# 54993                 Organic Chemical          Pharmacologic Substance
# 62628    Biologically Active Substance  Amino Acid, Peptide, or Protein
# 69781    Biologically Active Substance  Amino Acid, Peptide, or Protein
# 2414     Biologically Active Substance                 Organic Chemical
# 34427  Amino Acid, Peptide, or Protein                              NaN
#
#       type_z                             type
# 55888    NaN          Pharmacologic Substance
# 79631    NaN  Amino Acid, Peptide, or Protein
# 71274    NaN  Amino Acid, Peptide, or Protein
# 7370     NaN                        Bacterium
# 1183     NaN                 Organic Chemical
# 54993    NaN          Pharmacologic Substance
# 62628    NaN  Amino Acid, Peptide, or Protein
# 69781    NaN  Amino Acid, Peptide, or Protein
# 2414     NaN                 Organic Chemical
# 34427    NaN  Amino Acid, Peptide, or Protein

# %%
mesh_df.to_csv('data/MESH_with_Semantic_types.csv',index=False)

# %% [markdown]
# ## Chemicals in MESH

# %%
mesh_df = pd.read_csv('data/MESH_with_Semantic_types.csv')
mesh_df
# Out:
#          Class ID                               Preferred Label  \
# 0      C000624633  technetium 99m hydroxyethylene-diphosphonate
# 1         C020354                           hexacyanoferrate II
# 2         C044522                             neptunium nitrate
# 3         D010772                          Phosphotungstic Acid
# 4         C045076                              Fenton's reagent
# ...           ...                                           ...
# 87228     D008393                                      Marriage
# 87229     D004868                             Equipment Failure
# 87230     D005298                                     Fertility
# 87231     D016247             Information Storage and Retrieval
# 87232  D000068616                               Professionalism
#
#                                                 Synonyms  \
# 0          99mTc-HDP|99mTc-hydroxyethylene-diphosphonate
# 1      hexacyanoiron(II)|ferrocyanate|ferrocyanide io...
# 2      neptunium nitrate, 237Np-labeled cpd Np(5+)|ne...
# 3      Tungsten hydroxide oxide phosphate|Acid, Phosp...
# 4                                         Fenton reagent
# ...                                                  ...
# 87228  Union, Consensual|Age, Marriage|Ages, Marriage...
# 87229  Misuses, Equipment|Failures, Equipment|Equipme...
# 87230  Fertility Preferences|Fertility Preference|Mar...
# 87231  Data Source|Retrieval, Data|Machine-Readable D...
# 87232  Professionalism, Surgical|Education, Professio...
#
#                                       type_x                 type_y  \
# 0      Indicator, Reagent, or Diagnostic Aid     Inorganic Chemical
# 1      Indicator, Reagent, or Diagnostic Aid     Inorganic Chemical
# 2      Indicator, Reagent, or Diagnostic Aid     Inorganic Chemical
# 3      Indicator, Reagent, or Diagnostic Aid     Inorganic Chemical
# 4      Indicator, Reagent, or Diagnostic Aid     Inorganic Chemical
# ...                                      ...                    ...
# 87228                    Qualitative Concept       Temporal Concept
# 87229                       Machine Activity  Phenomenon or Process
# 87230                      Organism Function                 Entity
# 87231                  Occupational Activity       Machine Activity
# 87232                  Occupational Activity        Idea or Concept
#
#                     type_z                 type
# 0                      NaN   Inorganic Chemical
# 1                      NaN   Inorganic Chemical
# 2                      NaN   Inorganic Chemical
# 3                      NaN   Inorganic Chemical
# 4                      NaN   Inorganic Chemical
# ...                    ...                  ...
# 87228                  NaN     Temporal Concept
# 87229             Activity             Activity
# 87230                  NaN               Entity
# 87231                  NaN     Machine Activity
# 87232  Qualitative Concept  Qualitative Concept
#
# [87233 rows x 7 columns]

# %%
list(mesh_df.type.unique())
# Out:
# ['Inorganic Chemical',
#  'Organic Chemical',
#  'Immunologic Factor',
#  'Indicator, Reagent, or Diagnostic Aid',
#  'Biologically Active Substance',
#  'Virus',
#  'Bacterium',
#  'Enzyme',
#  'Amino Acid, Peptide, or Protein',
#  'Disease or Syndrome',
#  'Element, Ion, or Isotope',
#  'Body Part, Organ, or Organ Component',
#  'Biomedical or Dental Material',
#  'Diagnostic Procedure',
#  'Nucleic Acid, Nucleoside, or Nucleotide',
#  'Antibiotic',
#  'Pharmacologic Substance',
#  'Plant',
#  'Body Location or Region',
#  'Geographic Area',
#  'Congenital Abnormality',
#  'Molecular Function',
#  'Cell',
#  'Therapeutic or Preventive Procedure',
#  'Biomedical Occupation or Discipline',
#  'Pathologic Function',
#  'Intellectual Product',
#  'Functional Concept',
#  'Tissue',
#  'Health Care Activity',
#  'Eukaryote',
#  'Population Group',
#  'Hazardous or Poisonous Substance',
#  'Vitamin',
#  'Injury or Poisoning',
#  'Body Space or Junction',
#  'Laboratory Procedure',
#  'Finding',
#  'Medical Device',
#  'Social Behavior',
#  'Neoplastic Process',
#  'Quantitative Concept',
#  'Mental or Behavioral Dysfunction',
#  'Mammal',
#  'Organization',
#  'Manufactured Object',
#  'Chemical Viewed Structurally',
#  'Idea or Concept',
#  'Qualitative Concept',
#  'Professional Society',
#  'Organ or Tissue Function',
#  'Chemical',
#  'Cell Component',
#  'Clinical Attribute',
#  'Anatomical Structure',
#  'Research Activity',
#  'Embryonic Structure',
#  'Organism Attribute',
#  'Hormone',
#  'Machine Activity',
#  'Anatomical Abnormality',
#  'Organism Function',
#  'Activity',
#  'Fungus',
#  'Occupational Activity',
#  'Natural Phenomenon or Process',
#  'Cell Function',
#  'Gene or Genome',
#  'Individual Behavior',
#  'Genetic Function',
#  'Daily or Recreational Activity',
#  'Amino Acid Sequence',
#  'Food',
#  'Health Care Related Organization',
#  'Governmental or Regulatory Activity',
#  'Human-caused Phenomenon or Process',
#  'Phenomenon or Process',
#  'Archaeon',
#  'Educational Activity',
#  'Physiologic Function',
#  'Reptile',
#  'Receptor',
#  'Research Device',
#  'Occupation or Discipline',
#  'Temporal Concept',
#  'Sign or Symptom',
#  'Regulation or Law',
#  'Clinical Drug',
#  'Mental Process',
#  'Cell or Molecular Dysfunction',
#  'Body System',
#  'Professional or Occupational Group',
#  'Substance',
#  'Acquired Abnormality',
#  'Experimental Model of Disease',
#  'Molecular Biology Research Technique',
#  'Biologic Function',
#  'Spatial Concept',
#  'Fish',
#  'Self-help or Relief Organization',
#  'Body Substance',
#  'Patient or Disabled Group',
#  'Physical Object',
#  'Chemical Viewed Functionally',
#  'Laboratory or Test Result',
#  'Animal',
#  'Bird',
#  'Behavior',
#  'Amphibian',
#  'Family Group',
#  'Nucleotide Sequence',
#  'Group Attribute',
#  'Environmental Effect of Humans',
#  'Conceptual Entity',
#  'Organism',
#  'Classification',
#  'Age Group',
#  'Molecular Sequence',
#  'Vertebrate',
#  'Event',
#  'Group',
#  'Entity']

# %%
chemical_types = ['Inorganic Chemical',
         'Organic Chemical',
         'Immunologic Factor',
         'Indicator, Reagent, or Diagnostic Aid',
         'Biologically Active Substance',
         'Element, Ion, or Isotope',
         'Antibiotic',
         'Pharmacologic Substance',
         'Molecular Function',
         'Hazardous or Poisonous Substance',
         'Vitamin',
         'Chemical Viewed Structurally',
         'Chemical',
         'Clinical Attribute',
         'Hormone',
         'Clinical Drug',
         'Substance',
         'Body Substance',
         'Chemical Viewed Functionally',
         'Laboratory or Test Result'
 ]

# %%
chemical_mesh_df = mesh_df[mesh_df.type.isin(chemical_types)]

# %%
chemical_mesh_df.sample(10)
# Out:
#          Class ID                                    Preferred Label  \
# 23861     C098546                             ethyl tert-butyl ether
# 59570     C058287                                      glidobactin H
# 61526     D001278                                      Atractyloside
# 30236     C532539                luteolin 6-C-beta-boivinopyranoside
# 3441      C495698  hu3S193-N-acetyl gamma calicheamicin dimethyl ...
# 85784  C000613469                                        tafasitamab
# 15359     C013266                 3-sulfonamido-4-chlorobenzoic acid
# 102       C037129                            gold tetrabromide, acid
# 61207  C000613050                                            L01-750
# 48148     C555157                                           SGI-1252
#
#                                                 Synonyms  \
# 23861  2-ethoxy-2-methylpropane|ethyl tertiary-butyl ...
# 59570                                      Glidobactin H
# 61526  Atractylic Acid|Acid, Atractylic|19-Norkaur-16...
# 30236                                                NaN
# 3441                                   hu3S193-CalichDMH
# 85784  XmAb5574|XMAB-5574|MOR00208|MOR-208|MOR208 mon...
# 15359                                                NaN
# 102    potassium tetrabromoaurate|gold tetrabromide, ...
# 61207                                                NaN
# 48148                                                NaN
#
#                                 type_x                            type_y  \
# 23861                 Organic Chemical                               NaN
# 59570  Amino Acid, Peptide, or Protein           Pharmacologic Substance
# 61526                 Organic Chemical  Hazardous or Poisonous Substance
# 30236                 Organic Chemical                               NaN
# 3441                  Organic Chemical                Immunologic Factor
# 85784  Amino Acid, Peptide, or Protein                Immunologic Factor
# 15359                 Organic Chemical                               NaN
# 102            Pharmacologic Substance                Inorganic Chemical
# 61207               Immunologic Factor           Pharmacologic Substance
# 48148                 Organic Chemical           Pharmacologic Substance
#
#                         type_z                              type
# 23861                      NaN                  Organic Chemical
# 59570                      NaN           Pharmacologic Substance
# 61526                      NaN  Hazardous or Poisonous Substance
# 30236                      NaN                  Organic Chemical
# 3441                       NaN                Immunologic Factor
# 85784  Pharmacologic Substance           Pharmacologic Substance
# 15359                      NaN                  Organic Chemical
# 102                        NaN                Inorganic Chemical
# 61207                      NaN           Pharmacologic Substance
# 48148                      NaN           Pharmacologic Substance

# %%
print(chemical_mesh_df.shape)
# Out:
# (45292, 7)

# %%
chemical_mesh_df.to_csv('data/MESH_chemicals.csv',index=False)

# %%
chemical_mesh_df = pd.read_csv('data/MESH_chemicals.csv')
chemical_mesh_df
# Out:
#          Class ID                               Preferred Label  \
# 0      C000624633  technetium 99m hydroxyethylene-diphosphonate
# 1         C020354                           hexacyanoferrate II
# 2         C044522                             neptunium nitrate
# 3         D010772                          Phosphotungstic Acid
# 4         C045076                              Fenton's reagent
# ...           ...                                           ...
# 45287     C031149                                 glycolic acid
# 45288     C029063                      fructose-1,6-diphosphate
# 45289     C444119                  technetium Tc 99m depreotide
# 45290     D012662                            Semen Preservation
# 45291     D057927      Hydrophobic and Hydrophilic Interactions
#
#                                                 Synonyms  \
# 0          99mTc-HDP|99mTc-hydroxyethylene-diphosphonate
# 1      hexacyanoiron(II)|ferrocyanate|ferrocyanide io...
# 2      neptunium nitrate, 237Np-labeled cpd Np(5+)|ne...
# 3      Tungsten hydroxide oxide phosphate|Acid, Phosp...
# 4                                         Fenton reagent
# ...                                                  ...
# 45287  glycolate|glycolic acid, monopotassium salt|gl...
# 45288  fructose-1,6-diphosphate, disodium salt|fructo...
# 45289                           NeoTec|Tc-99m depreotide
# 45290  Frozen Semen|Preservation, Sperm|Semen, Frozen...
# 45291  Interaction, Hydrophilic|Hydrophobicity|Intera...
#
#                                       type_x  \
# 0      Indicator, Reagent, or Diagnostic Aid
# 1      Indicator, Reagent, or Diagnostic Aid
# 2      Indicator, Reagent, or Diagnostic Aid
# 3      Indicator, Reagent, or Diagnostic Aid
# 4      Indicator, Reagent, or Diagnostic Aid
# ...                                      ...
# 45287           Chemical Viewed Structurally
# 45288          Biologically Active Substance
# 45289        Amino Acid, Peptide, or Protein
# 45290                   Health Care Activity
# 45291                    Qualitative Concept
#
#                                       type_y              type_z  \
# 0                         Inorganic Chemical                 NaN
# 1                         Inorganic Chemical                 NaN
# 2                         Inorganic Chemical                 NaN
# 3                         Inorganic Chemical                 NaN
# 4                         Inorganic Chemical                 NaN
# ...                                      ...                 ...
# 45287  Indicator, Reagent, or Diagnostic Aid                 NaN
# 45288           Chemical Viewed Structurally                 NaN
# 45289                                Hormone                 NaN
# 45290                   Laboratory Procedure      Body Substance
# 45291          Natural Phenomenon or Process  Molecular Function
#
#                                         type
# 0                         Inorganic Chemical
# 1                         Inorganic Chemical
# 2                         Inorganic Chemical
# 3                         Inorganic Chemical
# 4                         Inorganic Chemical
# ...                                      ...
# 45287  Indicator, Reagent, or Diagnostic Aid
# 45288           Chemical Viewed Structurally
# 45289                                Hormone
# 45290                         Body Substance
# 45291                     Molecular Function
#
# [45292 rows x 7 columns]

# %% [markdown]
# # Union of Databases

# %%
df = pd.merge(pubchem_df,chebi_df,on='inchikey',how='outer')
df
# Out:
#         cid                              cmpdname  \
# 0         1                       Acetylcarnitine
# 1         4                    1-Aminopropan-2-ol
# 2         6           1-Chloro-2,4-dinitrobenzene
# 3         7                        9-Ethyladenine
# 4         8  2,3-Dihydroxy-3-methylpentanoic acid
# ...     ...                                   ...
# 246486  NaN                                   NaN
# 246487  NaN                                   NaN
# 246488  NaN                                   NaN
# 246489  NaN                                   NaN
# 246490  NaN                                   NaN
#
#                                               cmpdsynonym  \
# 0       Acetyl-DL-carnitine|acetylcarnitine|DL-O-Acety...
# 1       1-Aminopropan-2-ol|1-AMINO-2-PROPANOL|78-96-6|...
# 2       1-chloro-2,4-dinitrobenzene|2,4-Dinitrochlorob...
# 3       9-Ethyladenine|2715-68-6|9-ethyl-9h-purin-6-am...
# 4       2,3-Dihydroxy-3-methylpentanoic acid|2,3-dihyd...
# ...                                                   ...
# 246486                                                NaN
# 246487                                                NaN
# 246488                                                NaN
# 246489                                                NaN
# 246490                                                NaN
#
#                            inchikey          meshheadings  \
# 0       RDHQFKQIGNGIED-UHFFFAOYSA-N       Acetylcarnitine
# 1       HXKKHQJGJAFBHI-UHFFFAOYSA-N
# 2       VYZAHLCBVHPDDF-UHFFFAOYSA-N  Dinitrochlorobenzene
# 3       MUIPLRMGAXZWSQ-UHFFFAOYSA-N
# 4       PDGXJDXVGMHUIR-UHFFFAOYSA-N
# ...                             ...                   ...
# 246486  RYZLCEZTTCNESU-ISYZDWFVSA-N                   NaN
# 246487  OETBDAZRINTQAP-SNUYCWBESA-N                   NaN
# 246488  DEWDMTSMCKXBNP-BYPYZUCNSA-M                   NaN
# 246489  GIFMPMIHCYRIMA-GAMJHBRKSA-N                   NaN
# 246490  KFSCSKZDNNPRDI-SCTDSRPQSA-N                   NaN
#
#                                               ChEBI_label  \
# 0                                       O-acetylcarnitine
# 1                                      1-aminopropan-2-ol
# 2                             1-chloro-2,4-dinitrobenzene
# 3                                                     NaN
# 4                        2,3-Dihydroxy-3-methylpentanoate
# ...                                                   ...
# 246486  (2S,4S,5R,6R)-5-Acetamido-2-[(2R,3R,4S,5S,6R)-...
# 246487  (5Z,7E)-(1R,2R,3R)-3-(hydroxy-propyl)-19-nor-9...
# 246488                         N-carbamoyl-L-methioninate
# 246489  [(2R,3S,4R,5R,6R)-5-Acetamido-6-[[(2R,3R,4R,5R...
# 246490  2-(dimethylamino)-N-[[(2R,3S,4S)-4-(hydroxymet...
#
#                                            ChEBI_synonyms  \
# 0       3-(acetyloxy)-4-(trimethylazaniumyl)butanoate|...
# 1       1-aminopropan-2-ol|1-methyl-2-aminoethanol|2-h...
# 2       1-chloro-2,4-dinitrobenzene|1-Chloro-2,4-dinit...
# 3                                                     NaN
# 4       2,3-Dihydroxy-3-methylpentanoate|2,3-Dihydroxy...
# ...                                                   ...
# 246486  WURCS=2.0/5,7,6/[h2112h_2*NCC/3=O][a2112h-1b_1...
# 246487  (1R,2R,3R,5Z,7E,17beta)-17-[(2R)-6-hydroxy-6-m...
# 246488  (2S)-2-(carbamoylamino)-4-(methylsulfanyl)buta...
# 246489  beta-D-galacto-hexopyranosyl-(1->3)-[2-acetami...
# 246490                                                NaN
#
#                                             ChEBI_parents  \
# 0              http://purl.obolibrary.org/obo/CHEBI_17387
# 1       http://purl.obolibrary.org/obo/CHEBI_35681|htt...
# 2       http://purl.obolibrary.org/obo/CHEBI_35716|htt...
# 3                                                     NaN
# 4              http://purl.obolibrary.org/obo/CHEBI_24654
# ...                                                   ...
# 246486         http://purl.obolibrary.org/obo/CHEBI_37909
# 246487         http://purl.obolibrary.org/obo/CHEBI_27300
# 246488         http://purl.obolibrary.org/obo/CHEBI_58865
# 246489         http://purl.obolibrary.org/obo/CHEBI_78616
# 246490  http://purl.obolibrary.org/obo/CHEBI_22712|htt...
#
#                                     ChEBI_cross_reference      ChEBI_id
# 0               CAS:870-77-9|PMID:23315938|Reaxys:4136458   CHEBI:73024
# 1       HMDB:HMDB0012136|PMID:4362743|CAS:78-96-6|Reax...   CHEBI:19030
# 2       CAS:97-00-7|PMID:25515858|Reaxys:613161|PMID:1...   CHEBI:34718
# 3                                                     NaN           NaN
# 4                                             KEGG:C04104     CHEBI:882
# ...                                                   ...           ...
# 246486                 GlyTouCan:G49104WF|GlyGen:G49104WF  CHEBI:151828
# 246487                                                NaN  CHEBI:137133
# 246488                                       PMID:1732229  CHEBI:137116
# 246489                 GlyTouCan:G71575PR|GlyGen:G71575PR  CHEBI:157053
# 246490                                    LINCS:LSM-38570  CHEBI:127007
#
# [246491 rows x 10 columns]

# %%
df.isnull().sum(axis = 0)
# Out:
# cid                      115829
# cmpdname                 115829
# cmpdsynonym              115829
# inchikey                  22476
# meshheadings             115829
# ChEBI_label              108419
# ChEBI_synonyms           157565
# ChEBI_parents            108419
# ChEBI_cross_reference    139115
# ChEBI_id                 108419
# dtype: int64

# %%
df.fillna('', inplace=True)
df
# Out:
#        cid                              cmpdname  \
# 0        1                       Acetylcarnitine
# 1        4                    1-Aminopropan-2-ol
# 2        6           1-Chloro-2,4-dinitrobenzene
# 3        7                        9-Ethyladenine
# 4        8  2,3-Dihydroxy-3-methylpentanoic acid
# ...     ..                                   ...
# 246486
# 246487
# 246488
# 246489
# 246490
#
#                                               cmpdsynonym  \
# 0       Acetyl-DL-carnitine|acetylcarnitine|DL-O-Acety...
# 1       1-Aminopropan-2-ol|1-AMINO-2-PROPANOL|78-96-6|...
# 2       1-chloro-2,4-dinitrobenzene|2,4-Dinitrochlorob...
# 3       9-Ethyladenine|2715-68-6|9-ethyl-9h-purin-6-am...
# 4       2,3-Dihydroxy-3-methylpentanoic acid|2,3-dihyd...
# ...                                                   ...
# 246486
# 246487
# 246488
# 246489
# 246490
#
#                            inchikey          meshheadings  \
# 0       RDHQFKQIGNGIED-UHFFFAOYSA-N       Acetylcarnitine
# 1       HXKKHQJGJAFBHI-UHFFFAOYSA-N
# 2       VYZAHLCBVHPDDF-UHFFFAOYSA-N  Dinitrochlorobenzene
# 3       MUIPLRMGAXZWSQ-UHFFFAOYSA-N
# 4       PDGXJDXVGMHUIR-UHFFFAOYSA-N
# ...                             ...                   ...
# 246486  RYZLCEZTTCNESU-ISYZDWFVSA-N
# 246487  OETBDAZRINTQAP-SNUYCWBESA-N
# 246488  DEWDMTSMCKXBNP-BYPYZUCNSA-M
# 246489  GIFMPMIHCYRIMA-GAMJHBRKSA-N
# 246490  KFSCSKZDNNPRDI-SCTDSRPQSA-N
#
#                                               ChEBI_label  \
# 0                                       O-acetylcarnitine
# 1                                      1-aminopropan-2-ol
# 2                             1-chloro-2,4-dinitrobenzene
# 3
# 4                        2,3-Dihydroxy-3-methylpentanoate
# ...                                                   ...
# 246486  (2S,4S,5R,6R)-5-Acetamido-2-[(2R,3R,4S,5S,6R)-...
# 246487  (5Z,7E)-(1R,2R,3R)-3-(hydroxy-propyl)-19-nor-9...
# 246488                         N-carbamoyl-L-methioninate
# 246489  [(2R,3S,4R,5R,6R)-5-Acetamido-6-[[(2R,3R,4R,5R...
# 246490  2-(dimethylamino)-N-[[(2R,3S,4S)-4-(hydroxymet...
#
#                                            ChEBI_synonyms  \
# 0       3-(acetyloxy)-4-(trimethylazaniumyl)butanoate|...
# 1       1-aminopropan-2-ol|1-methyl-2-aminoethanol|2-h...
# 2       1-chloro-2,4-dinitrobenzene|1-Chloro-2,4-dinit...
# 3
# 4       2,3-Dihydroxy-3-methylpentanoate|2,3-Dihydroxy...
# ...                                                   ...
# 246486  WURCS=2.0/5,7,6/[h2112h_2*NCC/3=O][a2112h-1b_1...
# 246487  (1R,2R,3R,5Z,7E,17beta)-17-[(2R)-6-hydroxy-6-m...
# 246488  (2S)-2-(carbamoylamino)-4-(methylsulfanyl)buta...
# 246489  beta-D-galacto-hexopyranosyl-(1->3)-[2-acetami...
# 246490
#
#                                             ChEBI_parents  \
# 0              http://purl.obolibrary.org/obo/CHEBI_17387
# 1       http://purl.obolibrary.org/obo/CHEBI_35681|htt...
# 2       http://purl.obolibrary.org/obo/CHEBI_35716|htt...
# 3
# 4              http://purl.obolibrary.org/obo/CHEBI_24654
# ...                                                   ...
# 246486         http://purl.obolibrary.org/obo/CHEBI_37909
# 246487         http://purl.obolibrary.org/obo/CHEBI_27300
# 246488         http://purl.obolibrary.org/obo/CHEBI_58865
# 246489         http://purl.obolibrary.org/obo/CHEBI_78616
# 246490  http://purl.obolibrary.org/obo/CHEBI_22712|htt...
#
#                                     ChEBI_cross_reference      ChEBI_id
# 0               CAS:870-77-9|PMID:23315938|Reaxys:4136458   CHEBI:73024
# 1       HMDB:HMDB0012136|PMID:4362743|CAS:78-96-6|Reax...   CHEBI:19030
# 2       CAS:97-00-7|PMID:25515858|Reaxys:613161|PMID:1...   CHEBI:34718
# 3
# 4                                             KEGG:C04104     CHEBI:882
# ...                                                   ...           ...
# 246486                 GlyTouCan:G49104WF|GlyGen:G49104WF  CHEBI:151828
# 246487                                                     CHEBI:137133
# 246488                                       PMID:1732229  CHEBI:137116
# 246489                 GlyTouCan:G71575PR|GlyGen:G71575PR  CHEBI:157053
# 246490                                    LINCS:LSM-38570  CHEBI:127007
#
# [246491 rows x 10 columns]

# %%
(df['meshheadings'].values == '').sum()
# Out:
# 238018

# %%
chemical_mesh_df.sample(10)
# Out:
#          Class ID                                    Preferred Label  \
# 27611  C000708352                                        trilaciclib
# 31592     C571528         chloro(curcuminato)(p-cymene)ruthenium(II)
# 5326      C502343                                           bromanil
# 6125   C000626579                                             LSS-11
# 43278     C058397      ganglioside GT1b-bovine serum albumin complex
# 38014     C451860  6-bromo-2-(2-(3-(2-chloroethyl)-3-nitrosoureid...
# 43311  C000619835                           technetium 99m HYNIC-H6F
# 1592      C005356                      sphingosine phosphorylcholine
# 23329     C548136                                   papyriferic acid
# 14168     C529319                    1,7-dihydroxy-3-methoxyacridone
#
#                                                 Synonyms  \
# 27611  2'-((5-(4-Methyl-1-piperazinyl)-2-pyridinyl)am...
# 31592                    (p-cymene)Ru(curcuminato)chloro
# 5326                                                 NaN
# 6125                                                 NaN
# 43278                                          GGT1b-BSA
# 38014                                   6-Br-CE-NUE-B-IQ
# 43311                                    99mTc-HYNIC-H6F
# 1592   lysosphingomyelin|sphingosylphosphocholine|sph...
# 23329                                                NaN
# 14168                                           KS-5 cpd
#
#                                 type_x                                 type_y  \
# 27611                 Organic Chemical                Pharmacologic Substance
# 31592                 Organic Chemical                Pharmacologic Substance
# 5326                  Organic Chemical                                    NaN
# 6125                  Organic Chemical                                    NaN
# 43278  Amino Acid, Peptide, or Protein  Indicator, Reagent, or Diagnostic Aid
# 38014                 Organic Chemical                Pharmacologic Substance
# 43311  Amino Acid, Peptide, or Protein  Indicator, Reagent, or Diagnostic Aid
# 1592     Biologically Active Substance                       Organic Chemical
# 23329                 Organic Chemical                                    NaN
# 14168                 Organic Chemical                                    NaN
#
#       type_z                                   type
# 27611    NaN                Pharmacologic Substance
# 31592    NaN                Pharmacologic Substance
# 5326     NaN                       Organic Chemical
# 6125     NaN                       Organic Chemical
# 43278    NaN  Indicator, Reagent, or Diagnostic Aid
# 38014    NaN                Pharmacologic Substance
# 43311    NaN  Indicator, Reagent, or Diagnostic Aid
# 1592     NaN                       Organic Chemical
# 23329    NaN                       Organic Chemical
# 14168    NaN                       Organic Chemical

# %% [markdown]
# ## Multiprocessing with Dask

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
import dask
from dask.distributed import Client, progress
from dask import delayed

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:34693' processes=4 threads=12, memory=7.45 GiB>

# %%
@delayed(nout=2)
def check_mesh(chemical_mesh_df,i,pubchem_doc):
    for j in chemical_mesh_df.itertuples(index=False):
        if (j[1].lower() == i[1].lower()) or (j[1].lower in [item.lower() for item in pubchem_doc['synonyms']]):
            return True, j
    return False, j

# %%
@delayed(nout=4)
def mesh_addition(mesh_flag,mesh,pubchem_doc,new_syn_mesh,total_mesh_concepts): 
    if mesh_flag:
        mesh_id = mesh[0]
        print(mesh_id)
        if mesh[1] not in pubchem_doc['synonyms']:
            new_syn_mesh.append(mesh[1])
        semantic_type = mesh[6]
        total_mesh_concepts = total_mesh_concepts + 1
        return mesh_id,new_syn_mesh,semantic_type,total_mesh_concepts
    return '',[],'',total_mesh_concepts

# %%
documents = []
num = 0
total_mesh_concepts = 0

for i in df.itertuples(index=False):
    pubchem_doc = {}
    
    if len(i[1])==0 and len(i[5])>0:
            pubchem_doc['term'] = i[5]
    else:
            pubchem_doc['term'] = i[1]
            
    synonyms = []
    if len(i[2])>0:
        synonyms = synonyms + i[2].split("|")  
    if len(i[6])>0:
        possible_new_syn = i[6].split("|")
        if possible_new_syn not in synonyms:
            synonyms = synonyms + possible_new_syn
    pubchem_doc['synonyms']= synonyms
    
    mesh_id=''
    semantic_type =''
    new_syn_mesh = []
    
    mesh_flag,mesh = check_mesh(chemical_mesh_df,i,pubchem_doc)
    mesh_id,new_syn_mesh,semantic_type,total_mesh_concepts = mesh_addition(mesh_flag,mesh,pubchem_doc,new_syn_mesh,total_mesh_concepts)
    
    pubchem_doc['synonyms'] = pubchem_doc['synonyms'] + new_syn_mesh
    pubchem_doc['mesh_id'] = mesh_id
    pubchem_doc['semantic_type'] = semantic_type        
    pubchem_doc['cid']= i[0]
    pubchem_doc['chebi_id']= i[9] 
    pubchem_doc['inchikey'] = i[3]
    
    cross_references = []
    if len(i[9])>0:
        cross_references = cross_references + i[8].split("|")
    pubchem_doc['cross_references']= cross_references
    
    num +=1
    if num%1000 == 0:
        print(num/df.shape[0]*100,'% processed')
        
    documents.append(pubchem_doc)


results = dask.persist(*documents)

print(total_mesh_concepts, 'MESH ids added')

# %% [markdown]
# ## Processing in one core

# %%
import json
import os

# %%
def check_mesh(chemical_mesh_df,i,pubchem_doc):
    for j in chemical_mesh_df.itertuples(index=False):
        if (j[1].lower() == i[1].lower()) or (j[1].lower in [item.lower() for item in pubchem_doc['synonyms']]):
            return True, j
    return False, j

# %%
def mesh_addition(mesh_flag,mesh,pubchem_doc,new_syn_mesh,total_mesh_concepts): 
    if mesh_flag:
        mesh_id = mesh[0]
        if mesh[1] not in pubchem_doc['synonyms']:
            new_syn_mesh.append(mesh[1])
        semantic_type = mesh[6]
        total_mesh_concepts = total_mesh_concepts + 1
        return mesh_id,new_syn_mesh,semantic_type,total_mesh_concepts
    return '',[],'',total_mesh_concepts

# %%
documents = []
num = 0
total_mesh_concepts = 0
file_part = 'data/final/drugs_doc_1.json'
checkpoint_flag = True
length_file = 20000

for i in df.itertuples(index=False):
    num +=1
    if os.path.isfile(file_part):
        #print('Archivo',file_part,'encontrado')
        if num%length_file == 0:
            part = int(num/length_file)
            print('Part number',part)        
            file_part = 'data/final/drugs_doc_'+str(part+1)+'.json'
        checkpoint_flag = True

    else:
        pubchem_doc = {}

        if len(i[1])==0 and len(i[5])>0:
                pubchem_doc['term'] = i[5]
        else:
                pubchem_doc['term'] = i[1]

        synonyms = []
        if len(i[2])>0:
            synonyms = synonyms + i[2].split("|")  
        if len(i[6])>0:
            possible_new_syn = i[6].split("|")
            if possible_new_syn not in synonyms:
                synonyms = synonyms + possible_new_syn
        pubchem_doc['synonyms']= synonyms

        mesh_id=''
        semantic_type =''
        new_syn_mesh = []

        mesh_flag,mesh = check_mesh(chemical_mesh_df,i,pubchem_doc)
        mesh_id,new_syn_mesh,semantic_type,total_mesh_concepts = mesh_addition(mesh_flag,mesh,pubchem_doc,new_syn_mesh,total_mesh_concepts)
        
        
        pubchem_doc['synonyms'] = pubchem_doc['synonyms'] + new_syn_mesh
        pubchem_doc['mesh_headings'] = i[4]
        pubchem_doc['mesh_id'] = mesh_id
        pubchem_doc['semantic_type'] = semantic_type        
        pubchem_doc['cid']= i[0]
        pubchem_doc['chebi_id']= i[9] 
        pubchem_doc['inchikey'] = i[3]

        cross_references = []
        if len(i[9])>0:
            cross_references = cross_references + i[8].split("|")
        pubchem_doc['cross_references']= cross_references

        if num%(length_file/10) == 0:
            print(num)
            print(num/df.shape[0]*100,'% processed')
            
        documents.append(pubchem_doc)
        
        if num%length_file == 0:
            part = int(num/length_file)
            print('Part number',part)
            file_part = 'data/final/drugs_doc_'+str(part)+'.json'
            if checkpoint_flag:
                print('Processing file with checkpoint')
                with open(file_part, 'w') as fout:
                    json.dump(documents, fout)
                start = length_file
                end = start + length_file
            else:
                print('Processing file without checkpoint from',start)
                with open(file_part, 'w') as fout:
                    json.dump(documents[start:end], fout)
                start = end
                end = start + length_file
            file_part = 'data/final/drugs_doc_'+str(part+1)+'.json'
            checkpoint_flag = False
    


print(total_mesh_concepts, 'MESH ids added')
# Out:
# 2000
# 0.811388651106937 % processed
# 4000
# 1.622777302213874 % processed
# 6000
# 2.434165953320811 % processed
# 8000
# 3.245554604427748 % processed
# 10000
# 4.0569432555346845 % processed
# 12000
# 4.868331906641622 % processed
# 14000
# 5.679720557748559 % processed
# 16000
# 6.491109208855496 % processed
# 18000
# 7.302497859962433 % processed
# 20000
# 8.113886511069369 % processed
# Part number 1
# Processing file with checkpoint
# 22000
# 8.925275162176307 % processed
# 24000
# 9.736663813283243 % processed
# 26000
# 10.54805246439018 % processed
# 28000
# 11.359441115497118 % processed
# 30000
# 12.170829766604054 % processed
# 32000
# 12.982218417710992 % processed
# 34000
# 13.793607068817929 % processed
# 36000
# 14.604995719924865 % processed
# 38000
# 15.416384371031802 % processed
# 40000
# 16.227773022138738 % processed
# Part number 2
# Processing file without checkpoint from 20000
# 42000
# 17.039161673245676 % processed
# 44000
# 17.850550324352614 % processed
# 46000
# 18.66193897545955 % processed
# 48000
# 19.473327626566487 % processed
# 50000
# 20.28471627767342 % processed
# 52000
# 21.09610492878036 % processed
# 54000
# 21.907493579887298 % processed
# 56000
# 22.718882230994236 % processed
# 58000
# 23.530270882101174 % processed
# 60000
# 24.34165953320811 % processed
# Part number 3
# Processing file without checkpoint from 40000
# 62000
# 25.153048184315047 % processed
# 64000
# 25.964436835421985 % processed
# 66000
# 26.77582548652892 % processed
# 68000
# 27.587214137635858 % processed
# 70000
# 28.398602788742792 % processed
# 72000
# 29.20999143984973 % processed
# 74000
# 30.02138009095667 % processed
# 76000
# 30.832768742063603 % processed
# 78000
# 31.64415739317054 % processed
# 80000
# 32.455546044277476 % processed
# Part number 4
# Processing file without checkpoint from 60000
# 82000
# 33.266934695384414 % processed
# 84000
# 34.07832334649135 % processed
# 86000
# 34.88971199759829 % processed
# 88000
# 35.70110064870523 % processed
# 90000
# 36.51248929981216 % processed
# 92000
# 37.3238779509191 % processed
# 94000
# 38.135266602026036 % processed
# 96000
# 38.946655253132974 % processed
# 98000
# 39.75804390423991 % processed
# 100000
# 40.56943255534684 % processed
# Part number 5
# Processing file without checkpoint from 80000
# 102000
# 41.38082120645378 % processed
# 104000
# 42.19220985756072 % processed
# 106000
# 43.003598508667665 % processed
# 108000
# 43.814987159774596 % processed
# 110000
# 44.626375810881534 % processed
# 112000
# 45.43776446198847 % processed
# 114000
# 46.24915311309541 % processed
# 116000
# 47.06054176420235 % processed
# 118000
# 47.87193041530928 % processed
# 120000
# 48.68331906641622 % processed
# Part number 6
# Processing file without checkpoint from 100000
# 122000
# 49.494707717523156 % processed
# 124000
# 50.306096368630094 % processed
# 126000
# 51.11748501973703 % processed
# 128000
# 51.92887367084397 % processed
# 130000
# 52.7402623219509 % processed
# 132000
# 53.55165097305784 % processed
# 134000
# 54.36303962416478 % processed
# 136000
# 55.174428275271715 % processed
# 138000
# 55.985816926378654 % processed
# 140000
# 56.797205577485585 % processed
# Part number 7
# Processing file without checkpoint from 120000
# 142000
# 57.60859422859252 % processed
# 144000
# 58.41998287969946 % processed
# 146000
# 59.2313715308064 % processed
# 148000
# 60.04276018191334 % processed
# 150000
# 60.854148833020275 % processed
# 152000
# 61.665537484127206 % processed
# 154000
# 62.476926135234145 % processed
# 156000
# 63.28831478634108 % processed
# 158000
# 64.09970343744801 % processed
# 160000
# 64.91109208855495 % processed
# Part number 8
# Processing file without checkpoint from 140000
# 162000
# 65.72248073966189 % processed
# 164000
# 66.53386939076883 % processed
# 166000
# 67.34525804187577 % processed
# 168000
# 68.1566466929827 % processed
# 170000
# 68.96803534408964 % processed
# 172000
# 69.77942399519658 % processed
# 174000
# 70.59081264630352 % processed
# 176000
# 71.40220129741046 % processed
# 178000
# 72.21358994851738 % processed
# 180000
# 73.02497859962432 % processed
# Part number 9
# Processing file without checkpoint from 160000
# 182000
# 73.83636725073126 % processed
# 184000
# 74.6477559018382 % processed
# 186000
# 75.45914455294513 % processed
# 188000
# 76.27053320405207 % processed
# 190000
# 77.08192185515901 % processed
# 192000
# 77.89331050626595 % processed
# 194000
# 78.70469915737289 % processed
# 196000
# 79.51608780847982 % processed
# 198000
# 80.32747645958676 % processed
# 200000
# 81.13886511069369 % processed
# Part number 10
# Processing file without checkpoint from 180000
# 202000
# 81.95025376180062 % processed
# 204000
# 82.76164241290756 % processed
# 206000
# 83.5730310640145 % processed
# 208000
# 84.38441971512144 % processed
# 210000
# 85.19580836622838 % processed
# 212000
# 86.00719701733533 % processed
# 214000
# 86.81858566844227 % processed
# 216000
# 87.62997431954919 % processed
# 218000
# 88.44136297065613 % processed
# 220000
# 89.25275162176307 % processed
# Part number 11
# Processing file without checkpoint from 200000
# 222000
# 90.06414027287 % processed
# 224000
# 90.87552892397694 % processed
# 226000
# 91.68691757508388 % processed
# 228000
# 92.49830622619082 % processed
# 230000
# 93.30969487729776 % processed
# 232000
# 94.1210835284047 % processed
# 234000
# 94.93247217951163 % processed
# 236000
# 95.74386083061856 % processed
# 238000
# 96.5552494817255 % processed
# 240000
# 97.36663813283243 % processed
# Part number 12
# Processing file without checkpoint from 220000
# 242000
# 98.17802678393937 % processed
# 244000
# 98.98941543504631 % processed
# 246000
# 99.80080408615325 % processed
# 14853 MESH ids added

# %%
mypath = 'data/final'
drug_files = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]

# %%
drugs = []
for file in drug_files:
    with open(os.path.join(mypath,file), 'r') as fout:
        drug_file = json.loads(fout.read())
    drugs += drug_file

with open('data/drugs_doc_all.json', 'w') as fout:
    json.dump(drugs, fout)

print(len(drugs))
# Out:
# 246491

# %% [markdown]
# ## Load processed drugs json

# %%
with open('data/drugs_doc_all.json', 'r') as fout:
    drug_file = json.loads(fout.read())
    print(len(drug_file))
# Out:
# 246491

# %%
drug_file[0].keys()
# Out:
# dict_keys(['term', 'synonyms', 'mesh_headings', 'mesh_id', 'semantic_type', 'cid', 'chebi_id', 'inchikey', 'cross_references'])

# %% [markdown]
# # CTD

# %%
important_columns_ctd = ['ChemicalName','ChemicalID', 'Synonyms']

# %%
ctd_df = pd.read_csv(
    "data/CTD_chemicals.csv",      # relative python path to subdirectory
    sep=',',
    usecols=important_columns_ctd,
    dtype=str
)

print(ctd_df.shape)
ctd_df.head()
# Out:
# (174239, 3)
#               ChemicalName    ChemicalID  \
# 0  (0.017ferrocene)amylose  MESH:C089250
# 1               001-C8-NBD  MESH:C114385
# 2      001-C8 oligopeptide  MESH:C114386
# 3     0231A , Streptomyces  MESH:C434150
# 4      0231B, Streptomyces  MESH:C434149
#
#                                             Synonyms
# 0                           (0.017 ferrocene)amylose
# 1  001 C8 NBD|H-MeTyr-Arg-MeArg-D-Leu-NH(CH2)8NH-...
# 2  001 C8 oligopeptide|H-MeTyr-Arg-MeArg-D-Leu-NH...
# 3                                                NaN
# 4                                                NaN

# %%
ctd_df = ctd_df[ctd_df['ChemicalID'].str.startswith('MESH')]
print(ctd_df.shape)
# Out:
# (174239, 3)

# %%
ctd_df['ChemicalID'] = ctd_df['ChemicalID'].apply(lambda x: x.split(':')[1])

# %%
#ctd_df['Synonyms'] = ctd_df['Synonyms'].apply(lambda x: [syn for syn in str(x).split('|')])

# %%
ctd_df.sample(10)
# Out:
#                                              ChemicalName ChemicalID  \
# 29683   3-hydroxymethylphenytoin N,N-dimethylglycine e...    C043113
# 112711                                     LQB34 compound    C527703
# 117411                    methyl-(4-carboxyphenyl)glycine    C474696
# 12055                       2,2',4,5'-tetrachlorobiphenyl    C042128
# 76728                                           CRL 41405    C077879
# 100226                                  hexa CAF protocol    C040421
# 74214                                       clathrimide B    C575041
# 45670   6-methyl-8-methylsulfonyl-1,3,4,6-tetrahydro-2...    C048443
# 101338                                    HLA-DR4 Antigen    D015804
# 71375                                      CEVAD protocol    C404862
#
#                                                  Synonyms
# 29683               Glycine, N,N-dimethyl-, (R)-|HDH ODGE
# 112711                                                NaN
# 117411     alpha-methyl-(4-carboxyphenyl)glycine|MCPG cpd
# 12055                                       2,2',4,5'-TCB
# 76728   2-(hexahydro-1H-azepin-1-yl)-4'-aminopropiophe...
# 100226                                           hexa-CAF
# 74214                                                 NaN
# 45670   2H-5,1-Benzothiazocine, 1,3,4,6-tetrahydro-6-m...
# 101338           Antigen, HLA-DR4|HLA-DR4|HLA DR4 Antigen
# 71375                                       CEVAD regimen

# %%
i = 0
num = 0
mesh_appended= set([])

for doc in drug_file:
    if doc['mesh_id'] == '':
        proposed_mesh = ctd_df.loc[ctd_df['ChemicalName']==doc['term']]
        if len(proposed_mesh)>0:
            new_mesh = str(proposed_mesh['ChemicalID'].values[0])
            doc['mesh_id'] = new_mesh
            mesh_appended.add(new_mesh)
            num +=1
        else:
            try:
                alternative_proposed_mesh = ctd_df[ctd_df['Synonyms'].str.contains(doc['term'], na=False, case = False,regex= False)]
                #print(alternative_proposed_mesh)
                if len(alternative_proposed_mesh)>0 and len(alternative_proposed_mesh)<2:
                    new_mesh = str(alternative_proposed_mesh['ChemicalID'].values[0])
                    doc['mesh_id'] = new_mesh
                    mesh_appended.add(new_mesh)
                    num +=1
                elif len(alternative_proposed_mesh)>1:
                    all_terms=[]
                    for j in alternative_proposed_mesh.itertuples(index=False):
                        all_terms.append(j[0])
                        all_terms += [f for f in j[2].split('|')]
                        
                        if doc['term'] in all_terms:
                            doc['mesh_id'] = j[1]
                            mesh_appended.add(j[1])
                            num +=1
                        elif similar(doc['term'],j[0])>0.85:
                            doc['mesh_id'] = j[1] 
                            mesh_appended.add(j[1])
                            num +=1
                        all_terms=[]
                        
                
            except:
                print('Error in:',doc['term'])
            
    i +=1
    if i%1000 == 0:
        print(i)
        print('No of mesh ids linked:',num)
# Out:
# 1000
# No of mesh ids linked: 90
# 2000
# No of mesh ids linked: 126
# 3000
# No of mesh ids linked: 163
# 4000
# No of mesh ids linked: 253
# 5000
# No of mesh ids linked: 321
# 6000
# No of mesh ids linked: 367
# 7000
# No of mesh ids linked: 411
# 8000
# No of mesh ids linked: 451
# 9000
# No of mesh ids linked: 467
# 10000
# No of mesh ids linked: 503
# 11000
# No of mesh ids linked: 528
# 12000
# No of mesh ids linked: 539
# 13000
# No of mesh ids linked: 551
# 14000
# No of mesh ids linked: 601
# 15000
# No of mesh ids linked: 629
# 16000
# No of mesh ids linked: 645
# 17000
# No of mesh ids linked: 673
# 18000
# No of mesh ids linked: 821
# 19000
# No of mesh ids linked: 1059
# 20000
# No of mesh ids linked: 1329
# 21000
# No of mesh ids linked: 1559
# 22000
# No of mesh ids linked: 1766
# 23000
# No of mesh ids linked: 1967
# 24000
# No of mesh ids linked: 2214
# 25000
# No of mesh ids linked: 2440
# 26000
# No of mesh ids linked: 2702
# 27000
# No of mesh ids linked: 3013
# 28000
# No of mesh ids linked: 3283
# 29000
# No of mesh ids linked: 3522
# 30000
# No of mesh ids linked: 3725
# 31000
# No of mesh ids linked: 3940
# 32000
# No of mesh ids linked: 4181
# 33000
# No of mesh ids linked: 4348
# 34000
# No of mesh ids linked: 4502
# 35000
# No of mesh ids linked: 4641
# 36000
# No of mesh ids linked: 4763
# 37000
# No of mesh ids linked: 4892
# 38000
# No of mesh ids linked: 5048
# 39000
# No of mesh ids linked: 5163
# 40000
# No of mesh ids linked: 5243
# 41000
# No of mesh ids linked: 5345
# 42000
# No of mesh ids linked: 5457
# 43000
# No of mesh ids linked: 5576
# 44000
# No of mesh ids linked: 5684
# 45000
# No of mesh ids linked: 5793
# 46000
# No of mesh ids linked: 5896
# 47000
# No of mesh ids linked: 5984
# 48000
# No of mesh ids linked: 6103
# 49000
# No of mesh ids linked: 6192
# 50000
# No of mesh ids linked: 6298
# 51000
# No of mesh ids linked: 6429
# 52000
# No of mesh ids linked: 6541
# 53000
# No of mesh ids linked: 6632
# 54000
# No of mesh ids linked: 6671
# 55000
# No of mesh ids linked: 6702
# 56000
# No of mesh ids linked: 6737
# 57000
# No of mesh ids linked: 6771
# 58000
# No of mesh ids linked: 6817
# 59000
# No of mesh ids linked: 6848
# 60000
# No of mesh ids linked: 6878
# 61000
# No of mesh ids linked: 7136
# 62000
# No of mesh ids linked: 7406
# 63000
# No of mesh ids linked: 7690
# 64000
# No of mesh ids linked: 7999
# 65000
# No of mesh ids linked: 8238
# 66000
# No of mesh ids linked: 8471
# 67000
# No of mesh ids linked: 8594
# 68000
# No of mesh ids linked: 8891
# 69000
# No of mesh ids linked: 9127
# 70000
# No of mesh ids linked: 9277
# 71000
# No of mesh ids linked: 9442
# 72000
# No of mesh ids linked: 9620
# 73000
# No of mesh ids linked: 9806
# 74000
# No of mesh ids linked: 10022
# 75000
# No of mesh ids linked: 10269
# 76000
# No of mesh ids linked: 10541
# 77000
# No of mesh ids linked: 10806
# 78000
# No of mesh ids linked: 11019
# 79000
# No of mesh ids linked: 11158
# 80000
# No of mesh ids linked: 11504
# 81000
# No of mesh ids linked: 11753
# 82000
# No of mesh ids linked: 11859
# 83000
# No of mesh ids linked: 11917
# 84000
# No of mesh ids linked: 12117
# 85000
# No of mesh ids linked: 12278
# 86000
# No of mesh ids linked: 12495
# 87000
# No of mesh ids linked: 12582
# 88000
# No of mesh ids linked: 12661
# 89000
# No of mesh ids linked: 12719
# 90000
# No of mesh ids linked: 12791
# 91000
# No of mesh ids linked: 12885
# 92000
# No of mesh ids linked: 13008
# 93000
# No of mesh ids linked: 13116
# 94000
# No of mesh ids linked: 13231
# 95000
# No of mesh ids linked: 13337
# 96000
# No of mesh ids linked: 13468
# 97000
# No of mesh ids linked: 13582
# 98000
# No of mesh ids linked: 13692
# 99000
# No of mesh ids linked: 13798
# 100000
# No of mesh ids linked: 13910
# 101000
# No of mesh ids linked: 13939
# 102000
# No of mesh ids linked: 13977
# 103000
# No of mesh ids linked: 13998
# 104000
# No of mesh ids linked: 14031
# 105000
# No of mesh ids linked: 14068
# 106000
# No of mesh ids linked: 14102
# 107000
# No of mesh ids linked: 14152
# 108000
# No of mesh ids linked: 14179
# 109000
# No of mesh ids linked: 14215
# 110000
# No of mesh ids linked: 14257
# 111000
# No of mesh ids linked: 14290
# 112000
# No of mesh ids linked: 14314
# 113000
# No of mesh ids linked: 14348
# 114000
# No of mesh ids linked: 14380
# 115000
# No of mesh ids linked: 14418
# 116000
# No of mesh ids linked: 14455
# 117000
# No of mesh ids linked: 14495
# 118000
# No of mesh ids linked: 14529
# 119000
# No of mesh ids linked: 14575
# 120000
# No of mesh ids linked: 14615
# 121000
# No of mesh ids linked: 14652
# 122000
# No of mesh ids linked: 14683
# 123000
# No of mesh ids linked: 14719
# 124000
# No of mesh ids linked: 14752
# 125000
# No of mesh ids linked: 14782
# 126000
# No of mesh ids linked: 14816
# 127000
# No of mesh ids linked: 14856
# 128000
# No of mesh ids linked: 14895
# 129000
# No of mesh ids linked: 14930
# 130000
# No of mesh ids linked: 14956
# 131000
# No of mesh ids linked: 14991
# 132000
# No of mesh ids linked: 15013
# 133000
# No of mesh ids linked: 15050
# 134000
# No of mesh ids linked: 15080
# 135000
# No of mesh ids linked: 15119
# 136000
# No of mesh ids linked: 15154
# 137000
# No of mesh ids linked: 15188
# 138000
# No of mesh ids linked: 15235
# 139000
# No of mesh ids linked: 15260
# 140000
# No of mesh ids linked: 15292
# 141000
# No of mesh ids linked: 15322
# 142000
# No of mesh ids linked: 15364
# 143000
# No of mesh ids linked: 15398
# 144000
# No of mesh ids linked: 15424
# 145000
# No of mesh ids linked: 15452
# 146000
# No of mesh ids linked: 15483
# 147000
# No of mesh ids linked: 15513
# 148000
# No of mesh ids linked: 15537
# 149000
# No of mesh ids linked: 15562
# 150000
# No of mesh ids linked: 15607
# 151000
# No of mesh ids linked: 15650
# 152000
# No of mesh ids linked: 15688
# 153000
# No of mesh ids linked: 15718
# 154000
# No of mesh ids linked: 15765
# 155000
# No of mesh ids linked: 15806
# 156000
# No of mesh ids linked: 15843
# 157000
# No of mesh ids linked: 15870
# 158000
# No of mesh ids linked: 15907
# 159000
# No of mesh ids linked: 15932
# 160000
# No of mesh ids linked: 15956
# 161000
# No of mesh ids linked: 15992
# 162000
# No of mesh ids linked: 16016
# 163000
# No of mesh ids linked: 16052
# 164000
# No of mesh ids linked: 16078
# 165000
# No of mesh ids linked: 16113
# 166000
# No of mesh ids linked: 16135
# 167000
# No of mesh ids linked: 16171
# 168000
# No of mesh ids linked: 16206
# 169000
# No of mesh ids linked: 16245
# 170000
# No of mesh ids linked: 16283
# 171000
# No of mesh ids linked: 16332
# 172000
# No of mesh ids linked: 16367
# 173000
# No of mesh ids linked: 16398
# 174000
# No of mesh ids linked: 16441
# 175000
# No of mesh ids linked: 16472
# 176000
# No of mesh ids linked: 16499
# 177000
# No of mesh ids linked: 16527
# 178000
# No of mesh ids linked: 16569
# 179000
# No of mesh ids linked: 16605
# 180000
# No of mesh ids linked: 16638
# 181000
# No of mesh ids linked: 16731
# 182000
# No of mesh ids linked: 16868
# 183000
# No of mesh ids linked: 16989
# 184000
# No of mesh ids linked: 17130
# 185000
# No of mesh ids linked: 17316
# 186000
# No of mesh ids linked: 17479
# 187000
# No of mesh ids linked: 17646
# 188000
# No of mesh ids linked: 17794
# 189000
# No of mesh ids linked: 17960
# 190000
# No of mesh ids linked: 18219
# 191000
# No of mesh ids linked: 18391
# 192000
# No of mesh ids linked: 18584
# 193000
# No of mesh ids linked: 18725
# 194000
# No of mesh ids linked: 18894
# 195000
# No of mesh ids linked: 19237
# 196000
# No of mesh ids linked: 19369
# 197000
# No of mesh ids linked: 19539
# 198000
# No of mesh ids linked: 19715
# 199000
# No of mesh ids linked: 19888
# 200000
# No of mesh ids linked: 19997
# 201000
# No of mesh ids linked: 20109
# 202000
# No of mesh ids linked: 20209
# 203000
# No of mesh ids linked: 20306
# 204000
# No of mesh ids linked: 20512
# 205000
# No of mesh ids linked: 20694
# 206000
# No of mesh ids linked: 20864
# 207000
# No of mesh ids linked: 20978
# 208000
# No of mesh ids linked: 21083
# 209000
# No of mesh ids linked: 21196
# 210000
# No of mesh ids linked: 21296
# 211000
# No of mesh ids linked: 21436
# 212000
# No of mesh ids linked: 21597
# 213000
# No of mesh ids linked: 21715
# 214000
# No of mesh ids linked: 21835
# 215000
# No of mesh ids linked: 21926
# 216000
# No of mesh ids linked: 22008
# 217000
# No of mesh ids linked: 22077
# 218000
# No of mesh ids linked: 22141
# 219000
# No of mesh ids linked: 22252
# 220000
# No of mesh ids linked: 22392
# 221000
# No of mesh ids linked: 22425
# 222000
# No of mesh ids linked: 22465
# 223000
# No of mesh ids linked: 22498
# 224000
# No of mesh ids linked: 22525
# 225000
# No of mesh ids linked: 22559
# 226000
# No of mesh ids linked: 22593
# 227000
# No of mesh ids linked: 22681
# 228000
# No of mesh ids linked: 22898
# 229000
# No of mesh ids linked: 23205
# 230000
# No of mesh ids linked: 23491
# 231000
# No of mesh ids linked: 23829
# 232000
# No of mesh ids linked: 24066
# 233000
# No of mesh ids linked: 24315
# 234000
# No of mesh ids linked: 24538
# 235000
# No of mesh ids linked: 24757
# 236000
# No of mesh ids linked: 24993
# 237000
# No of mesh ids linked: 25285
# 238000
# No of mesh ids linked: 25556
# 239000
# No of mesh ids linked: 25807
# 240000
# No of mesh ids linked: 26014
# 241000
# No of mesh ids linked: 26239
# 242000
# No of mesh ids linked: 26508
# 243000
# No of mesh ids linked: 26770
# 244000
# No of mesh ids linked: 27050
# 245000
# No of mesh ids linked: 27322
# 246000
# No of mesh ids linked: 27556

# %%
with open('data/drugs_with_mesh.json', 'w') as fout:
    json.dump(drug_file, fout)

# %%
with open('data/foo.txt', 'w') as fout:
    for row in mesh_appended:
        output.write(str(row) + '\n')

# %% [markdown]
# ## Read docs with MESH

# %%
with open('data/drugs_with_mesh.json', 'r') as fout:
    drug_file = json.loads(fout.read())
    print(len(drug_file))
# Out:
# 246491

# %%
drug_file[0].keys()
# Out:
# dict_keys(['term', 'synonyms', 'mesh_headings', 'mesh_id', 'semantic_type', 'cid', 'chebi_id', 'inchikey', 'cross_references'])

# %% [markdown]
# ## Append non linked Mesh terms

# %%
with open('data/mesh_appended.txt','r') as f:
    mesh_appended = f.read().splitlines()

# %%
len(mesh_appended)
# Out:
# 21864

# %%
df_not_linked = ctd_df[~ctd_df.ChemicalID.isin(mesh_appended)]

# %%
df_not_linked.fillna('',inplace=True)
# Out:
# /home/alvaro/anaconda3/envs/biobert/lib/python3.8/site-packages/pandas/core/frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df_not_linked
# Out:
#                            ChemicalName  ChemicalID  \
# 0               (0.017ferrocene)amylose     C089250
# 1                            001-C8-NBD     C114385
# 2                   001-C8 oligopeptide     C114386
# 3                  0231A , Streptomyces     C434150
# 4                   0231B, Streptomyces     C434149
# ...                                 ...         ...
# 174234    (Z,Z)-6,9-heneicosadien-11-ol     C482761
# 174235         (Z,Z)-6,9-heptadecadiene  C000712888
# 174236        (Z,Z)-7,11-hexadecadienal     C558532
# 174237       (Z,Z)-dodeca-3,6-dien-1-ol     C483463
# 174238  (Z,Z,E)-7,11,13-hexadecatrienal     C558533
#
#                                                  Synonyms
# 0                                (0.017 ferrocene)amylose
# 1       001 C8 NBD|H-MeTyr-Arg-MeArg-D-Leu-NH(CH2)8NH-...
# 2       001 C8 oligopeptide|H-MeTyr-Arg-MeArg-D-Leu-NH...
# 3
# 4
# ...                                                   ...
# 174234                                    Z6Z9-11R-ol-C21
# 174235                                            6,9-C17
# 174236
# 174237
# 174238
#
# [152375 rows x 3 columns]

# %%
for i in df_not_linked.itertuples(index=False):
    new_doc = {}
    new_doc['term'] = i[0]
    
    synonyms = []
    if len(i[2])>0:
        synonyms += i[2].split("|")
    new_doc['synonyms']= synonyms

    new_doc['mesh_headings'] = ''
    new_doc['mesh_id'] = i[1]
    new_doc['semantic_type'] = ''
    new_doc['cid'] = ''
    new_doc['chebi_id'] = ''
    new_doc['inchikey'] = ''
    new_doc['cross_references'] = ''
    
    drug_file.append(new_doc)

# %%
print(len(drug_file))
# Out:
# 398866

# %% [markdown]
# ## Resultant number of linked Mesh terms

# %%
from collections import Counter
counter = Counter(x['mesh_id'] for x in drug_file)

# %%
print('The number of terms with MESH value is:',len(drug_file)-counter[''])
# Out:
# The number of terms with MESH value is: 199920

# %% [markdown]
# ## Save and load Doc with Mesh

# %%
with open('data/drugs.json', 'w') as fout:
    json.dump(drug_file, fout)

# %%
with open('data/drugs.json', 'r') as fout:
    drugs = json.loads(fout.read())
    print(len(drugs))
# Out:
# 398866

# %% [markdown]
# # ATC

# %%
atc_df= pd.read_csv(
    "data/ATC.csv",      # relative python path to subdirectory
    sep=',',
    na_filter=False,
    quotechar="\"",       # single quote allowed as quote character
    usecols=['Class ID','Preferred Label','Synonyms','Semantic Types','ATC LEVEL'],
    dtype=str
)

print(atc_df.shape)
atc_df.head()
# Out:
# (6458, 5)
#                                             Class ID  \
# 0  http://purl.bioontology.org/ontology/UATC/A03AX13
# 1  http://purl.bioontology.org/ontology/UATC/J01DB07
# 2    http://purl.bioontology.org/ontology/UATC/V09AA
# 3  http://purl.bioontology.org/ontology/UATC/G03GA04
# 4  http://purl.bioontology.org/ontology/UATC/D04AA10
#
#                                      Preferred Label  \
# 0                                          silicones
# 1                                        cefatrizine
# 2  Technetium 99m compounds, central nervous syst...
# 3                                     urofollitropin
# 4                                       promethazine
#
#                        Synonyms  \
# 0
# 1
# 2  Technetium (99mTc) compounds
# 3
# 4
#
#                                       Semantic Types ATC LEVEL
# 0  http://purl.bioontology.org/ontology/STY/T109|...         5
# 1  http://purl.bioontology.org/ontology/STY/T195|...         5
# 2  http://purl.bioontology.org/ontology/STY/T130|...         4
# 3  http://purl.bioontology.org/ontology/STY/T116|...         5
# 4  http://purl.bioontology.org/ontology/STY/T109|...         5

# %%
atc_df['Class ID'] = atc_df['Class ID'].apply(lambda x: x.split('/')[-1])

# %%
atc_df['Semantic Types'] = atc_df['Semantic Types'].apply(lambda x: x.split('|')[-1].split('/')[-1])

# %%
semantic_type_df = pd.read_csv(
    "data/STY.csv",      # relative python path to subdirectory
    sep=',',
    dtype=str,
    usecols=['Class ID','Preferred Label']
)
semantic_type_df
# Out:
#                                           Class ID  \
# 0    http://purl.bioontology.org/ontology/STY/T057
# 1    http://purl.bioontology.org/ontology/STY/T047
# 2    http://purl.bioontology.org/ontology/STY/T167
# 3    http://purl.bioontology.org/ontology/STY/T066
# 4    http://purl.bioontology.org/ontology/STY/T184
# ..                                             ...
# 122  http://purl.bioontology.org/ontology/STY/T194
# 123  http://purl.bioontology.org/ontology/STY/T012
# 124  http://purl.bioontology.org/ontology/STY/T087
# 125  http://purl.bioontology.org/ontology/STY/T122
# 126  http://purl.bioontology.org/ontology/STY/T197
#
#                    Preferred Label
# 0            Occupational Activity
# 1              Disease or Syndrome
# 2                        Substance
# 3                 Machine Activity
# 4                  Sign or Symptom
# ..                             ...
# 122                       Archaeon
# 123                           Bird
# 124            Amino Acid Sequence
# 125  Biomedical or Dental Material
# 126             Inorganic Chemical
#
# [127 rows x 2 columns]

# %%
semantic_type_df['Class ID'] = semantic_type_df['Class ID'].apply(lambda x: x.split('/')[-1])

# %%
atc_df = atc_df.merge(semantic_type_df,left_on='Semantic Types',right_on='Class ID',how='inner')

# %%
atc_df.drop(['Semantic Types','Class ID_y'],inplace=True,axis=1)

# %%
atc_df.rename(columns={'Preferred Label_y':'Semantic Type','Preferred Label_x':'Term','Class ID_x':'ATC'},inplace=True)

# %%
atc_df
# Out:
#           ATC                        Term Synonyms ATC LEVEL  \
# 0     A03AX13                   silicones                  5
# 1     B05AA06              gelatin agents                  5
# 2       V07AA                    Plasters                  4
# 3       A01AA  Caries prophylactic agents                  4
# 4     V03AE01       polystyrene sulfonate                  5
# ...       ...                         ...      ...       ...
# 6326  A07FA02     saccharomyces boulardii                  5
# 6327  B05AX03                blood plasma                  5
# 6328  G01AX14               lactobacillus                  5
# 6329  D08AL30                      silver                  5
# 6330  V03AN04                    nitrogen                  5
#
#                       Semantic Type
# 0     Biomedical or Dental Material
# 1     Biomedical or Dental Material
# 2     Biomedical or Dental Material
# 3     Biomedical or Dental Material
# 4     Biomedical or Dental Material
# ...                             ...
# 6326                         Fungus
# 6327                 Body Substance
# 6328                      Bacterium
# 6329       Element, Ion, or Isotope
# 6330       Element, Ion, or Isotope
#
# [6331 rows x 5 columns]

# %%
i = 0
num = 0
atc_appended= set([])

for doc in drugs:
    proposed_atc = atc_df.loc[atc_df['Term']==doc['term']]
    if len(proposed_atc)>0:
        new_atc_id = str(proposed_atc['ATC'].values[0])
        new_semantic_type = str(proposed_atc['Semantic Type'].values[0])
        new_level = str(proposed_atc['ATC LEVEL'].values[0])
        doc['ATC'] = new_atc_id
        doc['semantic_type'] = new_semantic_type
        doc['ATC_level'] = new_level
        atc_appended.add(new_atc_id)
        num +=1
    elif len(proposed_atc)<1:
        try:
            alternative_proposed_atc = atc_df[atc_df['Synonyms'].str.contains(doc['term'], na=False, case = False,regex= False)]
            if len(alternative_proposed_atc)>0 and len(alternative_proposed_atc)<2:
                new_atc_id = str(alternative_proposed_atc['ATC'].values[0])
                new_semantic_type = str(alternative_proposed_atc['Semantic Type'].values[0])
                new_level = str(alternative_proposed_atc['ATC LEVEL'].values[0])
                doc['ATC'] = new_atc_id
                doc['semantic_type'] = new_semantic_type
                doc['ATC_level'] = new_level
                atc_appended.add(new_atc_id)
                num +=1
            elif len(alternative_proposed_atc)>1:
                all_terms=[]
                for j in alternative_proposed_atc.itertuples(index=False):
                    all_terms.append(j[1])
                    all_terms += [f for f in j[2].split('|')]

                    if doc['term'] in all_terms:
                        doc['ATC'] = j[0]
                        doc['semantic_type'] = j[4]
                        doc['ATC_level'] =j[3]
                        atc_appended.add(j[0])
                        num +=1
                    elif similar(doc['term'],j[0])>0.92:
                        doc['ATC'] = j[0]
                        doc['semantic_type'] = j[4]
                        doc['ATC_level'] =j[3]
                        atc_appended.add(j[0])
                        num +=1
                    all_terms=[]
            else:
                doc['ATC'] = ''
                doc['ATC_level'] = ''
                    
        except:
            print('Error in:',doc['term'])


        
            
    i +=1
    if i%30000 == 0:
        print(i)
        print('No of ATC ids linked:',num)
# Out:
# 30000
# No of ATC ids linked: 69
# 60000
# No of ATC ids linked: 218
# 90000
# No of ATC ids linked: 233
# 120000
# No of ATC ids linked: 355
# 150000
# No of ATC ids linked: 407
# 180000
# No of ATC ids linked: 458
# 210000
# No of ATC ids linked: 465
# 240000
# No of ATC ids linked: 483
# 270000
# No of ATC ids linked: 483
# 300000
# No of ATC ids linked: 540
# 330000
# No of ATC ids linked: 815
# 360000
# No of ATC ids linked: 979
# 390000
# No of ATC ids linked: 1179

# %% [markdown]
# ## Append non linked ATC terms

# %%
len(atc_appended)
# Out:
# 1115

# %%
atc_appended=list(atc_appended)

# %%
df_not_linked = atc_df[~atc_df['ATC'].isin(atc_appended)]

# %%
df_not_linked.fillna('',inplace=True)
# Out:
# /home/alvaro/anaconda3/envs/biobert/lib/python3.8/site-packages/pandas/core/frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
drugs[0]
# Out:
# {'term': 'Acetylcarnitine',
#  'synonyms': ['Acetyl-DL-carnitine',
#   'acetylcarnitine',
#   'DL-O-Acetylcarnitine',
#   'DL-Acetylcarnitine',
#   'O-acetylcarnitine',
#   '3-acetyloxy-4-(trimethylazaniumyl)butanoate',
#   '(+/-)-acetylcarnitine',
#   '3-(acetyloxy)-4-(trimethylazaniumyl)butanoate',
#   'Ammonium, (3-carboxy-2-hydroxypropyl)trimethyl-, hydroxide, inner salt, acetate, DL-',
#   '14992-62-2',
#   '870-77-9',
#   '1-Propanaminium, 2-(acetoxy)-3-carboxy-N,N,N-trimethyl-, hydroxide, inner salt, (+-)- (9CI)',
#   'L-ACETYLCARNITINE',
#   '1-Propanaminium, 2-(acetyloxy)-3-carboxy-N,N,N-trimethyl-, inner salt',
#   '3040-38-8',
#   'bmse000142',
#   'SCHEMBL69781',
#   'DTXSID2048117',
#   'CHEBI:73024',
#   'LMFA07070060',
#   'HY-126358',
#   '3-(acetyloxy)-4-(trimethylammonio)butanoate',
#   'CS-0102945',
#   'FT-0778235',
#   'Q27140241',
#   '3-(acetyloxy)-4-(trimethylazaniumyl)butanoate',
#   'acetylcarnitine',
#   '3-(acetyloxy)-4-(trimethylammonio)butanoate',
#   'Acetyl-DL-carnitine',
#   'DL-O-Acetylcarnitine'],
#  'mesh_headings': 'Acetylcarnitine',
#  'mesh_id': 'D000108',
#  'semantic_type': '',
#  'cid': '1',
#  'chebi_id': 'CHEBI:73024',
#  'inchikey': 'RDHQFKQIGNGIED-UHFFFAOYSA-N',
#  'cross_references': ['CAS:870-77-9', 'PMID:23315938', 'Reaxys:4136458'],
#  'ATC': '',
#  'ATC_level': ''}

# %%
df_not_linked
# Out:
#           ATC                        Term Synonyms ATC LEVEL  \
# 0     A03AX13                   silicones                  5
# 1     B05AA06              gelatin agents                  5
# 2       V07AA                    Plasters                  4
# 3       A01AA  Caries prophylactic agents                  4
# 4     V03AE01       polystyrene sulfonate                  5
# ...       ...                         ...      ...       ...
# 6326  A07FA02     saccharomyces boulardii                  5
# 6327  B05AX03                blood plasma                  5
# 6328  G01AX14               lactobacillus                  5
# 6329  D08AL30                      silver                  5
# 6330  V03AN04                    nitrogen                  5
#
#                       Semantic Type
# 0     Biomedical or Dental Material
# 1     Biomedical or Dental Material
# 2     Biomedical or Dental Material
# 3     Biomedical or Dental Material
# 4     Biomedical or Dental Material
# ...                             ...
# 6326                         Fungus
# 6327                 Body Substance
# 6328                      Bacterium
# 6329       Element, Ion, or Isotope
# 6330       Element, Ion, or Isotope
#
# [5216 rows x 5 columns]

# %%
for i in df_not_linked.itertuples(index=False):
    new_doc = {}
    new_doc['term'] = i[1]
    
    synonyms = []
    if len(i[2])>0:
        synonyms += i[2].split("|")
    new_doc['synonyms']= synonyms

    new_doc['mesh_headings'] = ''
    new_doc['mesh_id'] = ''
    new_doc['semantic_type'] = i[4]
    new_doc['cid'] = ''
    new_doc['chebi_id'] = ''
    new_doc['inchikey'] = ''
    new_doc['cross_references'] = ''
    new_doc['ATC'] = i[0]
    new_doc['ATC_level'] = i[3]
    
    drugs.append(new_doc)

# %%
print(len(drugs))
# Out:
# 404082

# %%
with open('data/Chemical/drugs.json', 'w') as fout:
    json.dump(drugs, fout)

# %%
with open('data/Chemical/drugs.json', 'r') as fout:
    drugs = json.loads(fout.read())
    print(len(drugs))
# Out:
# 398866

# %%
import pysolr
import math

solr = pysolr.Solr('http://localhost:8983/solr/gettingstarted', timeout=10)

# %%
solr.ping()
# Out:
# '{\n  "responseHeader":{\n    "zkConnected":null,\n    "status":0,\n    "QTime":25,\n    "params":{\n      "q":"{!lucene}*:*",\n      "distrib":"false",\n      "df":"_text_",\n      "rows":"10",\n      "echoParams":"all",\n      "rid":"-4"}},\n  "status":"OK"}\n'

# %%
import pysolr
import math

solr = pysolr.Solr('http://librairy.linkedddata.es/data/atc', timeout=2)

documents = []
num = 0;
for i in atc_data.itertuples(index=False):
    atc_document = {}
    if (len(i[0]) > 0 ):
        atc_document['id']= i[0].split("/")[-1]
    if (len(i[1]) > 0 ):
        atc_document['label_t']= i[1].lower()
    synonyms = []
    if (len(i[2]) > 0 ):
        synonyms.append(i[2].lower())
    atc_document['synonyms']= synonyms
    if (len(i[3]) > 0 ):
        atc_document['cui_s']= i[3]
    if (len(i[4]) > 0 ):
        atc_document['parent_s']= i[4].split("/")[-1]
    if (len(i[5]) > 0 ):
        atc_document['level_i']= i[5]    
    documents.append(atc_document) 
    num+=1
    if (len(documents) > 0 and len(documents) %100 == 0):
        solr.add(documents)
        solr.commit()
        documents = []
        print(num,"drugs added")
# Out:
# 100 drugs added
# 200 drugs added
# 300 drugs added
# 400 drugs added
# 500 drugs added
# 600 drugs added
# 700 drugs added
# 800 drugs added
# 900 drugs added
# 1000 drugs added
# 1100 drugs added
# 1200 drugs added
# 1300 drugs added
# 1400 drugs added
# 1500 drugs added
# 1600 drugs added
# 1700 drugs added
# 1800 drugs added
# 1900 drugs added
# 2000 drugs added
# 2100 drugs added
# 2200 drugs added
# 2300 drugs added
# 2400 drugs added
# 2500 drugs added
# 2600 drugs added
# 2700 drugs added
# 2800 drugs added
# 2900 drugs added
# 3000 drugs added
# 3100 drugs added
# 3200 drugs added
# 3300 drugs added
# 3400 drugs added
# 3500 drugs added
# 3600 drugs added
# 3700 drugs added
# 3800 drugs added
# 3900 drugs added
# 4000 drugs added
# 4100 drugs added
# 4200 drugs added
# 4300 drugs added
# 4400 drugs added
# 4500 drugs added
# 4600 drugs added
# 4700 drugs added
# 4800 drugs added
# 4900 drugs added
# 5000 drugs added
# 5100 drugs added
# 5200 drugs added
# 5300 drugs added
# 5400 drugs added
# 5500 drugs added
# 5600 drugs added
# 5700 drugs added
# 5800 drugs added
# 5900 drugs added
# 6000 drugs added
# 6100 drugs added
# 6200 drugs added
# 6300 drugs added

# %% [markdown]
# # Adding CIMA Codes

# %%
drugs_data = pd.read_csv(
    "data/drugs.csv",      # relative python path to subdirectory
    sep=';',           # Tab-separated value file.
    quotechar="\"",        # single quote allowed as quote character
    usecols=['Nº Registro', 'Medicamento', 'Cód. ATC']
)

print(drugs_data.shape) 
drugs_data.head()
# Out:
# (23407, 3)
#   Nº Registro                                   Medicamento Cód. ATC
# 0       40537                   INACID 25 mg CAPSULAS DURAS  M01AB01
# 1        7235                    PASSIFLORINE SOLUCION ORAL    N05CM
# 2       18329                         TIOBARBITAL BRAUN 1 G  N01AF03
# 3       33561                        DIHYDERGOT COMPRIMIDOS  N02CA01
# 4       34369  GLUCOSADA GRIFOLS 5% SOLUCION PARA PERFUSION  B05BA03

# %%
atc_regs = drugs_data.groupby('Cód. ATC')['Nº Registro'].apply(list).reset_index()
print(atc_regs)
# Out:
#      Cód. ATC                                       Nº Registro
# 0     A01AA01                                    [57745, 57746]
# 1       A01AB  [38791, 34484, 35528, 12912, 45563, 9957, 29898]
# 2     A01AB03                                    [84343, 80642]
# 3     A01AB09                                    [55969, 55962]
# 4     A01AB19                                           [39783]
# ...       ...                                               ...
# 2227    V10XX                              [05322001, 05322002]
# 2228  V10XX02                                        [03264001]
# 2229  V10XX03                                       [113873001]
# 2230  V10XX04                                      [1171226001]
# 2231   XXXXXX               [75668, 75670, 75659, 75661, 75663]
#
# [2232 rows x 2 columns]

# %%
import pysolr

solr = pysolr.Solr('http://librairy.linkeddata.es/data/atc', timeout=2)

def add_num_regs(atc_code,num_regs):
    solr_query = "id:"+str(atc_code)
    for result in solr.search(q=solr_query,rows=1):
        result['cima_codes']=num_regs
        del (result['_version_'])
        return result
    return {}

sample_doc = {
  "id": "1212121212112121212",
  "cima_codes":["a","b","c"]
}
solr.add([sample_doc])
solr.commit()
solr.delete(id=sample_doc['id'])
solr.commit()
updated_drugs = []
num = 0;
for i in atc_regs.itertuples():
    atc_code = i[1]
    updated_drugs.append(add_num_regs(atc_code,[str(code) for code in i[2]])) 
    num+=1
    if (len(updated_drugs) == 0):
        solr.add(updated_drugs)
        solr.commit()
        updated_drugs = []
        print(num,"drugs updated")
# Out:
# 100 drugs updated
# 200 drugs updated
# 300 drugs updated
# 400 drugs updated
# 500 drugs updated
# 600 drugs updated
# 700 drugs updated
# 800 drugs updated
# 900 drugs updated
# 1000 drugs updated
# 1100 drugs updated
# 1200 drugs updated
# 1300 drugs updated
# 1400 drugs updated
# 1500 drugs updated
# 1600 drugs updated
# 1700 drugs updated
# 1800 drugs updated
# 1900 drugs updated
# 2000 drugs updated
# 2100 drugs updated
# 2200 drugs updated

# %% [markdown]
# # Adding medical names

# %%
import pandas as pd

md_df = pd.read_excel('data/Medicines_output_european_public_assessment_reports.xlsx', skiprows=8, keep_default_na=False)
md_df.head()
# Out:
#   Category     Medicine name                      Therapeutic area  \
# 0    Human           Eliquis  Arthroplasty, Venous Thromboembolism
# 1    Human  Temozolomide Sun                  Glioma, Glioblastoma
# 2    Human  Atazanavir Mylan                        HIV Infections
# 3    Human           Vivanza                  Erectile Dysfunction
# 4    Human            Juluca                        HIV Infections
#
#   International non-proprietary name (INN) / common name  \
# 0                                           apixaban
# 1                                       temozolomide
# 2                                         atazanavir
# 3                                         vardenafil
# 4                         dolutegravir / rilpivirine
#
#                                  Active substance   Product number  \
# 0                                        Apixaban  EMEA/H/C/002148
# 1                                    temozolomide  EMEA/H/C/002198
# 2                              atazanavir sulfate  EMEA/H/C/004048
# 3                                      vardenafil  EMEA/H/C/000488
# 4  dolutegravir sodium, rilpivirine hydrochloride  EMEA/H/C/004427
#
#   Patient safety Authorisation status ATC code Additional monitoring  ...  \
# 0            yes           Authorised  B01AF02                    no  ...
# 1             no           Authorised  L01AX03                    no  ...
# 2             no           Authorised  J05AE08                    no  ...
# 3             no           Authorised  G04BE09                    no  ...
# 4            yes           Authorised    J05AR                   yes  ...
#
#   Vet pharmacotherapeutic group      Date of opinion       Decision date  \
# 0                                                    2020-03-26 01:00:00
# 1                                                    2020-03-11 01:00:00
# 2                                                    2020-03-12 01:00:00
# 3                                                    2020-03-19 01:00:00
# 4                                2018-03-22 01:00:00 2020-04-01 00:00:00
#
#   Revision number                             Condition / indication Species  \
# 0              20  For Eliquis 2.5 mg film-coated tablets:Prevent...
# 1              16  Temozolomide Sun is indicated for the treatmen...
# 2               8  Atazanavir Mylan, co-administered with low dos...
# 3              27  Treatment of erectile dysfunction in adult men...
# 4               2  Juluca is indicated for the treatment of human...
#
#   ATCvet code     First published       Revision date  \
# 0             2018-08-03 16:27:00 2020-04-22 17:05:00
# 1             2018-08-03 00:00:00 2020-04-22 16:34:00
# 2             2018-05-03 17:20:00 2020-04-22 16:00:00
# 3             2018-04-19 00:00:00 2020-04-22 16:00:00
# 4             2018-05-16 12:26:00 2020-04-22 15:44:00
#
#                                                  URL
# 0  https://www.ema.europa.eu/en/medicines/human/E...
# 1  https://www.ema.europa.eu/en/medicines/human/E...
# 2  https://www.ema.europa.eu/en/medicines/human/E...
# 3  https://www.ema.europa.eu/en/medicines/human/E...
# 4  https://www.ema.europa.eu/en/medicines/human/E...
#
# [5 rows x 30 columns]

# %%
import pysolr
import html2text
import urllib.request

solr = pysolr.Solr('http://librairy.linkeddata.es/data/atc', timeout=20)

h = html2text.HTML2Text()
h.ignore_links = True

def add_field_in_list(resource,field,value):
    if (len(value) > 0 ):
        if (not field in resource):
            resource[field] = []
        resource[field].append(value)  

def get_txt(url):
    fp = urllib.request.urlopen(url)
    mybytes = fp.read()
    mystr = mybytes.decode("utf8")
    fp.close()
    return h.handle(mystr)

documents = []
i = 1
for row in md_df.itertuples():
    atc_code = row[9]
    if (len(atc_code) > 1):
        for drug in solr.search("id:"+atc_code):
            add_field_in_list(drug,'category',row[1])
            add_field_in_list(drug,'medicines',row[2])
            add_field_in_list(drug,'therapeutic_area',row[3])
            add_field_in_list(drug,'emea_codes',row[6])
            add_field_in_list(drug,'overviews',row[30])
            solr.add([drug])
            solr.commit()
            #print(drug)
            if (i % 100 == 0):
                print(i,"drugs updated")
            i+=1
# Out:
# 100 drugs updated
# 200 drugs updated
# 300 drugs updated
# 400 drugs updated
# 500 drugs updated
# 600 drugs updated
# 700 drugs updated
# 800 drugs updated
# 900 drugs updated
# 1000 drugs updated
# 1100 drugs updated
# 1200 drugs updated
# 1300 drugs updated
